# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import os
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0, ResNet50, DenseNet201, MobileNet, MobileNetV2, VGG16
from tensorflow.keras.optimizers import AdamW, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import math
import itertools
import cv2

# Data loading
data_dir = r"/kaggle/input/eye-diseases-classification/dataset"
filepaths = []
labels = []
folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis=1)

print("Class distribution:")
print(df['labels'].value_counts())
print(f"Number of unique classes: {df['labels'].nunique()}")

# Split data
train_df, dummy_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42)
valid_df, test_df = train_test_split(dummy_df, train_size=0.6, shuffle=True, random_state=42)

print(f"Train samples: {len(train_df)}")
print(f"Valid samples: {len(valid_df)}")
print(f"Test samples: {len(test_df)}")

# Create data generators
batch_size = 32
img_size = (224, 224)
channels = 3

tr_gen = ImageDataGenerator(rescale=1./255)
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen = tr_gen.flow_from_dataframe(
    train_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
valid_gen = ts_gen.flow_from_dataframe(
    valid_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
test_gen = ts_gen.flow_from_dataframe(
    test_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=False, batch_size=batch_size
)

# Get number of classes
num_classes = 4
class_names = list(train_gen.class_indices.keys())
print(f"Classes: {class_names}")

# Multiscale Attention Layer for Eye Disease Classifier
class MultiscaleAttentionLayer(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(MultiscaleAttentionLayer, self).__init__(**kwargs)
        self.filters = filters
        
    def build(self, input_shape):
        # Channel attention
        self.channel_attention = keras.Sequential([
            layers.GlobalAveragePooling2D(),
            layers.Dense(self.filters // 8, activation='relu'),
            layers.Dense(self.filters, activation='sigmoid'),
            layers.Reshape((1, 1, self.filters))
        ])
        
        # Spatial attention
        self.spatial_attention = keras.Sequential([
            layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')
        ])
        
        super(MultiscaleAttentionLayer, self).build(input_shape)
    
    def call(self, inputs):
        # Channel attention
        channel_att = self.channel_attention(inputs)
        x = layers.Multiply()([inputs, channel_att])
        
        # Spatial attention
        avg_pool = tf.reduce_mean(x, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(x, axis=-1, keepdims=True)
        spatial_input = layers.Concatenate()([avg_pool, max_pool])
        spatial_att = self.spatial_attention(spatial_input)
        x = layers.Multiply()([x, spatial_att])
        
        return x
    
    def get_config(self):
        config = super(MultiscaleAttentionLayer, self).get_config()
        config.update({'filters': self.filters})
        return config

# Eye Disease Classifier
def create_eye_disease_classifier(num_classes):
    """
    Create Eye Disease Classifier with VGG16 base and multiscale attention
    """
    try:
        # Load pre-trained VGG16
        base_model = VGG16(
            weights='imagenet',
            include_top=False,
            input_shape=(224, 224, 3)
        )
        
        # Freeze early layers, unfreeze last few blocks for fine-tuning
        for layer in base_model.layers[:-4]:
            layer.trainable = False
        for layer in base_model.layers[-4:]:
            layer.trainable = True
            
        # Build the complete model
        inputs = keras.Input(shape=(224, 224, 3), name='input_image')
        
        # VGG16 feature extraction
        x = base_model(inputs, training=False)
        
        # Get the number of filters from VGG16 output
        vgg_output_filters = x.shape[-1]
        
        # Multiscale attention mechanism
        x = MultiscaleAttentionLayer(filters=vgg_output_filters, name='multiscale_attention')(x)
        
        # Global Average Pooling
        x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
        
        # Dropout for regularization
        x = layers.Dropout(0.5, name='dropout_1')(x)
        
        # Dense layer with batch normalization
        x = layers.Dense(256, activation='relu', name='dense_1')(x)
        x = layers.BatchNormalization(name='batch_norm')(x)
        x = layers.Dropout(0.25, name='dropout_2')(x)
        
        # Output layer with softmax activation
        predictions = layers.Dense(num_classes, activation='softmax', name='predictions')(x)
        
        # Create the model
        model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier')
        
        print(f"Eye Disease Classifier built successfully with {model.count_params()} parameters")
        return model
        
    except Exception as e:
        print(f"Error building model: {str(e)}")
        print("Building simplified model...")
        return create_eye_disease_classifier_simplified(num_classes)

def create_eye_disease_classifier_simplified(num_classes):
    """
    Build a simplified model without custom layers as fallback
    """
    # Load pre-trained VGG16
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    # Freeze early layers
    for layer in base_model.layers[:-4]:
        layer.trainable = False
    for layer in base_model.layers[-4:]:
        layer.trainable = True
        
    # Build simplified model
    inputs = keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    
    # Simple attention using Global Average Pooling and Dense layers
    gap = layers.GlobalAveragePooling2D()(x)
    attention_weights = layers.Dense(x.shape[-1], activation='sigmoid')(gap)
    attention_weights = layers.Reshape((1, 1, x.shape[-1]))(attention_weights)
    x = layers.Multiply()([x, attention_weights])
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.25)(x)
    predictions = layers.Dense(num_classes, activation='softmax')(x)
    
    model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier_Simplified')
    
    print(f"Simplified Eye Disease Classifier built successfully with {model.count_params()} parameters")
    return model

# ViT Small Implementation
class PatchEmbedding(layers.Layer):
    def __init__(self, patch_size=16, embed_dim=384):
        super().__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.projection = layers.Conv2D(
            embed_dim, kernel_size=patch_size, strides=patch_size, padding='valid'
        )
        
    def call(self, x):
        batch_size = tf.shape(x)[0]
        patches = self.projection(x)
        patches = tf.reshape(patches, [batch_size, -1, self.embed_dim])
        return patches

class MultiHeadAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        
        self.qkv = layers.Dense(embed_dim * 3)
        self.projection = layers.Dense(embed_dim)
        
    def call(self, x):
        batch_size, seq_len, embed_dim = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        
        qkv = self.qkv(x)
        qkv = tf.reshape(qkv, [batch_size, seq_len, 3, self.num_heads, self.head_dim])
        qkv = tf.transpose(qkv, [2, 0, 3, 1, 4])
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = tf.cast(self.head_dim, tf.float32) ** -0.5
        attn = tf.matmul(q, k, transpose_b=True) * scale
        attn = tf.nn.softmax(attn, axis=-1)
        
        out = tf.matmul(attn, v)
        out = tf.transpose(out, [0, 2, 1, 3])
        out = tf.reshape(out, [batch_size, seq_len, embed_dim])
        
        return self.projection(out)

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, mlp_ratio=4.0, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = MultiHeadAttention(embed_dim, num_heads)
        self.dropout1 = layers.Dropout(dropout)
        
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        mlp_hidden_dim = int(embed_dim * mlp_ratio)
        self.mlp = keras.Sequential([
            layers.Dense(mlp_hidden_dim, activation='gelu'),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout)
        ])
        
    def call(self, x, training=None):
        attn_out = self.attn(self.norm1(x))
        x = x + self.dropout1(attn_out, training=training)
        
        mlp_out = self.mlp(self.norm2(x), training=training)
        x = x + mlp_out
        
        return x

class VisionTransformerSmall(keras.Model):
    def __init__(self, 
                 img_size=224,
                 patch_size=16, 
                 num_classes=4,
                 embed_dim=384,
                 depth=12,
                 num_heads=6,
                 mlp_ratio=4.0,
                 dropout=0.1):
        super().__init__()
        
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        
        self.patch_embed = PatchEmbedding(patch_size, embed_dim)
        
        self.class_token = self.add_weight(
            shape=(1, 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='class_token'
        )
        
        self.pos_embed = self.add_weight(
            shape=(1, self.num_patches + 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='pos_embed'
        )
        
        self.dropout = layers.Dropout(dropout)
        
        self.blocks = [
            TransformerBlock(embed_dim, num_heads, mlp_ratio, dropout)
            for _ in range(depth)
        ]
        
        self.norm = layers.LayerNormalization(epsilon=1e-6)
        self.head = layers.Dense(num_classes)
        
    def call(self, x, training=None):
        batch_size = tf.shape(x)[0]
        
        x = self.patch_embed(x)
        
        class_tokens = tf.broadcast_to(self.class_token, [batch_size, 1, tf.shape(self.class_token)[-1]])
        x = tf.concat([class_tokens, x], axis=1)
        
        x = x + self.pos_embed
        x = self.dropout(x, training=training)
        
        for block in self.blocks:
            x = block(x, training=training)
            
        x = self.norm(x)
        
        class_token_final = x[:, 0]
        return self.head(class_token_final)

def create_vit_small(num_classes):
    return VisionTransformerSmall(
        img_size=224,
        patch_size=16,
        num_classes=num_classes,
        embed_dim=384,
        depth=12,
        num_heads=6,
        mlp_ratio=4.0,
        dropout=0.1
    )

# Other model creation functions
def create_efficientnet(num_classes):
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_vgg16(num_classes):
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_denseNet201(num_classes):
    base_model = DenseNet201(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

# GradCAM implementation
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Generate GradCAM heatmap"""
    try:
        # Create a model that maps the input image to the activations of the last conv layer
        grad_model = tf.keras.models.Model(
            [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
        )
        
        # Compute the gradient of the top predicted class
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Gradient of the output neuron with regard to the output feature map
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Mean intensity of the gradient over a specific feature map channel
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Multiply each channel by "how important this channel is"
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize the heatmap between 0 & 1
        heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
        return heatmap.numpy()
    except Exception as e:
        print(f"GradCAM error: {e}")
        return None

# Fixed GradCAM implementation with proper layer detection

def get_last_conv_layer_name(model, model_name):
    """Enhanced function to get the last convolutional layer name"""
    conv_layers = []
    
    def collect_conv_layers(layer_or_model, prefix=""):
        """Recursively collect all conv layer names"""
        if hasattr(layer_or_model, 'layers'):
            for layer in layer_or_model.layers:
                layer_name = f"{prefix}{layer.name}" if prefix else layer.name
                
                # Check if it's a conv layer
                if any(conv_type in layer.__class__.__name__.lower() for conv_type in ['conv2d', 'separableconv2d', 'depthwiseconv2d']):
                    conv_layers.append(layer_name)
                
                # Recursively check sublayers
                collect_conv_layers(layer, prefix=f"{layer_name}/")
    
    # Start collection from the model
    collect_conv_layers(model)
    
    # If no conv layers found directly, try to access base model
    if not conv_layers:
        try:
            # For Sequential models
            if hasattr(model, 'layers') and len(model.layers) > 0:
                first_layer = model.layers[0]
                if hasattr(first_layer, 'layers'):
                    collect_conv_layers(first_layer)
        except:
            pass
    
    # Print available conv layers for debugging
    print(f"Available conv layers in {model_name}: {conv_layers[-5:]}")  # Show last 5
    
    # Return the last conv layer found
    return conv_layers[-1] if conv_layers else None

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Enhanced GradCAM with better error handling"""
    try:
        # Handle nested layer names (e.g., "base_model/block5_conv3")
        if '/' in last_conv_layer_name:
            layer_parts = last_conv_layer_name.split('/')
            current_layer = model
            
            # Navigate through nested layers
            for part in layer_parts:
                if hasattr(current_layer, 'get_layer'):
                    current_layer = current_layer.get_layer(part)
                elif hasattr(current_layer, 'layers'):
                    # Find layer by name in layers list
                    found = False
                    for layer in current_layer.layers:
                        if layer.name == part:
                            current_layer = layer
                            found = True
                            break
                    if not found:
                        raise ValueError(f"Layer {part} not found")
                else:
                    raise ValueError(f"Cannot navigate to layer {part}")
            
            target_layer = current_layer
        else:
            # Simple case - direct layer access
            target_layer = model.get_layer(last_conv_layer_name)
        
        # Create gradient model
        grad_model = tf.keras.models.Model(
            [model.inputs], 
            [target_layer.output, model.output]
        )
        
        # Compute gradients
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Get gradients
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Handle None gradients
        if grads is None:
            print(f"Warning: No gradients computed for layer {last_conv_layer_name}")
            return None
        
        # Compute importance weights
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Generate heatmap
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize heatmap
        heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-10)
        return heatmap.numpy()
        
    except Exception as e:
        print(f"GradCAM failed for {last_conv_layer_name}: {str(e)}")
        return None

def plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples=4):
    """Fixed GradCAM plotting with fallback strategies"""
    print(f"\nGenerating GradCAM for {model_name}...")
    
    # Get last conv layer with enhanced detection
    last_conv_layer = get_last_conv_layer_name(model, model_name)
    
    if not last_conv_layer:
        print(f"No convolutional layers found in {model_name} - skipping GradCAM")
        return
    
    print(f"Using layer: {last_conv_layer}")
    
    # Try alternative layers if the first one fails
    alternative_layers = []
    if 'vgg16' in last_conv_layer.lower():
        alternative_layers = ['block5_conv3', 'block5_conv2', 'block4_conv3']
    elif 'efficientnet' in model_name.lower():
        alternative_layers = ['top_activation', 'top_conv', 'block7a_expand_activation']
    elif 'mobilenet' in model_name.lower():
        alternative_layers = ['out_relu', 'Conv_1', 'block_16_depthwise']
    
    successful_layer = None
    test_heatmap = None
    
    # Test the primary layer
    test_gen.reset()
    test_images, test_labels = next(iter(test_gen))
    test_img = np.expand_dims(test_images[0], axis=0)
    
    test_heatmap = make_gradcam_heatmap(test_img, model, last_conv_layer, pred_index=0)
    if test_heatmap is not None:
        successful_layer = last_conv_layer
    else:
        # Try alternative layers
        for alt_layer in alternative_layers:
            try:
                test_heatmap = make_gradcam_heatmap(test_img, model, alt_layer, pred_index=0)
                if test_heatmap is not None:
                    successful_layer = alt_layer
                    print(f"Using alternative layer: {alt_layer}")
                    break
            except:
                continue
    
    if successful_layer is None:
        print(f"All GradCAM attempts failed for {model_name}")
        return
    
    # Plot GradCAM examples
    plt.figure(figsize=(20, 10))
    plt.suptitle(f'GradCAM Visualizations - {model_name} (Layer: {successful_layer})', 
                 fontsize=16, fontweight='bold')
    
    test_gen.reset()
    images, labels = next(iter(test_gen))
    
    for i in range(min(num_examples, len(images))):
        img_array = np.expand_dims(images[i], axis=0)
        
        # Make prediction
        preds = model.predict(img_array, verbose=0)
        pred_class = np.argmax(preds[0])
        true_class = np.argmax(labels[i])
        confidence = np.max(preds[0])
        
        # Generate heatmap
        heatmap = make_gradcam_heatmap(img_array, model, successful_layer, pred_class)
        
        # Plot original
        plt.subplot(2, num_examples, i + 1)
        plt.imshow(images[i])
        plt.title(f'Original\nTrue: {class_names[true_class]}', fontsize=10)
        plt.axis('off')
        
        # Plot GradCAM
        plt.subplot(2, num_examples, i + 1 + num_examples)
        plt.imshow(images[i])
        if heatmap is not None:
            # Resize heatmap to match image size
            heatmap_resized = cv2.resize(heatmap, (224, 224))
            plt.imshow(heatmap_resized, alpha=0.4, cmap='jet')
            status = "Success"
        else:
            status = "Failed"
        
        plt.title(f'GradCAM ({status})\nPred: {class_names[pred_class]}\nConf: {confidence:.3f}', 
                 fontsize=10)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

def debug_model_structure(model, model_name):
    """Debug function to understand model structure"""
    print(f"\n=== MODEL STRUCTURE DEBUG: {model_name} ===")
    
    def print_layers(layer_or_model, indent=0):
        prefix = "  " * indent
        if hasattr(layer_or_model, 'layers'):
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
            for i, layer in enumerate(layer_or_model.layers):
                print(f"{prefix}├─ [{i}] {layer.__class__.__name__}: {layer.name}")
                if hasattr(layer, 'layers') and len(layer.layers) > 0:
                    print_layers(layer, indent + 1)
        else:
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
    
    print_layers(model)
    print("=" * 50)

# Modified plotting function call in main training loop
def plot_gradcam_examples(model, test_gen, class_names, model_name, num_examples=4):
    """Wrapper function that includes debugging"""
    # Debug model structure first
    debug_model_structure(model, model_name)
    
    # Use the fixed GradCAM implementation
    plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples)

# Additional helper function to manually specify conv layer names
def get_manual_conv_layer_mapping():
    """Manual mapping for problematic models"""
    return {
        'EfficientNet-B0': ['efficientnetb0/block6a_expand_conv', 'efficientnetb0/top_conv'],
        'MobileNet-V2': ['mobilenetv2_1.00_224/block_16_depthwise', 'mobilenetv2_1.00_224/Conv_1'],
        'VGG16': ['vgg16/block5_conv3', 'vgg16/block5_conv2'],
        'DenseNet201': ['densenet201/conv5_block32_2_conv', 'densenet201/conv5_block32_concat'],
        'Eye Disease Classifier': ['vgg16/block5_conv3', 'multiscale_attention']
    }
# Enhanced visualization functions
def plot_clean_training_history(history, model_name):
    """Plot clean training history with 4-digit precision"""
    tr_acc = history.history['accuracy']
    tr_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    
    # Find best epochs
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    # Plot training history
    plt.figure(figsize=(15, 8))
    plt.style.use('fivethirtyeight')
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, label='Training loss', linewidth=2)
    plt.plot(Epochs, val_loss, label='Validation loss', linewidth=2)
    plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy', linewidth=2)
    plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy', linewidth=2)
    plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print best epoch information with 4-digit precision
    print(f"\n{model_name} Training Summary:")
    print(f"  Best Validation Loss: {val_lowest:.4f} at epoch {index_loss + 1}")
    print(f"  Best Validation Accuracy: {acc_highest:.4f} at epoch {index_acc + 1}")
    print(f"  Final Training Accuracy: {tr_acc[-1]:.4f}")
    print(f"  Final Validation Accuracy: {val_acc[-1]:.4f}")
    print(f"  Overfitting (Train-Val): {tr_acc[-1] - val_acc[-1]:.4f}")

def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    """Plot confusion matrix with 4-digit precision"""
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    plt.style.use('default')
    
    # Calculate percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    # Create combined annotations (count and percentage)
    annotations = []
    for i in range(cm.shape[0]):
        row = []
        for j in range(cm.shape[1]):
            row.append(f'{cm[i,j]}\n({cm_percent[i,j]:.4f})')
        annotations.append(row)
    
    sns.heatmap(cm, annot=annotations, fmt='', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title(f'Confusion Matrix - {model_name}\n(Count and Proportion)', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()
    
    return cm

def generate_classification_report_4digits(y_true, y_pred, class_names, model_name):
    """Generate detailed classification report with 4-digit precision"""
    report = classification_report(y_true, y_pred, target_names=class_names, 
                                 digits=4, output_dict=True)
    
    print(f"\n{'='*80}")
    print(f"CLASSIFICATION REPORT - {model_name}")
    print(f"{'='*80}")
    
    # Print header
    print(f"{'Class':<15} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}")
    print("-" * 80)
    
    # Print per-class metrics
    for class_name in class_names:
        metrics = report[class_name]
        print(f"{class_name:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print("-" * 80)
    
    # Print averages
    for avg_type in ['macro avg', 'weighted avg']:
        metrics = report[avg_type]
        print(f"{avg_type:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print(f"\nAccuracy: {report['accuracy']:.4f}")
    print(f"{'='*80}")
    
    return report

def compile_and_train_model(model, model_name, train_gen, valid_gen, epochs=40):
    """Compile and train model with fixed callbacks (no ReduceLROnPlateau)"""
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    # Use fixed learning rate instead of schedule to avoid callback conflicts
    if 'Eye Disease' in model_name or 'ViT' in model_name:
        optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-4)
    else:
        optimizer = keras.optimizers.Adam(learning_rate=1e-4)
    
    # Compile the model
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top_2_accuracy')]
    )
    
    # Simple callbacks without ReduceLROnPlateau to avoid conflicts
    callbacks = [
        EarlyStopping(
            monitor='val_accuracy',
            patience=10,  # Increased patience since we removed ReduceLROnPlateau
            restore_best_weights=True,
            verbose=1
        )
    ]
    
    # Train model
    history = model.fit(
        train_gen,
        validation_data=valid_gen,
        epochs=40,
        verbose=1
    )
    
    # Plot individual training history
    plot_clean_training_history(history, model_name)
    
    return model, history

def measure_inference_time(model, test_gen, num_batches=10):
    """Measure inference time"""
    times = []
    
    for i, (x_batch, y_batch) in enumerate(test_gen):
        if i >= num_batches:
            break
        
        start_time = time.time()
        _ = model.predict(x_batch, verbose=0)
        end_time = time.time()
        
        times.append(end_time - start_time)
    
    avg_time_per_batch = np.mean(times)
    avg_time_per_image = avg_time_per_batch / batch_size
    
    return avg_time_per_batch, avg_time_per_image

def plot_combined_training_histories(histories):
    """Combined training histories visualization"""
    plt.figure(figsize=(20, 12))
    plt.style.use('fivethirtyeight')
    
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FECA57', '#FF9FF3']
    
    # Training Loss
    plt.subplot(2, 2, 1)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['loss']))]
        plt.plot(epochs, history.history['loss'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Loss
    plt.subplot(2, 2, 2)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_loss']))]
        val_loss = history.history['val_loss']
        plt.plot(epochs, val_loss, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmin(val_loss) + 1
        best_loss = min(val_loss)
        plt.scatter(best_epoch, best_loss, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Training Accuracy
    plt.subplot(2, 2, 3)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['accuracy']))]
        plt.plot(epochs, history.history['accuracy'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Accuracy
    plt.subplot(2, 2, 4)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_accuracy']))]
        val_acc = history.history['val_accuracy']
        plt.plot(epochs, val_acc, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmax(val_acc) + 1
        best_acc = max(val_acc)
        plt.scatter(best_epoch, best_acc, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_comprehensive_results(results):
    """Comprehensive results visualization with 4-digit precision"""
    fig, axes = plt.subplots(3, 3, figsize=(20, 18))
    plt.style.use('default')
    
    models = list(results.keys())
    colors = plt.cm.Set3(np.linspace(0, 1, len(models)))
    
    # Test Accuracy Comparison
    test_accs = [results[model]['test_accuracy'] for model in models]
    bars1 = axes[0, 0].bar(models, test_accs, color=colors)
    axes[0, 0].set_title('Test Accuracy Comparison', fontsize=14, fontweight='bold')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].set_ylim(0, 1)
    axes[0, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(test_accs):
        axes[0, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Parameters vs Accuracy
    params = [results[model]['parameters'] / 1e6 for model in models]
    scatter = axes[0, 1].scatter(params, test_accs, s=150, c=colors, alpha=0.7)
    axes[0, 1].set_title('Parameters vs Test Accuracy', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Parameters (Millions)')
    axes[0, 1].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[0, 1].annotate(model, (params[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Inference Time Comparison
    inf_times = [results[model]['inference_time_per_image'] * 1000 for model in models]
    bars2 = axes[0, 2].bar(models, inf_times, color=colors)
    axes[0, 2].set_title('Inference Time per Image', fontsize=14, fontweight='bold')
    axes[0, 2].set_ylabel('Time (ms)')
    axes[0, 2].tick_params(axis='x', rotation=45)
    for i, v in enumerate(inf_times):
        axes[0, 2].text(i, v + max(inf_times)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # F1-Score Comparison
    f1_scores = [results[model]['f1_macro'] for model in models]
    bars3 = axes[1, 0].bar(models, f1_scores, color=colors)
    axes[1, 0].set_title('F1-Score (Macro Average)', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('F1-Score')
    axes[1, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(f1_scores):
        axes[1, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Mean Average Precision
    mean_aps = [results[model]['mean_ap'] for model in models]
    bars4 = axes[1, 1].bar(models, mean_aps, color=colors)
    axes[1, 1].set_title('Mean Average Precision', fontsize=14, fontweight='bold')
    axes[1, 1].set_ylabel('mAP')
    axes[1, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(mean_aps):
        axes[1, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Precision vs Recall
    precisions = [results[model]['precision_macro'] for model in models]
    recalls = [results[model]['recall_macro'] for model in models]
    scatter = axes[1, 2].scatter(recalls, precisions, s=150, c=colors, alpha=0.7)
    axes[1, 2].set_title('Precision vs Recall', fontsize=14, fontweight='bold')
    axes[1, 2].set_xlabel('Recall (Macro)')
    axes[1, 2].set_ylabel('Precision (Macro)')
    for i, model in enumerate(models):
        axes[1, 2].annotate(model, (recalls[i], precisions[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Efficiency Score (Accuracy / Parameters)
    efficiency = [results[model]['test_accuracy'] / (results[model]['parameters'] / 1e6) for model in models]
    bars5 = axes[2, 0].bar(models, efficiency, color=colors)
    axes[2, 0].set_title('Efficiency Score (Acc/Params)', fontsize=14, fontweight='bold')
    axes[2, 0].set_ylabel('Efficiency Score')
    axes[2, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(efficiency):
        axes[2, 0].text(i, v + max(efficiency)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Top-2 Accuracy
    top2_accs = [results[model]['test_top2_accuracy'] for model in models]
    bars6 = axes[2, 1].bar(models, top2_accs, color=colors)
    axes[2, 1].set_title('Top-2 Accuracy', fontsize=14, fontweight='bold')
    axes[2, 1].set_ylabel('Top-2 Accuracy')
    axes[2, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(top2_accs):
        axes[2, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Speed vs Accuracy Trade-off
    axes[2, 2].scatter(inf_times, test_accs, s=150, c=colors, alpha=0.7)
    axes[2, 2].set_title('Speed vs Accuracy Trade-off', fontsize=14, fontweight='bold')
    axes[2, 2].set_xlabel('Inference Time (ms)')
    axes[2, 2].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[2, 2].annotate(model, (inf_times[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    plt.tight_layout()
    plt.show()

# Main execution: Train models one by one, with Eye Disease Classifier at the end
print("\n" + "="*80)
print("SEQUENTIAL MODEL TRAINING - EYE DISEASE CLASSIFICATION")
print("="*80)

# Define models in order (Eye Disease Classifier will be trained last)
models_to_train = [
    ('EfficientNet-B0', create_efficientnet),
    ('MobileNet-V2', create_mobilenet_v2), 
    ('VGG16', create_vgg16),
    ('DenseNet201', create_denseNet201),
    ('ViT Small', create_vit_small),
    ('Eye Disease Classifier', create_eye_disease_classifier)  # Your custom model last
]

# Store results
results = {}
histories = {}
trained_models = {}

# Train each model sequentially
for model_name, model_creator in models_to_train:
    print(f"\n{'='*60}")
    print(f"CREATING AND TRAINING: {model_name}")
    print(f"{'='*60}")
    
    # Create the model
    model = model_creator(num_classes)
    
    # Build the model using a real batch from train_gen if not built
    if not model.built:
        x_batch, y_batch = next(iter(train_gen))
        _ = model(x_batch)
    
    print(f"Parameters: {model.count_params():,}")
    
    # Reset generators before training
    train_gen.reset()
    valid_gen.reset()
    
    # Train model
    trained_model, history = compile_and_train_model(
        model, model_name, train_gen, valid_gen, epochs=30
    )
    
    # Store trained model and history
    trained_models[model_name] = trained_model
    histories[model_name] = history
    
    # Evaluate on test set
    test_gen.reset()
    test_loss, test_acc, test_top2_acc = trained_model.evaluate(test_gen, verbose=0)
    
    # Get predictions for confusion matrix and classification report
    test_gen.reset()
    y_pred_probs = trained_model.predict(test_gen, verbose=0)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)
    
    # Get true labels
    y_true = test_gen.classes
    
    # Measure inference time
    test_gen.reset()
    avg_batch_time, avg_image_time = measure_inference_time(trained_model, test_gen)
    
    # Plot confusion matrix with 4-digit precision
    cm = plot_confusion_matrix(y_true, y_pred_classes, class_names, model_name)
    
    # Generate classification report with 4-digit precision
    class_report = generate_classification_report_4digits(
        y_true, y_pred_classes, class_names, model_name
    )
    
    # Plot GradCAM examples (for CNN-based models)
    if any(keyword in model_name for keyword in ['Eye Disease', 'EfficientNet', 'MobileNet', 'VGG', 'DenseNet201', 'MobileNet_v2']):
        #plot_gradcam_examples(trained_model, test_gen, class_names, model_name)
        pass
    
    # Calculate precision-recall curves
    y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes)
    
    # Calculate mean AP with 4-digit precision
    mean_ap = np.mean([average_precision_score(y_true_onehot[:, i], y_pred_probs[:, i]) 
                      for i in range(len(class_names))])
    
    # Store results with 4-digit precision
    results[model_name] = {
        'test_accuracy': round(test_acc, 4),
        'test_top2_accuracy': round(test_top2_acc, 4),
        'test_loss': round(test_loss, 4),
        'parameters': model.count_params(),
        'best_val_accuracy': round(max(history.history['val_accuracy']), 4),
        'mean_ap': round(mean_ap, 4),
        'precision_macro': round(class_report['macro avg']['precision'], 4),
        'recall_macro': round(class_report['macro avg']['recall'], 4),
        'f1_macro': round(class_report['macro avg']['f1-score'], 4),
        'inference_time_per_image': round(avg_image_time, 6),
        'inference_time_per_batch': round(avg_batch_time, 4)
    }
    
    print(f"\n{'='*50}")
    print(f"TEST RESULTS FOR {model_name}:")
    print(f"{'='*50}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Test Top-2 Accuracy: {test_top2_acc:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Mean AP: {mean_ap:.4f}")
    print(f"F1-Score (Macro): {class_report['macro avg']['f1-score']:.4f}")
    print(f"Precision (Macro): {class_report['macro avg']['precision']:.4f}")
    print(f"Recall (Macro): {class_report['macro avg']['recall']:.4f}")
    print(f"Inference time per image: {avg_image_time*1000:.4f} ms")
    print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
    print(f"Parameters: {model.count_params():,}")
    
    # Clean up to save memory (optional)
    if model_name != 'Eye Disease Classifier':  # Keep your custom model
        del model

# Combined visualizations after all models are trained
print(f"\n{'='*80}")
print("COMBINED TRAINING HISTORIES VISUALIZATION")
print(f"{'='*80}")
plot_combined_training_histories(histories)

# Comprehensive results visualization
print(f"\n{'='*80}")
print("COMPREHENSIVE RESULTS VISUALIZATION")
print(f"{'='*80}")
plot_comprehensive_results(results)

# Print final detailed comparison with 4-digit precision
print("\n" + "="*130)
print("COMPREHENSIVE RESULTS COMPARISON (4-DIGIT PRECISION)")
print("="*130)

results_df = pd.DataFrame(results).T
results_df = results_df.sort_values('test_accuracy', ascending=False)

print(f"{'Model':<20} {'Test Acc':<10} {'Top-2 Acc':<10} {'mAP':<10} {'F1':<10} {'Precision':<10} {'Recall':<10} {'Params(M)':<12} {'Time(ms)':<12}")
print("-" * 130)

for model_name, row in results_df.iterrows():
    print(f"{model_name:<20} "
          f"{row['test_accuracy']:<10.4f} "
          f"{row['test_top2_accuracy']:<10.4f} "
          f"{row['mean_ap']:<10.4f} "
          f"{row['f1_macro']:<10.4f} "
          f"{row['precision_macro']:<10.4f} "
          f"{row['recall_macro']:<10.4f} "
          f"{row['parameters']/1e6:<12.2f} "
          f"{row['inference_time_per_image']*1000:<12.4f}")

# Final analysis and recommendations
print("\n" + "="*130)
print("FINAL ANALYSIS AND RECOMMENDATIONS")
print("="*130)

best_model = results_df.index[0]
efficiency_scores = results_df['test_accuracy'] / (results_df['parameters'] / 1e6)
most_efficient = efficiency_scores.idxmax()
fastest = results_df['inference_time_per_image'].idxmin()

print(f"🏆 BEST OVERALL PERFORMANCE: {best_model}")
print(f"   → Test Accuracy: {results_df.loc[best_model, 'test_accuracy']:.4f}")
print(f"   → F1-Score: {results_df.loc[best_model, 'f1_macro']:.4f}")
print(f"   → mAP: {results_df.loc[best_model, 'mean_ap']:.4f}")
print(f"   → Parameters: {results_df.loc[best_model, 'parameters']/1e6:.2f}M")

print(f"\n⚡ MOST EFFICIENT: {most_efficient}")
print(f"   → Efficiency Score: {efficiency_scores[most_efficient]:.4f}")
print(f"   → Test Accuracy: {results_df.loc[most_efficient, 'test_accuracy']:.4f}")
print(f"   → Parameters: {results_df.loc[most_efficient, 'parameters']/1e6:.2f}M")

print(f"\n🚀 FASTEST INFERENCE: {fastest}")
print(f"   → Inference Time: {results_df.loc[fastest, 'inference_time_per_image']*1000:.4f} ms")
print(f"   → Test Accuracy: {results_df.loc[fastest, 'test_accuracy']:.4f}")
print(f"   → FPS: {1/results_df.loc[fastest, 'inference_time_per_image']:.1f}")

# Eye Disease Classifier specific analysis
if 'Eye Disease Classifier' in results_df.index:
    eye_model_results = results_df.loc['Eye Disease Classifier']
    print(f"\n🔬 YOUR EYE DISEASE CLASSIFIER ANALYSIS:")
    print(f"   → Test Accuracy: {eye_model_results['test_accuracy']:.4f}")
    print(f"   → F1-Score: {eye_model_results['f1_macro']:.4f}")
    print(f"   → Mean AP: {eye_model_results['mean_ap']:.4f}")
    print(f"   → Efficiency: {efficiency_scores['Eye Disease Classifier']:.4f}")
    print(f"   → Inference Time: {eye_model_results['inference_time_per_image']*1000:.4f} ms")
    print(f"   → Rank by Accuracy: {list(results_df.index).index('Eye Disease Classifier') + 1}/{len(results_df)}")

# Save comprehensive results
results_df.to_csv('eye_disease_comprehensive_results.csv')
print(f"\n📊 Results saved to: eye_disease_comprehensive_results.csv")
print(f"\n{'='*130}")
print("ANALYSIS COMPLETE - ALL MODELS TRAINED SEQUENTIALLY")
print(f"{'='*130}")
# Out:
# Class distribution:
# labels
# diabetic_retinopathy    1098
# normal                  1074
# cataract                1038
# glaucoma                1007
# Name: count, dtype: int64
# Number of unique classes: 4
# Train samples: 3373
# Valid samples: 506
# Test samples: 338
# Found 3373 validated image filenames belonging to 4 classes.
# Found 506 validated image filenames belonging to 4 classes.
# Found 338 validated image filenames belonging to 4 classes.
# Classes: ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
#
# ================================================================================
# SEQUENTIAL MODEL TRAINING - EYE DISEASE CLASSIFICATION
# ================================================================================
#
# ============================================================
# CREATING AND TRAINING: EfficientNet-B0
# ============================================================
# Parameters: 4,054,695
#
# ==================================================
# Training EfficientNet-B0
# ==================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 145s 583ms/step - accuracy: 0.6509 - loss: 0.8738 - top_2_accuracy: 0.8431 - val_accuracy: 0.2411 - val_loss: 1.4807 - val_top_2_accuracy: 0.4664
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.8934 - loss: 0.2982 - top_2_accuracy: 0.9808 - val_accuracy: 0.2411 - val_loss: 1.4718 - val_top_2_accuracy: 0.5929
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9172 - loss: 0.2282 - top_2_accuracy: 0.9880 - val_accuracy: 0.3597 - val_loss: 1.6153 - val_top_2_accuracy: 0.4842
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9574 - loss: 0.1343 - top_2_accuracy: 0.9969 - val_accuracy: 0.3794 - val_loss: 1.8114 - val_top_2_accuracy: 0.4802
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9543 - loss: 0.1412 - top_2_accuracy: 0.9951 - val_accuracy: 0.3202 - val_loss: 1.7046 - val_top_2_accuracy: 0.4901
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9728 - loss: 0.0882 - top_2_accuracy: 0.9987 - val_accuracy: 0.3715 - val_loss: 1.8344 - val_top_2_accuracy: 0.4802
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 249ms/step - accuracy: 0.9840 - loss: 0.0548 - top_2_accuracy: 0.9985 - val_accuracy: 0.2451 - val_loss: 1.6690 - val_top_2_accuracy: 0.4269
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9862 - loss: 0.0452 - top_2_accuracy: 0.9990 - val_accuracy: 0.2925 - val_loss: 96.1374 - val_top_2_accuracy: 0.6877
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9844 - loss: 0.0416 - top_2_accuracy: 1.0000 - val_accuracy: 0.4407 - val_loss: 1.8495 - val_top_2_accuracy: 0.5968
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9873 - loss: 0.0434 - top_2_accuracy: 0.9982 - val_accuracy: 0.1996 - val_loss: 978.5771 - val_top_2_accuracy: 0.8755
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9909 - loss: 0.0304 - top_2_accuracy: 0.9986 - val_accuracy: 0.2352 - val_loss: 1.8838 - val_top_2_accuracy: 0.5237
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9954 - loss: 0.0154 - top_2_accuracy: 0.9999 - val_accuracy: 0.3182 - val_loss: 1.9932 - val_top_2_accuracy: 0.4921
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9907 - loss: 0.0223 - top_2_accuracy: 0.9983 - val_accuracy: 0.2490 - val_loss: 109.7873 - val_top_2_accuracy: 0.6265
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9949 - loss: 0.0169 - top_2_accuracy: 0.9998 - val_accuracy: 0.2372 - val_loss: 15612.7773 - val_top_2_accuracy: 0.9901
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9897 - loss: 0.0349 - top_2_accuracy: 0.9998 - val_accuracy: 0.5573 - val_loss: 1.8900 - val_top_2_accuracy: 0.7213
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9932 - loss: 0.0215 - top_2_accuracy: 1.0000 - val_accuracy: 0.3893 - val_loss: 1.9454 - val_top_2_accuracy: 0.5672
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9930 - loss: 0.0207 - top_2_accuracy: 0.9993 - val_accuracy: 0.3320 - val_loss: 2.7094 - val_top_2_accuracy: 0.5059
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9963 - loss: 0.0140 - top_2_accuracy: 1.0000 - val_accuracy: 0.4269 - val_loss: 2.1850 - val_top_2_accuracy: 0.5059
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9929 - loss: 0.0184 - top_2_accuracy: 0.9998 - val_accuracy: 0.2589 - val_loss: 2.1335 - val_top_2_accuracy: 0.5435
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9971 - loss: 0.0108 - top_2_accuracy: 1.0000 - val_accuracy: 0.3518 - val_loss: 2.2790 - val_top_2_accuracy: 0.5257
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9955 - loss: 0.0135 - top_2_accuracy: 0.9998 - val_accuracy: 0.3419 - val_loss: 2.3525 - val_top_2_accuracy: 0.6285
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9974 - loss: 0.0105 - top_2_accuracy: 1.0000 - val_accuracy: 0.4783 - val_loss: 1.8692 - val_top_2_accuracy: 0.6364
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9953 - loss: 0.0169 - top_2_accuracy: 0.9999 - val_accuracy: 0.2806 - val_loss: 42.5665 - val_top_2_accuracy: 0.5316
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9937 - loss: 0.0180 - top_2_accuracy: 1.0000 - val_accuracy: 0.3221 - val_loss: 2.7159 - val_top_2_accuracy: 0.6403
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 240ms/step - accuracy: 0.9906 - loss: 0.0219 - top_2_accuracy: 0.9995 - val_accuracy: 0.2569 - val_loss: 1094.3881 - val_top_2_accuracy: 0.9565
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9966 - loss: 0.0134 - top_2_accuracy: 0.9995 - val_accuracy: 0.5178 - val_loss: 1.7062 - val_top_2_accuracy: 0.6996
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9949 - loss: 0.0130 - top_2_accuracy: 0.9988 - val_accuracy: 0.5632 - val_loss: 1.2685 - val_top_2_accuracy: 0.6897
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9959 - loss: 0.0134 - top_2_accuracy: 1.0000 - val_accuracy: 0.3854 - val_loss: 1.8953 - val_top_2_accuracy: 0.5435
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9967 - loss: 0.0088 - top_2_accuracy: 1.0000 - val_accuracy: 0.5217 - val_loss: 1.5774 - val_top_2_accuracy: 0.7174
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9961 - loss: 0.0105 - top_2_accuracy: 1.0000 - val_accuracy: 0.1957 - val_loss: 1.9402 - val_top_2_accuracy: 0.4545
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.9969 - loss: 0.0077 - top_2_accuracy: 0.9996 - val_accuracy: 0.4130 - val_loss: 1.6550 - val_top_2_accuracy: 0.6739
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9944 - loss: 0.0209 - top_2_accuracy: 1.0000 - val_accuracy: 0.2628 - val_loss: 5132.9360 - val_top_2_accuracy: 0.9901
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9978 - loss: 0.0065 - top_2_accuracy: 1.0000 - val_accuracy: 0.2194 - val_loss: 15.5911 - val_top_2_accuracy: 0.4664
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9983 - loss: 0.0079 - top_2_accuracy: 1.0000 - val_accuracy: 0.6364 - val_loss: 1.2381 - val_top_2_accuracy: 0.7826
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9981 - loss: 0.0048 - top_2_accuracy: 0.9997 - val_accuracy: 0.3241 - val_loss: 45.5244 - val_top_2_accuracy: 0.6206
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9979 - loss: 0.0073 - top_2_accuracy: 1.0000 - val_accuracy: 0.4802 - val_loss: 2.6911 - val_top_2_accuracy: 0.5613
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9987 - loss: 0.0058 - top_2_accuracy: 1.0000 - val_accuracy: 0.4032 - val_loss: 2.0799 - val_top_2_accuracy: 0.5099
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9964 - loss: 0.0094 - top_2_accuracy: 1.0000 - val_accuracy: 0.3557 - val_loss: 1.7671 - val_top_2_accuracy: 0.5119
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9964 - loss: 0.0113 - top_2_accuracy: 1.0000 - val_accuracy: 0.5158 - val_loss: 2.5176 - val_top_2_accuracy: 0.6206
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9990 - loss: 0.0045 - top_2_accuracy: 1.0000 - val_accuracy: 0.2569 - val_loss: 632.0521 - val_top_2_accuracy: 0.8617
# EfficientNet-B0 Training Summary:
#   Best Validation Loss: 1.2381 at epoch 34
#   Best Validation Accuracy: 0.6364 at epoch 34
#   Final Training Accuracy: 0.9982
#   Final Validation Accuracy: 0.2569
#   Overfitting (Train-Val): 0.7413
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ================================================================================
# CLASSIFICATION REPORT - EfficientNet-B0
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.3846       0.1333       0.1980       75
# diabetic_retinopathy 0.2442       0.2530       0.2485       83
# glaucoma        0.2925       0.4831       0.3644       89
# normal          0.3038       0.2637       0.2824       91
# --------------------------------------------------------------------------------
# macro avg       0.3063       0.2833       0.2733       338
# weighted avg    0.3041       0.2899       0.2769       338
#
# Accuracy: 0.2899
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR EfficientNet-B0:
# ==================================================
# Test Accuracy: 0.2899
# Test Top-2 Accuracy: 0.8964
# Test Loss: 619.4717
# Mean AP: 0.2685
# F1-Score (Macro): 0.2733
# Precision (Macro): 0.3063
# Recall (Macro): 0.2833
# Inference time per image: 26.5135 ms
# Best Validation Accuracy: 0.6364
# Parameters: 4,054,695
#
# ============================================================
# CREATING AND TRAINING: MobileNet-V2
# ============================================================
# Parameters: 2,263,108
#
# ==================================================
# Training MobileNet-V2
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 96s 419ms/step - accuracy: 0.6934 - loss: 0.7836 - top_2_accuracy: 0.8535 - val_accuracy: 0.4842 - val_loss: 1.5721 - val_top_2_accuracy: 0.8043
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - accuracy: 0.9364 - loss: 0.1819 - top_2_accuracy: 0.9886 - val_accuracy: 0.6047 - val_loss: 1.2491 - val_top_2_accuracy: 0.8103
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9695 - loss: 0.0994 - top_2_accuracy: 0.9976 - val_accuracy: 0.5257 - val_loss: 2.2330 - val_top_2_accuracy: 0.7905
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.9840 - loss: 0.0529 - top_2_accuracy: 0.9995 - val_accuracy: 0.5356 - val_loss: 2.0830 - val_top_2_accuracy: 0.8320
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9932 - loss: 0.0262 - top_2_accuracy: 0.9999 - val_accuracy: 0.5731 - val_loss: 2.4490 - val_top_2_accuracy: 0.7727
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9903 - loss: 0.0320 - top_2_accuracy: 0.9995 - val_accuracy: 0.5336 - val_loss: 2.3811 - val_top_2_accuracy: 0.8241
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.9912 - loss: 0.0228 - top_2_accuracy: 1.0000 - val_accuracy: 0.5909 - val_loss: 2.0205 - val_top_2_accuracy: 0.7846
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.9942 - loss: 0.0200 - top_2_accuracy: 1.0000 - val_accuracy: 0.5771 - val_loss: 1.9163 - val_top_2_accuracy: 0.8656
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.9955 - loss: 0.0150 - top_2_accuracy: 1.0000 - val_accuracy: 0.6225 - val_loss: 1.8706 - val_top_2_accuracy: 0.7964
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9924 - loss: 0.0190 - top_2_accuracy: 0.9996 - val_accuracy: 0.6700 - val_loss: 1.8873 - val_top_2_accuracy: 0.8004
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.9959 - loss: 0.0134 - top_2_accuracy: 1.0000 - val_accuracy: 0.6660 - val_loss: 1.5854 - val_top_2_accuracy: 0.8735
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9969 - loss: 0.0171 - top_2_accuracy: 0.9998 - val_accuracy: 0.6976 - val_loss: 1.7559 - val_top_2_accuracy: 0.8439
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9966 - loss: 0.0144 - top_2_accuracy: 1.0000 - val_accuracy: 0.7253 - val_loss: 1.4493 - val_top_2_accuracy: 0.8814
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9957 - loss: 0.0156 - top_2_accuracy: 0.9999 - val_accuracy: 0.7747 - val_loss: 1.1692 - val_top_2_accuracy: 0.8972
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9952 - loss: 0.0186 - top_2_accuracy: 0.9997 - val_accuracy: 0.7411 - val_loss: 1.5035 - val_top_2_accuracy: 0.8696
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 232ms/step - accuracy: 0.9923 - loss: 0.0243 - top_2_accuracy: 0.9997 - val_accuracy: 0.8024 - val_loss: 1.0805 - val_top_2_accuracy: 0.8972
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.9925 - loss: 0.0202 - top_2_accuracy: 1.0000 - val_accuracy: 0.7312 - val_loss: 2.2516 - val_top_2_accuracy: 0.7964
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 231ms/step - accuracy: 0.9925 - loss: 0.0254 - top_2_accuracy: 1.0000 - val_accuracy: 0.7688 - val_loss: 1.3212 - val_top_2_accuracy: 0.9051
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.9974 - loss: 0.0094 - top_2_accuracy: 1.0000 - val_accuracy: 0.7787 - val_loss: 1.4602 - val_top_2_accuracy: 0.8953
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9979 - loss: 0.0062 - top_2_accuracy: 1.0000 - val_accuracy: 0.7964 - val_loss: 1.3369 - val_top_2_accuracy: 0.9051
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9965 - loss: 0.0098 - top_2_accuracy: 1.0000 - val_accuracy: 0.7490 - val_loss: 1.7334 - val_top_2_accuracy: 0.8636
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9981 - loss: 0.0044 - top_2_accuracy: 1.0000 - val_accuracy: 0.7984 - val_loss: 1.2316 - val_top_2_accuracy: 0.9229
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.9993 - loss: 0.0036 - top_2_accuracy: 1.0000 - val_accuracy: 0.8182 - val_loss: 0.9465 - val_top_2_accuracy: 0.9368
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.9991 - loss: 0.0020 - top_2_accuracy: 1.0000 - val_accuracy: 0.8458 - val_loss: 0.8285 - val_top_2_accuracy: 0.9486
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9995 - loss: 0.0013 - top_2_accuracy: 1.0000 - val_accuracy: 0.8458 - val_loss: 0.8093 - val_top_2_accuracy: 0.9605
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 1.0000 - loss: 6.4464e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8439 - val_loss: 0.8043 - val_top_2_accuracy: 0.9664
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9986 - loss: 0.0048 - top_2_accuracy: 1.0000 - val_accuracy: 0.8162 - val_loss: 1.0570 - val_top_2_accuracy: 0.9190
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9931 - loss: 0.0208 - top_2_accuracy: 0.9997 - val_accuracy: 0.8597 - val_loss: 0.5891 - val_top_2_accuracy: 0.9585
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9876 - loss: 0.0287 - top_2_accuracy: 0.9996 - val_accuracy: 0.8281 - val_loss: 0.8609 - val_top_2_accuracy: 0.9585
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9892 - loss: 0.0312 - top_2_accuracy: 0.9992 - val_accuracy: 0.8775 - val_loss: 0.6599 - val_top_2_accuracy: 0.9684
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9985 - loss: 0.0081 - top_2_accuracy: 1.0000 - val_accuracy: 0.8399 - val_loss: 0.9249 - val_top_2_accuracy: 0.9387
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9966 - loss: 0.0131 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.5754 - val_top_2_accuracy: 0.9842
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9958 - loss: 0.0110 - top_2_accuracy: 1.0000 - val_accuracy: 0.9012 - val_loss: 0.5106 - val_top_2_accuracy: 0.9822
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.9969 - loss: 0.0085 - top_2_accuracy: 0.9990 - val_accuracy: 0.8953 - val_loss: 0.6014 - val_top_2_accuracy: 0.9822
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9996 - loss: 0.0034 - top_2_accuracy: 1.0000 - val_accuracy: 0.8834 - val_loss: 0.6308 - val_top_2_accuracy: 0.9881
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9996 - loss: 0.0021 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.5829 - val_top_2_accuracy: 0.9763
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9957 - loss: 0.0185 - top_2_accuracy: 0.9996 - val_accuracy: 0.9071 - val_loss: 0.5513 - val_top_2_accuracy: 0.9862
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9958 - loss: 0.0103 - top_2_accuracy: 0.9997 - val_accuracy: 0.9012 - val_loss: 0.6377 - val_top_2_accuracy: 0.9723
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9979 - loss: 0.0051 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.6227 - val_top_2_accuracy: 0.9802
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9960 - loss: 0.0148 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.4896 - val_top_2_accuracy: 0.9783
# MobileNet-V2 Training Summary:
#   Best Validation Loss: 0.4896 at epoch 40
#   Best Validation Accuracy: 0.9071 at epoch 37
#   Final Training Accuracy: 0.9953
#   Final Validation Accuracy: 0.8972
#   Overfitting (Train-Val): 0.0980
# ================================================================================
# CLASSIFICATION REPORT - MobileNet-V2
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.8706       0.9867       0.9250       75
# diabetic_retinopathy 0.9881       1.0000       0.9940       83
# glaucoma        0.9250       0.8315       0.8757       89
# normal          0.9213       0.9011       0.9111       91
# --------------------------------------------------------------------------------
# macro avg       0.9263       0.9298       0.9265       338
# weighted avg    0.9274       0.9260       0.9252       338
#
# Accuracy: 0.9260
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR MobileNet-V2:
# ==================================================
# Test Accuracy: 0.9260
# Test Top-2 Accuracy: 0.9941
# Test Loss: 0.2753
# Mean AP: 0.9792
# F1-Score (Macro): 0.9265
# Precision (Macro): 0.9263
# Recall (Macro): 0.9298
# Inference time per image: 12.6223 ms
# Best Validation Accuracy: 0.9071
# Parameters: 2,263,108
#
# ============================================================
# CREATING AND TRAINING: VGG16
# ============================================================
# Parameters: 14,716,740
#
# ==================================================
# Training VGG16
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 43s 310ms/step - accuracy: 0.6031 - loss: 0.9457 - top_2_accuracy: 0.7794 - val_accuracy: 0.8103 - val_loss: 0.5088 - val_top_2_accuracy: 0.9605
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 277ms/step - accuracy: 0.8674 - loss: 0.3520 - top_2_accuracy: 0.9702 - val_accuracy: 0.8715 - val_loss: 0.3526 - val_top_2_accuracy: 0.9842
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 285ms/step - accuracy: 0.8949 - loss: 0.2891 - top_2_accuracy: 0.9779 - val_accuracy: 0.8577 - val_loss: 0.3929 - val_top_2_accuracy: 0.9802
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 279ms/step - accuracy: 0.8989 - loss: 0.2741 - top_2_accuracy: 0.9869 - val_accuracy: 0.8617 - val_loss: 0.3562 - val_top_2_accuracy: 0.9802
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.9216 - loss: 0.2248 - top_2_accuracy: 0.9934 - val_accuracy: 0.8854 - val_loss: 0.2873 - val_top_2_accuracy: 0.9783
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 267ms/step - accuracy: 0.9281 - loss: 0.2132 - top_2_accuracy: 0.9923 - val_accuracy: 0.8735 - val_loss: 0.3039 - val_top_2_accuracy: 0.9862
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 281ms/step - accuracy: 0.9429 - loss: 0.1578 - top_2_accuracy: 0.9949 - val_accuracy: 0.8775 - val_loss: 0.3023 - val_top_2_accuracy: 0.9802
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 278ms/step - accuracy: 0.9443 - loss: 0.1557 - top_2_accuracy: 0.9951 - val_accuracy: 0.8755 - val_loss: 0.3958 - val_top_2_accuracy: 0.9743
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 273ms/step - accuracy: 0.9429 - loss: 0.1555 - top_2_accuracy: 0.9961 - val_accuracy: 0.8794 - val_loss: 0.3360 - val_top_2_accuracy: 0.9881
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 278ms/step - accuracy: 0.9600 - loss: 0.1164 - top_2_accuracy: 0.9954 - val_accuracy: 0.8755 - val_loss: 0.3569 - val_top_2_accuracy: 0.9802
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 280ms/step - accuracy: 0.9633 - loss: 0.1128 - top_2_accuracy: 0.9964 - val_accuracy: 0.8854 - val_loss: 0.2607 - val_top_2_accuracy: 0.9822
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 276ms/step - accuracy: 0.9740 - loss: 0.0785 - top_2_accuracy: 0.9968 - val_accuracy: 0.8933 - val_loss: 0.3189 - val_top_2_accuracy: 0.9921
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 278ms/step - accuracy: 0.9808 - loss: 0.0599 - top_2_accuracy: 0.9992 - val_accuracy: 0.8735 - val_loss: 0.4103 - val_top_2_accuracy: 0.9901
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 275ms/step - accuracy: 0.9826 - loss: 0.0606 - top_2_accuracy: 0.9995 - val_accuracy: 0.8913 - val_loss: 0.3291 - val_top_2_accuracy: 0.9901
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 280ms/step - accuracy: 0.9846 - loss: 0.0538 - top_2_accuracy: 0.9973 - val_accuracy: 0.8775 - val_loss: 0.4503 - val_top_2_accuracy: 0.9862
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9808 - loss: 0.0573 - top_2_accuracy: 0.9975 - val_accuracy: 0.8913 - val_loss: 0.3765 - val_top_2_accuracy: 0.9862
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 273ms/step - accuracy: 0.9810 - loss: 0.0652 - top_2_accuracy: 0.9995 - val_accuracy: 0.8953 - val_loss: 0.3385 - val_top_2_accuracy: 0.9901
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 279ms/step - accuracy: 0.9871 - loss: 0.0398 - top_2_accuracy: 0.9982 - val_accuracy: 0.8794 - val_loss: 0.4204 - val_top_2_accuracy: 0.9842
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 275ms/step - accuracy: 0.9939 - loss: 0.0263 - top_2_accuracy: 0.9980 - val_accuracy: 0.8953 - val_loss: 0.3541 - val_top_2_accuracy: 0.9901
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 276ms/step - accuracy: 0.9833 - loss: 0.0541 - top_2_accuracy: 0.9987 - val_accuracy: 0.8775 - val_loss: 0.4692 - val_top_2_accuracy: 0.9881
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 269ms/step - accuracy: 0.9834 - loss: 0.0482 - top_2_accuracy: 0.9975 - val_accuracy: 0.8972 - val_loss: 0.4557 - val_top_2_accuracy: 0.9881
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 275ms/step - accuracy: 0.9961 - loss: 0.0196 - top_2_accuracy: 0.9995 - val_accuracy: 0.8893 - val_loss: 0.4577 - val_top_2_accuracy: 0.9901
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 273ms/step - accuracy: 0.9914 - loss: 0.0287 - top_2_accuracy: 0.9991 - val_accuracy: 0.8636 - val_loss: 0.5915 - val_top_2_accuracy: 0.9901
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 272ms/step - accuracy: 0.9865 - loss: 0.0446 - top_2_accuracy: 0.9994 - val_accuracy: 0.8834 - val_loss: 0.4231 - val_top_2_accuracy: 0.9901
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 275ms/step - accuracy: 0.9846 - loss: 0.0406 - top_2_accuracy: 0.9990 - val_accuracy: 0.9051 - val_loss: 0.4525 - val_top_2_accuracy: 0.9901
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 277ms/step - accuracy: 0.9964 - loss: 0.0135 - top_2_accuracy: 0.9998 - val_accuracy: 0.8953 - val_loss: 0.4357 - val_top_2_accuracy: 0.9881
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 278ms/step - accuracy: 0.9845 - loss: 0.0417 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.4709 - val_top_2_accuracy: 0.9881
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9991 - loss: 0.0032 - top_2_accuracy: 1.0000 - val_accuracy: 0.8854 - val_loss: 0.5935 - val_top_2_accuracy: 0.9862
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 266ms/step - accuracy: 0.9997 - loss: 0.0010 - top_2_accuracy: 0.9999 - val_accuracy: 0.8972 - val_loss: 0.6118 - val_top_2_accuracy: 0.9881
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.9989 - loss: 0.0042 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.6113 - val_top_2_accuracy: 0.9822
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.9996 - loss: 9.8312e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.6416 - val_top_2_accuracy: 0.9842
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.9998 - loss: 7.0142e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.6603 - val_top_2_accuracy: 0.9842
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.9999 - loss: 1.8772e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.6758 - val_top_2_accuracy: 0.9842
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9999 - loss: 3.4119e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.6999 - val_top_2_accuracy: 0.9862
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9996 - loss: 0.0011 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.7120 - val_top_2_accuracy: 0.9842
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.9999 - loss: 3.8219e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.6980 - val_top_2_accuracy: 0.9862
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 266ms/step - accuracy: 0.9999 - loss: 4.5788e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.7092 - val_top_2_accuracy: 0.9842
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.9999 - loss: 5.1861e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8933 - val_loss: 0.7458 - val_top_2_accuracy: 0.9862
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 1.0000 - loss: 1.7035e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.7503 - val_top_2_accuracy: 0.9862
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.9990 - loss: 0.0018 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.7378 - val_top_2_accuracy: 0.9842
# VGG16 Training Summary:
#   Best Validation Loss: 0.2607 at epoch 11
#   Best Validation Accuracy: 0.9051 at epoch 25
#   Final Training Accuracy: 0.9994
#   Final Validation Accuracy: 0.8992
#   Overfitting (Train-Val): 0.1002
# ================================================================================
# CLASSIFICATION REPORT - VGG16
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.9367       0.9867       0.9610       75
# diabetic_retinopathy 0.9881       1.0000       0.9940       83
# glaucoma        0.9302       0.8989       0.9143       89
# normal          0.9326       0.9121       0.9222       91
# --------------------------------------------------------------------------------
# macro avg       0.9469       0.9494       0.9479       338
# weighted avg    0.9465       0.9467       0.9464       338
#
# Accuracy: 0.9467
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR VGG16:
# ==================================================
# Test Accuracy: 0.9467
# Test Top-2 Accuracy: 0.9911
# Test Loss: 0.3783
# Mean AP: 0.9723
# F1-Score (Macro): 0.9479
# Precision (Macro): 0.9469
# Recall (Macro): 0.9494
# Inference time per image: 6.3903 ms
# Best Validation Accuracy: 0.9051
# Parameters: 14,716,740
#
# ============================================================
# CREATING AND TRAINING: DenseNet201
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Parameters: 18,329,668
#
# ==================================================
# Training DenseNet201
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 726s 3s/step - accuracy: 0.7730 - loss: 0.5703 - top_2_accuracy: 0.9225 - val_accuracy: 0.7806 - val_loss: 0.5882 - val_top_2_accuracy: 0.9091
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9537 - loss: 0.1244 - top_2_accuracy: 0.9957 - val_accuracy: 0.7470 - val_loss: 0.8693 - val_top_2_accuracy: 0.9012
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9741 - loss: 0.0783 - top_2_accuracy: 0.9978 - val_accuracy: 0.8320 - val_loss: 0.6302 - val_top_2_accuracy: 0.9368
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 297ms/step - accuracy: 0.9864 - loss: 0.0499 - top_2_accuracy: 0.9991 - val_accuracy: 0.8874 - val_loss: 0.3473 - val_top_2_accuracy: 0.9842
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9944 - loss: 0.0158 - top_2_accuracy: 1.0000 - val_accuracy: 0.8893 - val_loss: 0.3843 - val_top_2_accuracy: 0.9842
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9977 - loss: 0.0133 - top_2_accuracy: 0.9999 - val_accuracy: 0.9032 - val_loss: 0.2834 - val_top_2_accuracy: 0.9941
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9927 - loss: 0.0208 - top_2_accuracy: 0.9999 - val_accuracy: 0.9130 - val_loss: 0.2952 - val_top_2_accuracy: 0.9901
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9934 - loss: 0.0199 - top_2_accuracy: 0.9994 - val_accuracy: 0.8874 - val_loss: 0.4085 - val_top_2_accuracy: 0.9822
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9918 - loss: 0.0265 - top_2_accuracy: 0.9995 - val_accuracy: 0.9032 - val_loss: 0.3816 - val_top_2_accuracy: 0.9881
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9867 - loss: 0.0371 - top_2_accuracy: 0.9989 - val_accuracy: 0.9091 - val_loss: 0.4132 - val_top_2_accuracy: 0.9723
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 297ms/step - accuracy: 0.9875 - loss: 0.0373 - top_2_accuracy: 0.9988 - val_accuracy: 0.9111 - val_loss: 0.4232 - val_top_2_accuracy: 0.9842
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9962 - loss: 0.0164 - top_2_accuracy: 1.0000 - val_accuracy: 0.9071 - val_loss: 0.3937 - val_top_2_accuracy: 0.9862
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9979 - loss: 0.0072 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3784 - val_top_2_accuracy: 0.9901
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9999 - loss: 0.0025 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3643 - val_top_2_accuracy: 0.9921
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9986 - loss: 0.0041 - top_2_accuracy: 1.0000 - val_accuracy: 0.9091 - val_loss: 0.4807 - val_top_2_accuracy: 0.9881
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9951 - loss: 0.0168 - top_2_accuracy: 1.0000 - val_accuracy: 0.9071 - val_loss: 0.4775 - val_top_2_accuracy: 0.9862
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9988 - loss: 0.0045 - top_2_accuracy: 1.0000 - val_accuracy: 0.8715 - val_loss: 0.8713 - val_top_2_accuracy: 0.9625
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9949 - loss: 0.0177 - top_2_accuracy: 1.0000 - val_accuracy: 0.9111 - val_loss: 0.4263 - val_top_2_accuracy: 0.9822
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 296ms/step - accuracy: 0.9966 - loss: 0.0109 - top_2_accuracy: 1.0000 - val_accuracy: 0.8794 - val_loss: 0.6320 - val_top_2_accuracy: 0.9684
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9926 - loss: 0.0220 - top_2_accuracy: 0.9995 - val_accuracy: 0.9032 - val_loss: 0.4452 - val_top_2_accuracy: 0.9862
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9911 - loss: 0.0285 - top_2_accuracy: 0.9985 - val_accuracy: 0.9091 - val_loss: 0.4078 - val_top_2_accuracy: 0.9743
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9944 - loss: 0.0139 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.4240 - val_top_2_accuracy: 0.9881
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9970 - loss: 0.0095 - top_2_accuracy: 1.0000 - val_accuracy: 0.9032 - val_loss: 0.6322 - val_top_2_accuracy: 0.9802
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 297ms/step - accuracy: 0.9993 - loss: 0.0023 - top_2_accuracy: 1.0000 - val_accuracy: 0.9209 - val_loss: 0.4694 - val_top_2_accuracy: 0.9862
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9994 - loss: 0.0020 - top_2_accuracy: 1.0000 - val_accuracy: 0.9229 - val_loss: 0.4573 - val_top_2_accuracy: 0.9743
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9987 - loss: 0.0066 - top_2_accuracy: 1.0000 - val_accuracy: 0.9150 - val_loss: 0.4284 - val_top_2_accuracy: 0.9862
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9948 - loss: 0.0111 - top_2_accuracy: 1.0000 - val_accuracy: 0.8656 - val_loss: 0.6757 - val_top_2_accuracy: 0.9644
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9974 - loss: 0.0089 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.4068 - val_top_2_accuracy: 0.9664
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9937 - loss: 0.0148 - top_2_accuracy: 0.9998 - val_accuracy: 0.8439 - val_loss: 0.8446 - val_top_2_accuracy: 0.9565
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 296ms/step - accuracy: 0.9863 - loss: 0.0392 - top_2_accuracy: 0.9998 - val_accuracy: 0.8814 - val_loss: 0.6995 - val_top_2_accuracy: 0.9783
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 297ms/step - accuracy: 0.9915 - loss: 0.0347 - top_2_accuracy: 0.9995 - val_accuracy: 0.9051 - val_loss: 0.4960 - val_top_2_accuracy: 0.9881
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9935 - loss: 0.0154 - top_2_accuracy: 0.9997 - val_accuracy: 0.9032 - val_loss: 0.3582 - val_top_2_accuracy: 0.9901
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9997 - loss: 0.0024 - top_2_accuracy: 1.0000 - val_accuracy: 0.9111 - val_loss: 0.3566 - val_top_2_accuracy: 0.9921
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9996 - loss: 0.0020 - top_2_accuracy: 1.0000 - val_accuracy: 0.9209 - val_loss: 0.3668 - val_top_2_accuracy: 0.9881
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 31s 296ms/step - accuracy: 0.9999 - loss: 9.1077e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9071 - val_loss: 0.3712 - val_top_2_accuracy: 0.9881
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 298ms/step - accuracy: 0.9997 - loss: 7.4473e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9170 - val_loss: 0.3727 - val_top_2_accuracy: 0.9862
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9993 - loss: 0.0014 - top_2_accuracy: 1.0000 - val_accuracy: 0.9051 - val_loss: 0.4010 - val_top_2_accuracy: 0.9862
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 297ms/step - accuracy: 0.9996 - loss: 5.8008e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9091 - val_loss: 0.3979 - val_top_2_accuracy: 0.9862
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 296ms/step - accuracy: 0.9997 - loss: 6.7819e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.4045 - val_top_2_accuracy: 0.9862
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9996 - loss: 4.4539e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.4082 - val_top_2_accuracy: 0.9862
# DenseNet201 Training Summary:
#   Best Validation Loss: 0.2834 at epoch 6
#   Best Validation Accuracy: 0.9229 at epoch 25
#   Final Training Accuracy: 0.9994
#   Final Validation Accuracy: 0.9130
#   Overfitting (Train-Val): 0.0864
# ================================================================================
# CLASSIFICATION REPORT - DenseNet201
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.9605       0.9733       0.9669       75
# diabetic_retinopathy 1.0000       1.0000       1.0000       83
# glaucoma        0.9518       0.8876       0.9186       89
# normal          0.9062       0.9560       0.9305       91
# --------------------------------------------------------------------------------
# macro avg       0.9546       0.9543       0.9540       338
# weighted avg    0.9533       0.9527       0.9525       338
#
# Accuracy: 0.9527
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR DenseNet201:
# ==================================================
# Test Accuracy: 0.9527
# Test Top-2 Accuracy: 0.9970
# Test Loss: 0.2193
# Mean AP: 0.9829
# F1-Score (Macro): 0.9540
# Precision (Macro): 0.9546
# Recall (Macro): 0.9543
# Inference time per image: 60.6554 ms
# Best Validation Accuracy: 0.9229
# Parameters: 18,329,668
#
# ============================================================
# CREATING AND TRAINING: ViT Small
# ============================================================
# Parameters: 21,667,204
#
# ==================================================
# Training ViT Small
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 137s 582ms/step - accuracy: 0.2603 - loss: 1.8900 - top_2_accuracy: 0.5168 - val_accuracy: 0.3004 - val_loss: 1.3638 - val_top_2_accuracy: 0.6660
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.3441 - loss: 1.3915 - top_2_accuracy: 0.6040 - val_accuracy: 0.3458 - val_loss: 1.2149 - val_top_2_accuracy: 0.6581
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.3698 - loss: 1.9290 - top_2_accuracy: 0.6510 - val_accuracy: 0.5000 - val_loss: 3.2737 - val_top_2_accuracy: 0.7589
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.4724 - loss: 3.7011 - top_2_accuracy: 0.7515 - val_accuracy: 0.4565 - val_loss: 14.0819 - val_top_2_accuracy: 0.6245
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.3247 - loss: 12.9372 - top_2_accuracy: 0.5619 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.2259 - loss: 11.7339 - top_2_accuracy: 0.4740 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 258ms/step - accuracy: 0.2498 - loss: 11.8664 - top_2_accuracy: 0.4919 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 257ms/step - accuracy: 0.2493 - loss: 11.8162 - top_2_accuracy: 0.4967 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.2501 - loss: 11.7817 - top_2_accuracy: 0.4864 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.2696 - loss: 11.8025 - top_2_accuracy: 0.4864 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 258ms/step - accuracy: 0.2653 - loss: 11.8901 - top_2_accuracy: 0.5161 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.2449 - loss: 11.9055 - top_2_accuracy: 0.4771 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.2532 - loss: 12.0699 - top_2_accuracy: 0.5023 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 258ms/step - accuracy: 0.2529 - loss: 11.8533 - top_2_accuracy: 0.4992 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2485 - loss: 11.8083 - top_2_accuracy: 0.4903 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2512 - loss: 11.7328 - top_2_accuracy: 0.4840 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2570 - loss: 12.0010 - top_2_accuracy: 0.4994 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2438 - loss: 11.8275 - top_2_accuracy: 0.4818 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.2496 - loss: 11.9508 - top_2_accuracy: 0.4864 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.2485 - loss: 11.8934 - top_2_accuracy: 0.4980 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.2610 - loss: 12.0827 - top_2_accuracy: 0.5110 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.2655 - loss: 11.9565 - top_2_accuracy: 0.5045 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.2456 - loss: 12.0262 - top_2_accuracy: 0.4984 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.2509 - loss: 12.0711 - top_2_accuracy: 0.4768 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.2459 - loss: 11.7900 - top_2_accuracy: 0.4921 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - accuracy: 0.2429 - loss: 11.5693 - top_2_accuracy: 0.4744 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2354 - loss: 11.8500 - top_2_accuracy: 0.4827 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 266ms/step - accuracy: 0.2543 - loss: 11.8956 - top_2_accuracy: 0.5013 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 277ms/step - accuracy: 0.2699 - loss: 11.8833 - top_2_accuracy: 0.4899 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2586 - loss: 11.8186 - top_2_accuracy: 0.4947 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2507 - loss: 11.6943 - top_2_accuracy: 0.4840 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.2657 - loss: 12.0967 - top_2_accuracy: 0.5040 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.2574 - loss: 11.7472 - top_2_accuracy: 0.4955 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.2622 - loss: 12.0226 - top_2_accuracy: 0.5033 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2599 - loss: 11.8984 - top_2_accuracy: 0.4817 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.2291 - loss: 11.6283 - top_2_accuracy: 0.4862 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.2566 - loss: 11.8074 - top_2_accuracy: 0.4906 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.2577 - loss: 12.0081 - top_2_accuracy: 0.4880 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.2469 - loss: 11.8134 - top_2_accuracy: 0.4815 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - accuracy: 0.2398 - loss: 11.8743 - top_2_accuracy: 0.4758 - val_accuracy: 0.2767 - val_loss: 12.2319 - val_top_2_accuracy: 0.5099
# ViT Small Training Summary:
#   Best Validation Loss: 1.2149 at epoch 2
#   Best Validation Accuracy: 0.5000 at epoch 3
#   Final Training Accuracy: 0.2541
#   Final Validation Accuracy: 0.2767
#   Overfitting (Train-Val): -0.0226
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
# CLASSIFICATION REPORT - ViT Small
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.2459       0.8000       0.3762       75
# diabetic_retinopathy 0.0000       0.0000       0.0000       83
# glaucoma        0.3898       0.2584       0.3108       89
# normal          0.0000       0.0000       0.0000       91
# --------------------------------------------------------------------------------
# macro avg       0.1589       0.2646       0.1717       338
# weighted avg    0.1572       0.2456       0.1653       338
#
# Accuracy: 0.2456
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR ViT Small:
# ==================================================
# Test Accuracy: 0.2456
# Test Top-2 Accuracy: 0.4852
# Test Loss: 12.1601
# Mean AP: 0.4400
# F1-Score (Macro): 0.1717
# Precision (Macro): 0.1589
# Recall (Macro): 0.2646
# Inference time per image: 15.7972 ms
# Best Validation Accuracy: 0.5000
# Parameters: 21,667,204
#
# ============================================================
# CREATING AND TRAINING: Eye Disease Classifier
# ============================================================
# Eye Disease Classifier built successfully with 14914279 parameters
# Parameters: 14,914,279
#
# ==================================================
# Training Eye Disease Classifier
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 0.5218 - loss: 1.0719 - top_2_accuracy: 0.7544 - val_accuracy: 0.8024 - val_loss: 1.0741 - val_top_2_accuracy: 0.9664
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.8415 - loss: 0.4285 - top_2_accuracy: 0.9647 - val_accuracy: 0.7984 - val_loss: 0.7694 - val_top_2_accuracy: 0.9644
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.8641 - loss: 0.3701 - top_2_accuracy: 0.9691 - val_accuracy: 0.8004 - val_loss: 0.6003 - val_top_2_accuracy: 0.9427
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.8836 - loss: 0.3084 - top_2_accuracy: 0.9788 - val_accuracy: 0.8360 - val_loss: 0.4301 - val_top_2_accuracy: 0.9822
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - accuracy: 0.8971 - loss: 0.2592 - top_2_accuracy: 0.9879 - val_accuracy: 0.8617 - val_loss: 0.3612 - val_top_2_accuracy: 0.9842
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - accuracy: 0.9239 - loss: 0.2140 - top_2_accuracy: 0.9887 - val_accuracy: 0.8419 - val_loss: 0.4360 - val_top_2_accuracy: 0.9822
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9289 - loss: 0.1931 - top_2_accuracy: 0.9880 - val_accuracy: 0.8735 - val_loss: 0.3438 - val_top_2_accuracy: 0.9842
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.9371 - loss: 0.1958 - top_2_accuracy: 0.9908 - val_accuracy: 0.8419 - val_loss: 0.4763 - val_top_2_accuracy: 0.9506
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9527 - loss: 0.1389 - top_2_accuracy: 0.9930 - val_accuracy: 0.8715 - val_loss: 0.3758 - val_top_2_accuracy: 0.9763
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9555 - loss: 0.1276 - top_2_accuracy: 0.9936 - val_accuracy: 0.7688 - val_loss: 1.2157 - val_top_2_accuracy: 0.9644
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9614 - loss: 0.1105 - top_2_accuracy: 0.9943 - val_accuracy: 0.8518 - val_loss: 0.5533 - val_top_2_accuracy: 0.9802
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9698 - loss: 0.0993 - top_2_accuracy: 0.9940 - val_accuracy: 0.8656 - val_loss: 0.5632 - val_top_2_accuracy: 0.9763
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9733 - loss: 0.0834 - top_2_accuracy: 0.9966 - val_accuracy: 0.8182 - val_loss: 0.6892 - val_top_2_accuracy: 0.9743
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9666 - loss: 0.0995 - top_2_accuracy: 0.9965 - val_accuracy: 0.8597 - val_loss: 0.5987 - val_top_2_accuracy: 0.9783
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9807 - loss: 0.0670 - top_2_accuracy: 0.9988 - val_accuracy: 0.8755 - val_loss: 0.4525 - val_top_2_accuracy: 0.9783
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9850 - loss: 0.0568 - top_2_accuracy: 0.9987 - val_accuracy: 0.8617 - val_loss: 0.4924 - val_top_2_accuracy: 0.9684
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9773 - loss: 0.0686 - top_2_accuracy: 0.9985 - val_accuracy: 0.8656 - val_loss: 0.5654 - val_top_2_accuracy: 0.9822
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9794 - loss: 0.0581 - top_2_accuracy: 0.9987 - val_accuracy: 0.8557 - val_loss: 0.6566 - val_top_2_accuracy: 0.9644
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9878 - loss: 0.0433 - top_2_accuracy: 0.9996 - val_accuracy: 0.8953 - val_loss: 0.5363 - val_top_2_accuracy: 0.9763
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9899 - loss: 0.0342 - top_2_accuracy: 0.9999 - val_accuracy: 0.8794 - val_loss: 0.5666 - val_top_2_accuracy: 0.9723
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9900 - loss: 0.0344 - top_2_accuracy: 0.9978 - val_accuracy: 0.8478 - val_loss: 0.7028 - val_top_2_accuracy: 0.9545
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9897 - loss: 0.0346 - top_2_accuracy: 0.9995 - val_accuracy: 0.8715 - val_loss: 0.5670 - val_top_2_accuracy: 0.9664
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9879 - loss: 0.0328 - top_2_accuracy: 0.9997 - val_accuracy: 0.8715 - val_loss: 0.5800 - val_top_2_accuracy: 0.9743
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9915 - loss: 0.0275 - top_2_accuracy: 0.9994 - val_accuracy: 0.8834 - val_loss: 0.4704 - val_top_2_accuracy: 0.9842
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9895 - loss: 0.0372 - top_2_accuracy: 0.9987 - val_accuracy: 0.8557 - val_loss: 0.8017 - val_top_2_accuracy: 0.9763
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9866 - loss: 0.0386 - top_2_accuracy: 0.9988 - val_accuracy: 0.8419 - val_loss: 0.6864 - val_top_2_accuracy: 0.9466
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9910 - loss: 0.0338 - top_2_accuracy: 0.9983 - val_accuracy: 0.8419 - val_loss: 0.8804 - val_top_2_accuracy: 0.9328
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9830 - loss: 0.0482 - top_2_accuracy: 0.9981 - val_accuracy: 0.8597 - val_loss: 0.7577 - val_top_2_accuracy: 0.9565
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9873 - loss: 0.0366 - top_2_accuracy: 0.9999 - val_accuracy: 0.8656 - val_loss: 0.6571 - val_top_2_accuracy: 0.9881
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - accuracy: 0.9927 - loss: 0.0215 - top_2_accuracy: 1.0000 - val_accuracy: 0.8696 - val_loss: 0.6693 - val_top_2_accuracy: 0.9743
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 241ms/step - accuracy: 0.9912 - loss: 0.0276 - top_2_accuracy: 0.9988 - val_accuracy: 0.8735 - val_loss: 0.5657 - val_top_2_accuracy: 0.9783
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9956 - loss: 0.0175 - top_2_accuracy: 0.9996 - val_accuracy: 0.8933 - val_loss: 0.6245 - val_top_2_accuracy: 0.9743
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9961 - loss: 0.0131 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.5716 - val_top_2_accuracy: 0.9743
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9923 - loss: 0.0284 - top_2_accuracy: 0.9992 - val_accuracy: 0.8103 - val_loss: 1.2775 - val_top_2_accuracy: 0.9545
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9941 - loss: 0.0210 - top_2_accuracy: 0.9995 - val_accuracy: 0.8577 - val_loss: 0.8548 - val_top_2_accuracy: 0.9704
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9936 - loss: 0.0178 - top_2_accuracy: 0.9992 - val_accuracy: 0.8735 - val_loss: 0.6237 - val_top_2_accuracy: 0.9704
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9935 - loss: 0.0271 - top_2_accuracy: 0.9995 - val_accuracy: 0.8676 - val_loss: 0.6458 - val_top_2_accuracy: 0.9822
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9907 - loss: 0.0285 - top_2_accuracy: 0.9998 - val_accuracy: 0.8834 - val_loss: 0.7201 - val_top_2_accuracy: 0.9783
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9964 - loss: 0.0126 - top_2_accuracy: 1.0000 - val_accuracy: 0.8636 - val_loss: 0.7441 - val_top_2_accuracy: 0.9565
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9869 - loss: 0.0369 - top_2_accuracy: 0.9997 - val_accuracy: 0.8715 - val_loss: 0.5716 - val_top_2_accuracy: 0.9783
# Eye Disease Classifier Training Summary:
#   Best Validation Loss: 0.3438 at epoch 7
#   Best Validation Accuracy: 0.8972 at epoch 33
#   Final Training Accuracy: 0.9870
#   Final Validation Accuracy: 0.8715
#   Overfitting (Train-Val): 0.1154
# ================================================================================
# CLASSIFICATION REPORT - Eye Disease Classifier
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.8750       0.9333       0.9032       75
# diabetic_retinopathy 1.0000       1.0000       1.0000       83
# glaucoma        0.8539       0.8539       0.8539       89
# normal          0.8837       0.8352       0.8588       91
# --------------------------------------------------------------------------------
# macro avg       0.9032       0.9056       0.9040       338
# weighted avg    0.9025       0.9024       0.9020       338
#
# Accuracy: 0.9024
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR Eye Disease Classifier:
# ==================================================
# Test Accuracy: 0.9024
# Test Top-2 Accuracy: 0.9852
# Test Loss: 0.4090
# Mean AP: 0.9590
# F1-Score (Macro): 0.9040
# Precision (Macro): 0.9032
# Recall (Macro): 0.9056
# Inference time per image: 7.4121 ms
# Best Validation Accuracy: 0.8972
# Parameters: 14,914,279
#
# ================================================================================
# COMBINED TRAINING HISTORIES VISUALIZATION
# ================================================================================
# ================================================================================
# COMPREHENSIVE RESULTS VISUALIZATION
# ================================================================================
# ==================================================================================================================================
# COMPREHENSIVE RESULTS COMPARISON (4-DIGIT PRECISION)
# ==================================================================================================================================
# Model                Test Acc   Top-2 Acc  mAP        F1         Precision  Recall     Params(M)    Time(ms)
# ----------------------------------------------------------------------------------------------------------------------------------
# DenseNet201          0.9527     0.9970     0.9829     0.9540     0.9546     0.9543     18.33        60.6550
# VGG16                0.9467     0.9911     0.9723     0.9479     0.9469     0.9494     14.72        6.3900
# MobileNet-V2         0.9260     0.9941     0.9792     0.9265     0.9263     0.9298     2.26         12.6220
# Eye Disease Classifier 0.9024     0.9852     0.9590     0.9040     0.9032     0.9056     14.91        7.4120
# EfficientNet-B0      0.2899     0.8964     0.2685     0.2733     0.3063     0.2833     4.05         26.5130
# ViT Small            0.2456     0.4852     0.4400     0.1717     0.1589     0.2646     21.67        15.7970
#
# ==================================================================================================================================
# FINAL ANALYSIS AND RECOMMENDATIONS
# ==================================================================================================================================
# 🏆 BEST OVERALL PERFORMANCE: DenseNet201
#    → Test Accuracy: 0.9527
#    → F1-Score: 0.9540
#    → mAP: 0.9829
#    → Parameters: 18.33M
#
# ⚡ MOST EFFICIENT: MobileNet-V2
#    → Efficiency Score: 0.4092
#    → Test Accuracy: 0.9260
#    → Parameters: 2.26M
#
# 🚀 FASTEST INFERENCE: VGG16
#    → Inference Time: 6.3900 ms
#    → Test Accuracy: 0.9467
#    → FPS: 156.5
#
# 🔬 YOUR EYE DISEASE CLASSIFIER ANALYSIS:
#    → Test Accuracy: 0.9024
#    → F1-Score: 0.9040
#    → Mean AP: 0.9590
#    → Efficiency: 0.0605
#    → Inference Time: 7.4120 ms
#    → Rank by Accuracy: 4/6
#
# 📊 Results saved to: eye_disease_comprehensive_results.csv
#
# ==================================================================================================================================
# ANALYSIS COMPLETE - ALL MODELS TRAINED SEQUENTIALLY
# ==================================================================================================================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# Path to your dataset
data_dir = r"/kaggle/input/eye-diseases-classification/dataset"

filepaths = []
labels = []

# Create filepaths and labels lists
for label in os.listdir(data_dir):
    label_path = os.path.join(data_dir, label)
    for file in os.listdir(label_path):
        filepaths.append(os.path.join(label_path, file))
        labels.append(label)

# Create DataFrame
df = pd.DataFrame({
    'filepaths': filepaths,
    'labels': labels
})

print("Total images:", len(df))
print("Class distribution:\n", df['labels'].value_counts())

# Split data: 80% train, 20% temp (will split temp into val/test)
train_df, temp_df = train_test_split(df, train_size=0.8, stratify=df['labels'], random_state=42)
valid_df, test_df = train_test_split(temp_df, train_size=0.6, stratify=temp_df['labels'], random_state=42)

# Function to count images per class
def count_per_class(split_df):
    return split_df['labels'].value_counts().to_dict()

train_counts = count_per_class(train_df)
valid_counts = count_per_class(valid_df)
test_counts = count_per_class(test_df)

# Build distribution table
classes = sorted(df['labels'].unique())
table_data = []

for cls in classes:
    table_data.append({
        'Class Name': cls,
        'No. of Training Images': train_counts.get(cls, 0),
        'No. of Validation Images': valid_counts.get(cls, 0),
        'No. of Testing Images': test_counts.get(cls, 0),
        'Total Images': train_counts.get(cls, 0) + valid_counts.get(cls, 0) + test_counts.get(cls, 0)
    })

distribution_table = pd.DataFrame(table_data)
distribution_table = distribution_table.sort_values('Total Images', ascending=False).reset_index(drop=True)

print("\nClass Distribution Table:")
print(distribution_table)
# Out:
# Total images: 4217
# Class distribution:
#  labels
# diabetic_retinopathy    1098
# normal                  1074
# cataract                1038
# glaucoma                1007
# Name: count, dtype: int64
#
# Class Distribution Table:
#              Class Name  No. of Training Images  No. of Validation Images  \
# 0  diabetic_retinopathy                     878                       132
# 1                normal                     859                       129
# 2              cataract                     830                       125
# 3              glaucoma                     806                       120
#
#    No. of Testing Images  Total Images
# 0                     88          1098
# 1                     86          1074
# 2                     83          1038
# 3                     81          1007

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import os
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0, ResNet50, DenseNet201, MobileNet, MobileNetV2, VGG16
from tensorflow.keras.optimizers import AdamW, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import math
import itertools
import cv2

# Data loading
data_dir = r"/kaggle/input/eye-diseases-classification/dataset"
filepaths = []
labels = []
folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis=1)

print("Class distribution:")
print(df['labels'].value_counts())
print(f"Number of unique classes: {df['labels'].nunique()}")

# Split data
train_df, dummy_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42)
valid_df, test_df = train_test_split(dummy_df, train_size=0.6, shuffle=True, random_state=42)

print(f"Train samples: {len(train_df)}")
print(f"Valid samples: {len(valid_df)}")
print(f"Test samples: {len(test_df)}")

# Create data generators
batch_size = 32
img_size = (224, 224)
channels = 3

tr_gen = ImageDataGenerator(rescale=1./255)
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen = tr_gen.flow_from_dataframe(
    train_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
valid_gen = ts_gen.flow_from_dataframe(
    valid_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
test_gen = ts_gen.flow_from_dataframe(
    test_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=False, batch_size=batch_size
)

# Get number of classes
num_classes = 4
class_names = list(train_gen.class_indices.keys())
print(f"Classes: {class_names}")

# Multiscale Attention Layer for Eye Disease Classifier
class MultiscaleAttentionLayer(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(MultiscaleAttentionLayer, self).__init__(**kwargs)
        self.filters = filters
        
    def build(self, input_shape):
        # Channel attention
        self.channel_attention = keras.Sequential([
            layers.GlobalAveragePooling2D(),
            layers.Dense(self.filters // 8, activation='relu'),
            layers.Dense(self.filters, activation='sigmoid'),
            layers.Reshape((1, 1, self.filters))
        ])
        
        # Spatial attention
        self.spatial_attention = keras.Sequential([
            layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')
        ])
        
        super(MultiscaleAttentionLayer, self).build(input_shape)
    
    def call(self, inputs):
        # Channel attention
        channel_att = self.channel_attention(inputs)
        x = layers.Multiply()([inputs, channel_att])
        
        # Spatial attention
        avg_pool = tf.reduce_mean(x, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(x, axis=-1, keepdims=True)
        spatial_input = layers.Concatenate()([avg_pool, max_pool])
        spatial_att = self.spatial_attention(spatial_input)
        x = layers.Multiply()([x, spatial_att])
        
        return x
    
    def get_config(self):
        config = super(MultiscaleAttentionLayer, self).get_config()
        config.update({'filters': self.filters})
        return config

# Eye Disease Classifier
def create_eye_disease_classifier(num_classes):
    """
    Create Eye Disease Classifier with VGG16 base and multiscale attention
    """
    try:
        # Load pre-trained VGG16
        base_model = VGG16(
            weights='imagenet',
            include_top=False,
            input_shape=(224, 224, 3)
        )
        
        # Freeze early layers, unfreeze last few blocks for fine-tuning
        for layer in base_model.layers[:-4]:
            layer.trainable = False
        for layer in base_model.layers[-4:]:
            layer.trainable = True
            
        # Build the complete model
        inputs = keras.Input(shape=(224, 224, 3), name='input_image')
        
        # VGG16 feature extraction
        x = base_model(inputs, training=False)
        
        # Get the number of filters from VGG16 output
        vgg_output_filters = x.shape[-1]
        
        # Multiscale attention mechanism
        x = MultiscaleAttentionLayer(filters=vgg_output_filters, name='multiscale_attention')(x)
        
        # Global Average Pooling
        x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
        
        # Dropout for regularization
        x = layers.Dropout(0.5, name='dropout_1')(x)
        
        # Dense layer with batch normalization
        x = layers.Dense(256, activation='relu', name='dense_1')(x)
        x = layers.BatchNormalization(name='batch_norm')(x)
        x = layers.Dropout(0.25, name='dropout_2')(x)
        
        # Output layer with softmax activation
        predictions = layers.Dense(num_classes, activation='softmax', name='predictions')(x)
        
        # Create the model
        model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier')
        
        print(f"Eye Disease Classifier built successfully with {model.count_params()} parameters")
        return model
        
    except Exception as e:
        print(f"Error building model: {str(e)}")
        print("Building simplified model...")
        return create_eye_disease_classifier_simplified(num_classes)

def create_eye_disease_classifier_simplified(num_classes):
    """
    Build a simplified model without custom layers as fallback
    """
    # Load pre-trained VGG16
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    # Freeze early layers
    for layer in base_model.layers[:-4]:
        layer.trainable = False
    for layer in base_model.layers[-4:]:
        layer.trainable = True
        
    # Build simplified model
    inputs = keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    
    # Simple attention using Global Average Pooling and Dense layers
    gap = layers.GlobalAveragePooling2D()(x)
    attention_weights = layers.Dense(x.shape[-1], activation='sigmoid')(gap)
    attention_weights = layers.Reshape((1, 1, x.shape[-1]))(attention_weights)
    x = layers.Multiply()([x, attention_weights])
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.25)(x)
    predictions = layers.Dense(num_classes, activation='softmax')(x)
    
    model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier_Simplified')
    
    print(f"Simplified Eye Disease Classifier built successfully with {model.count_params()} parameters")
    return model

# ViT Small Implementation
class PatchEmbedding(layers.Layer):
    def __init__(self, patch_size=16, embed_dim=384):
        super().__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.projection = layers.Conv2D(
            embed_dim, kernel_size=patch_size, strides=patch_size, padding='valid'
        )
        
    def call(self, x):
        batch_size = tf.shape(x)[0]
        patches = self.projection(x)
        patches = tf.reshape(patches, [batch_size, -1, self.embed_dim])
        return patches

class MultiHeadAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        
        self.qkv = layers.Dense(embed_dim * 3)
        self.projection = layers.Dense(embed_dim)
        
    def call(self, x):
        batch_size, seq_len, embed_dim = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        
        qkv = self.qkv(x)
        qkv = tf.reshape(qkv, [batch_size, seq_len, 3, self.num_heads, self.head_dim])
        qkv = tf.transpose(qkv, [2, 0, 3, 1, 4])
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = tf.cast(self.head_dim, tf.float32) ** -0.5
        attn = tf.matmul(q, k, transpose_b=True) * scale
        attn = tf.nn.softmax(attn, axis=-1)
        
        out = tf.matmul(attn, v)
        out = tf.transpose(out, [0, 2, 1, 3])
        out = tf.reshape(out, [batch_size, seq_len, embed_dim])
        
        return self.projection(out)

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, mlp_ratio=4.0, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = MultiHeadAttention(embed_dim, num_heads)
        self.dropout1 = layers.Dropout(dropout)
        
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        mlp_hidden_dim = int(embed_dim * mlp_ratio)
        self.mlp = keras.Sequential([
            layers.Dense(mlp_hidden_dim, activation='gelu'),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout)
        ])
        
    def call(self, x, training=None):
        attn_out = self.attn(self.norm1(x))
        x = x + self.dropout1(attn_out, training=training)
        
        mlp_out = self.mlp(self.norm2(x), training=training)
        x = x + mlp_out
        
        return x

class VisionTransformerSmall(keras.Model):
    def __init__(self, 
                 img_size=224,
                 patch_size=16, 
                 num_classes=4,
                 embed_dim=384,
                 depth=12,
                 num_heads=6,
                 mlp_ratio=4.0,
                 dropout=0.1):
        super().__init__()
        
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        
        self.patch_embed = PatchEmbedding(patch_size, embed_dim)
        
        self.class_token = self.add_weight(
            shape=(1, 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='class_token'
        )
        
        self.pos_embed = self.add_weight(
            shape=(1, self.num_patches + 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='pos_embed'
        )
        
        self.dropout = layers.Dropout(dropout)
        
        self.blocks = [
            TransformerBlock(embed_dim, num_heads, mlp_ratio, dropout)
            for _ in range(depth)
        ]
        
        self.norm = layers.LayerNormalization(epsilon=1e-6)
        self.head = layers.Dense(num_classes)
        
    def call(self, x, training=None):
        batch_size = tf.shape(x)[0]
        
        x = self.patch_embed(x)
        
        class_tokens = tf.broadcast_to(self.class_token, [batch_size, 1, tf.shape(self.class_token)[-1]])
        x = tf.concat([class_tokens, x], axis=1)
        
        x = x + self.pos_embed
        x = self.dropout(x, training=training)
        
        for block in self.blocks:
            x = block(x, training=training)
            
        x = self.norm(x)
        
        class_token_final = x[:, 0]
        return self.head(class_token_final)

def create_vit_small(num_classes):
    return VisionTransformerSmall(
        img_size=224,
        patch_size=16,
        num_classes=num_classes,
        embed_dim=384,
        depth=12,
        num_heads=6,
        mlp_ratio=4.0,
        dropout=0.1
    )

# Other model creation functions
def create_efficientnet(num_classes):
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_vgg16(num_classes):
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_denseNet201(num_classes):
    base_model = DenseNet201(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

# GradCAM implementation
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Generate GradCAM heatmap"""
    try:
        # Create a model that maps the input image to the activations of the last conv layer
        grad_model = tf.keras.models.Model(
            [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
        )
        
        # Compute the gradient of the top predicted class
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Gradient of the output neuron with regard to the output feature map
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Mean intensity of the gradient over a specific feature map channel
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Multiply each channel by "how important this channel is"
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize the heatmap between 0 & 1
        heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
        return heatmap.numpy()
    except Exception as e:
        print(f"GradCAM error: {e}")
        return None

# Fixed GradCAM implementation with proper layer detection

def get_last_conv_layer_name(model, model_name):
    """Enhanced function to get the last convolutional layer name"""
    conv_layers = []
    
    def collect_conv_layers(layer_or_model, prefix=""):
        """Recursively collect all conv layer names"""
        if hasattr(layer_or_model, 'layers'):
            for layer in layer_or_model.layers:
                layer_name = f"{prefix}{layer.name}" if prefix else layer.name
                
                # Check if it's a conv layer
                if any(conv_type in layer.__class__.__name__.lower() for conv_type in ['conv2d', 'separableconv2d', 'depthwiseconv2d']):
                    conv_layers.append(layer_name)
                
                # Recursively check sublayers
                collect_conv_layers(layer, prefix=f"{layer_name}/")
    
    # Start collection from the model
    collect_conv_layers(model)
    
    # If no conv layers found directly, try to access base model
    if not conv_layers:
        try:
            # For Sequential models
            if hasattr(model, 'layers') and len(model.layers) > 0:
                first_layer = model.layers[0]
                if hasattr(first_layer, 'layers'):
                    collect_conv_layers(first_layer)
        except:
            pass
    
    # Print available conv layers for debugging
    print(f"Available conv layers in {model_name}: {conv_layers[-5:]}")  # Show last 5
    
    # Return the last conv layer found
    return conv_layers[-1] if conv_layers else None

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Enhanced GradCAM with better error handling"""
    try:
        # Handle nested layer names (e.g., "base_model/block5_conv3")
        if '/' in last_conv_layer_name:
            layer_parts = last_conv_layer_name.split('/')
            current_layer = model
            
            # Navigate through nested layers
            for part in layer_parts:
                if hasattr(current_layer, 'get_layer'):
                    current_layer = current_layer.get_layer(part)
                elif hasattr(current_layer, 'layers'):
                    # Find layer by name in layers list
                    found = False
                    for layer in current_layer.layers:
                        if layer.name == part:
                            current_layer = layer
                            found = True
                            break
                    if not found:
                        raise ValueError(f"Layer {part} not found")
                else:
                    raise ValueError(f"Cannot navigate to layer {part}")
            
            target_layer = current_layer
        else:
            # Simple case - direct layer access
            target_layer = model.get_layer(last_conv_layer_name)
        
        # Create gradient model
        grad_model = tf.keras.models.Model(
            [model.inputs], 
            [target_layer.output, model.output]
        )
        
        # Compute gradients
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Get gradients
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Handle None gradients
        if grads is None:
            print(f"Warning: No gradients computed for layer {last_conv_layer_name}")
            return None
        
        # Compute importance weights
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Generate heatmap
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize heatmap
        heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-10)
        return heatmap.numpy()
        
    except Exception as e:
        print(f"GradCAM failed for {last_conv_layer_name}: {str(e)}")
        return None

def plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples=4):
    """Fixed GradCAM plotting with fallback strategies"""
    print(f"\nGenerating GradCAM for {model_name}...")
    
    # Get last conv layer with enhanced detection
    last_conv_layer = get_last_conv_layer_name(model, model_name)
    
    if not last_conv_layer:
        print(f"No convolutional layers found in {model_name} - skipping GradCAM")
        return
    
    print(f"Using layer: {last_conv_layer}")
    
    # Try alternative layers if the first one fails
    alternative_layers = []
    if 'vgg16' in last_conv_layer.lower():
        alternative_layers = ['block5_conv3', 'block5_conv2', 'block4_conv3']
    elif 'efficientnet' in model_name.lower():
        alternative_layers = ['top_activation', 'top_conv', 'block7a_expand_activation']
    elif 'mobilenet' in model_name.lower():
        alternative_layers = ['out_relu', 'Conv_1', 'block_16_depthwise']
    
    successful_layer = None
    test_heatmap = None
    
    # Test the primary layer
    test_gen.reset()
    test_images, test_labels = next(iter(test_gen))
    test_img = np.expand_dims(test_images[0], axis=0)
    
    test_heatmap = make_gradcam_heatmap(test_img, model, last_conv_layer, pred_index=0)
    if test_heatmap is not None:
        successful_layer = last_conv_layer
    else:
        # Try alternative layers
        for alt_layer in alternative_layers:
            try:
                test_heatmap = make_gradcam_heatmap(test_img, model, alt_layer, pred_index=0)
                if test_heatmap is not None:
                    successful_layer = alt_layer
                    print(f"Using alternative layer: {alt_layer}")
                    break
            except:
                continue
    
    if successful_layer is None:
        print(f"All GradCAM attempts failed for {model_name}")
        return
    
    # Plot GradCAM examples
    plt.figure(figsize=(20, 10))
    plt.suptitle(f'GradCAM Visualizations - {model_name} (Layer: {successful_layer})', 
                 fontsize=16, fontweight='bold')
    
    test_gen.reset()
    images, labels = next(iter(test_gen))
    
    for i in range(min(num_examples, len(images))):
        img_array = np.expand_dims(images[i], axis=0)
        
        # Make prediction
        preds = model.predict(img_array, verbose=0)
        pred_class = np.argmax(preds[0])
        true_class = np.argmax(labels[i])
        confidence = np.max(preds[0])
        
        # Generate heatmap
        heatmap = make_gradcam_heatmap(img_array, model, successful_layer, pred_class)
        
        # Plot original
        plt.subplot(2, num_examples, i + 1)
        plt.imshow(images[i])
        plt.title(f'Original\nTrue: {class_names[true_class]}', fontsize=10)
        plt.axis('off')
        
        # Plot GradCAM
        plt.subplot(2, num_examples, i + 1 + num_examples)
        plt.imshow(images[i])
        if heatmap is not None:
            # Resize heatmap to match image size
            heatmap_resized = cv2.resize(heatmap, (224, 224))
            plt.imshow(heatmap_resized, alpha=0.4, cmap='jet')
            status = "Success"
        else:
            status = "Failed"
        
        plt.title(f'GradCAM ({status})\nPred: {class_names[pred_class]}\nConf: {confidence:.3f}', 
                 fontsize=10)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

def debug_model_structure(model, model_name):
    """Debug function to understand model structure"""
    print(f"\n=== MODEL STRUCTURE DEBUG: {model_name} ===")
    
    def print_layers(layer_or_model, indent=0):
        prefix = "  " * indent
        if hasattr(layer_or_model, 'layers'):
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
            for i, layer in enumerate(layer_or_model.layers):
                print(f"{prefix}├─ [{i}] {layer.__class__.__name__}: {layer.name}")
                if hasattr(layer, 'layers') and len(layer.layers) > 0:
                    print_layers(layer, indent + 1)
        else:
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
    
    print_layers(model)
    print("=" * 50)

# Modified plotting function call in main training loop
def plot_gradcam_examples(model, test_gen, class_names, model_name, num_examples=4):
    """Wrapper function that includes debugging"""
    # Debug model structure first
    debug_model_structure(model, model_name)
    
    # Use the fixed GradCAM implementation
    plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples)

# Additional helper function to manually specify conv layer names
def get_manual_conv_layer_mapping():
    """Manual mapping for problematic models"""
    return {
        'EfficientNet-B0': ['efficientnetb0/block6a_expand_conv', 'efficientnetb0/top_conv'],
        'MobileNet-V2': ['mobilenetv2_1.00_224/block_16_depthwise', 'mobilenetv2_1.00_224/Conv_1'],
        'VGG16': ['vgg16/block5_conv3', 'vgg16/block5_conv2'],
        'DenseNet201': ['densenet201/conv5_block32_2_conv', 'densenet201/conv5_block32_concat'],
        'Eye Disease Classifier': ['vgg16/block5_conv3', 'multiscale_attention']
    }
# Enhanced visualization functions
def plot_clean_training_history(history, model_name):
    """Plot clean training history with 4-digit precision"""
    tr_acc = history.history['accuracy']
    tr_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    
    # Find best epochs
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    # Plot training history
    plt.figure(figsize=(15, 8))
    plt.style.use('fivethirtyeight')
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, label='Training loss', linewidth=2)
    plt.plot(Epochs, val_loss, label='Validation loss', linewidth=2)
    plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy', linewidth=2)
    plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy', linewidth=2)
    plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print best epoch information with 4-digit precision
    print(f"\n{model_name} Training Summary:")
    print(f"  Best Validation Loss: {val_lowest:.4f} at epoch {index_loss + 1}")
    print(f"  Best Validation Accuracy: {acc_highest:.4f} at epoch {index_acc + 1}")
    print(f"  Final Training Accuracy: {tr_acc[-1]:.4f}")
    print(f"  Final Validation Accuracy: {val_acc[-1]:.4f}")
    print(f"  Overfitting (Train-Val): {tr_acc[-1] - val_acc[-1]:.4f}")

def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    """Plot confusion matrix with 4-digit precision"""
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    plt.style.use('default')
    
    # Calculate percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    # Create combined annotations (count and percentage)
    annotations = []
    for i in range(cm.shape[0]):
        row = []
        for j in range(cm.shape[1]):
            row.append(f'{cm[i,j]}\n({cm_percent[i,j]:.4f})')
        annotations.append(row)
    
    sns.heatmap(cm, annot=annotations, fmt='', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title(f'Confusion Matrix - {model_name}\n(Count and Proportion)', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()
    
    return cm

def generate_classification_report_4digits(y_true, y_pred, class_names, model_name):
    """Generate detailed classification report with 4-digit precision"""
    report = classification_report(y_true, y_pred, target_names=class_names, 
                                 digits=4, output_dict=True)
    
    print(f"\n{'='*80}")
    print(f"CLASSIFICATION REPORT - {model_name}")
    print(f"{'='*80}")
    
    # Print header
    print(f"{'Class':<15} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}")
    print("-" * 80)
    
    # Print per-class metrics
    for class_name in class_names:
        metrics = report[class_name]
        print(f"{class_name:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print("-" * 80)
    
    # Print averages
    for avg_type in ['macro avg', 'weighted avg']:
        metrics = report[avg_type]
        print(f"{avg_type:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print(f"\nAccuracy: {report['accuracy']:.4f}")
    print(f"{'='*80}")
    
    return report

def compile_and_train_model(model, model_name, train_gen, valid_gen, epochs=40):
    """Compile and train model with fixed callbacks (no ReduceLROnPlateau)"""
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    # Use fixed learning rate instead of schedule to avoid callback conflicts
    if 'Eye Disease' in model_name or 'ViT' in model_name:
        optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-4)
    else:
        optimizer = keras.optimizers.Adam(learning_rate=1e-4)
    
    # Compile the model
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top_2_accuracy')]
    )
    
    # Simple callbacks without ReduceLROnPlateau to avoid conflicts
    callbacks = [
        EarlyStopping(
            monitor='val_accuracy',
            patience=10,  # Increased patience since we removed ReduceLROnPlateau
            restore_best_weights=True,
            verbose=1
        )
    ]
    
    # Train model
    history = model.fit(
        train_gen,
        validation_data=valid_gen,
        epochs=40,
        verbose=1
    )
    
    # Plot individual training history
    plot_clean_training_history(history, model_name)
    
    return model, history

def measure_inference_time(model, test_gen, num_batches=10):
    """Measure inference time"""
    times = []
    
    for i, (x_batch, y_batch) in enumerate(test_gen):
        if i >= num_batches:
            break
        
        start_time = time.time()
        _ = model.predict(x_batch, verbose=0)
        end_time = time.time()
        
        times.append(end_time - start_time)
    
    avg_time_per_batch = np.mean(times)
    avg_time_per_image = avg_time_per_batch / batch_size
    
    return avg_time_per_batch, avg_time_per_image

def plot_combined_training_histories(histories):
    """Combined training histories visualization"""
    plt.figure(figsize=(20, 12))
    plt.style.use('fivethirtyeight')
    
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FECA57', '#FF9FF3']
    
    # Training Loss
    plt.subplot(2, 2, 1)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['loss']))]
        plt.plot(epochs, history.history['loss'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Loss
    plt.subplot(2, 2, 2)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_loss']))]
        val_loss = history.history['val_loss']
        plt.plot(epochs, val_loss, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmin(val_loss) + 1
        best_loss = min(val_loss)
        plt.scatter(best_epoch, best_loss, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Training Accuracy
    plt.subplot(2, 2, 3)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['accuracy']))]
        plt.plot(epochs, history.history['accuracy'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Accuracy
    plt.subplot(2, 2, 4)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_accuracy']))]
        val_acc = history.history['val_accuracy']
        plt.plot(epochs, val_acc, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmax(val_acc) + 1
        best_acc = max(val_acc)
        plt.scatter(best_epoch, best_acc, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_comprehensive_results(results):
    """Comprehensive results visualization with 4-digit precision"""
    fig, axes = plt.subplots(3, 3, figsize=(20, 18))
    plt.style.use('default')
    
    models = list(results.keys())
    colors = plt.cm.Set3(np.linspace(0, 1, len(models)))
    
    # Test Accuracy Comparison
    test_accs = [results[model]['test_accuracy'] for model in models]
    bars1 = axes[0, 0].bar(models, test_accs, color=colors)
    axes[0, 0].set_title('Test Accuracy Comparison', fontsize=14, fontweight='bold')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].set_ylim(0, 1)
    axes[0, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(test_accs):
        axes[0, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Parameters vs Accuracy
    params = [results[model]['parameters'] / 1e6 for model in models]
    scatter = axes[0, 1].scatter(params, test_accs, s=150, c=colors, alpha=0.7)
    axes[0, 1].set_title('Parameters vs Test Accuracy', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Parameters (Millions)')
    axes[0, 1].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[0, 1].annotate(model, (params[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Inference Time Comparison
    inf_times = [results[model]['inference_time_per_image'] * 1000 for model in models]
    bars2 = axes[0, 2].bar(models, inf_times, color=colors)
    axes[0, 2].set_title('Inference Time per Image', fontsize=14, fontweight='bold')
    axes[0, 2].set_ylabel('Time (ms)')
    axes[0, 2].tick_params(axis='x', rotation=45)
    for i, v in enumerate(inf_times):
        axes[0, 2].text(i, v + max(inf_times)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # F1-Score Comparison
    f1_scores = [results[model]['f1_macro'] for model in models]
    bars3 = axes[1, 0].bar(models, f1_scores, color=colors)
    axes[1, 0].set_title('F1-Score (Macro Average)', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('F1-Score')
    axes[1, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(f1_scores):
        axes[1, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Mean Average Precision
    mean_aps = [results[model]['mean_ap'] for model in models]
    bars4 = axes[1, 1].bar(models, mean_aps, color=colors)
    axes[1, 1].set_title('Mean Average Precision', fontsize=14, fontweight='bold')
    axes[1, 1].set_ylabel('mAP')
    axes[1, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(mean_aps):
        axes[1, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Precision vs Recall
    precisions = [results[model]['precision_macro'] for model in models]
    recalls = [results[model]['recall_macro'] for model in models]
    scatter = axes[1, 2].scatter(recalls, precisions, s=150, c=colors, alpha=0.7)
    axes[1, 2].set_title('Precision vs Recall', fontsize=14, fontweight='bold')
    axes[1, 2].set_xlabel('Recall (Macro)')
    axes[1, 2].set_ylabel('Precision (Macro)')
    for i, model in enumerate(models):
        axes[1, 2].annotate(model, (recalls[i], precisions[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Efficiency Score (Accuracy / Parameters)
    efficiency = [results[model]['test_accuracy'] / (results[model]['parameters'] / 1e6) for model in models]
    bars5 = axes[2, 0].bar(models, efficiency, color=colors)
    axes[2, 0].set_title('Efficiency Score (Acc/Params)', fontsize=14, fontweight='bold')
    axes[2, 0].set_ylabel('Efficiency Score')
    axes[2, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(efficiency):
        axes[2, 0].text(i, v + max(efficiency)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Top-2 Accuracy
    top2_accs = [results[model]['test_top2_accuracy'] for model in models]
    bars6 = axes[2, 1].bar(models, top2_accs, color=colors)
    axes[2, 1].set_title('Top-2 Accuracy', fontsize=14, fontweight='bold')
    axes[2, 1].set_ylabel('Top-2 Accuracy')
    axes[2, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(top2_accs):
        axes[2, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Speed vs Accuracy Trade-off
    axes[2, 2].scatter(inf_times, test_accs, s=150, c=colors, alpha=0.7)
    axes[2, 2].set_title('Speed vs Accuracy Trade-off', fontsize=14, fontweight='bold')
    axes[2, 2].set_xlabel('Inference Time (ms)')
    axes[2, 2].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[2, 2].annotate(model, (inf_times[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    plt.tight_layout()
    plt.show()

# Main execution: Train models one by one, with Eye Disease Classifier at the end
print("\n" + "="*80)
print("SEQUENTIAL MODEL TRAINING - EYE DISEASE CLASSIFICATION")
print("="*80)

# Define models in order (Eye Disease Classifier will be trained last)
models_to_train = [
    ('EfficientNet-B0', create_efficientnet),
    ('MobileNet-V2', create_mobilenet_v2), 
    ('VGG16', create_vgg16),
    ('DenseNet201', create_denseNet201),
    ('ViT Small', create_vit_small),
    ('Eye Disease Classifier', create_eye_disease_classifier)  # Your custom model last
]

# Store results
results = {}
histories = {}
trained_models = {}

# Train each model sequentially
for model_name, model_creator in models_to_train:
    print(f"\n{'='*60}")
    print(f"CREATING AND TRAINING: {model_name}")
    print(f"{'='*60}")
    
    # Create the model
    model = model_creator(num_classes)
    
    # Build the model using a real batch from train_gen if not built
    if not model.built:
        x_batch, y_batch = next(iter(train_gen))
        _ = model(x_batch)
    
    print(f"Parameters: {model.count_params():,}")
    
    # Reset generators before training
    train_gen.reset()
    valid_gen.reset()
    
    # Train model
    trained_model, history = compile_and_train_model(
        model, model_name, train_gen, valid_gen, epochs=30
    )
 
# ✅ Save model for deployment
if model_name == 'Eye Disease Classifier':
    trained_model.save('/kaggle/working/retinal_model.h5')
    print("💾 Model saved successfully as retinal_model.h5 for deployment!")

    # Store trained model and history
    trained_models[model_name] = trained_model
    histories[model_name] = history
    
    # Evaluate on test set
    test_gen.reset()
    test_loss, test_acc, test_top2_acc = trained_model.evaluate(test_gen, verbose=0)

     # ✅ Save model for deployment
    save_path = f"/kaggle/working/{model_name}_model.h5"
    trained_model.save(save_path)
    print(f"💾 {model_name} model saved successfully at {save_path}")
    
    # Get predictions for confusion matrix and classification report
    test_gen.reset()
    y_pred_probs = trained_model.predict(test_gen, verbose=0)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)
    
    # Get true labels
    y_true = test_gen.classes
    
    # Measure inference time
    test_gen.reset()
    avg_batch_time, avg_image_time = measure_inference_time(trained_model, test_gen)
    
    # Plot confusion matrix with 4-digit precision
    cm = plot_confusion_matrix(y_true, y_pred_classes, class_names, model_name)
    
    # Generate classification report with 4-digit precision
    class_report = generate_classification_report_4digits(
        y_true, y_pred_classes, class_names, model_name
    )
    
    # Plot GradCAM examples (for CNN-based models)
    if any(keyword in model_name for keyword in ['Eye Disease', 'EfficientNet', 'MobileNet', 'VGG', 'DenseNet201', 'MobileNet_v2']):
        #plot_gradcam_examples(trained_model, test_gen, class_names, model_name)
        pass
    
    # Calculate precision-recall curves
    y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes)
    
    # Calculate mean AP with 4-digit precision
    mean_ap = np.mean([average_precision_score(y_true_onehot[:, i], y_pred_probs[:, i]) 
                      for i in range(len(class_names))])
    
    # Store results with 4-digit precision
    results[model_name] = {
        'test_accuracy': round(test_acc, 4),
        'test_top2_accuracy': round(test_top2_acc, 4),
        'test_loss': round(test_loss, 4),
        'parameters': model.count_params(),
        'best_val_accuracy': round(max(history.history['val_accuracy']), 4),
        'mean_ap': round(mean_ap, 4),
        'precision_macro': round(class_report['macro avg']['precision'], 4),
        'recall_macro': round(class_report['macro avg']['recall'], 4),
        'f1_macro': round(class_report['macro avg']['f1-score'], 4),
        'inference_time_per_image': round(avg_image_time, 6),
        'inference_time_per_batch': round(avg_batch_time, 4)
    }
    
    print(f"\n{'='*50}")
    print(f"TEST RESULTS FOR {model_name}:")
    print(f"{'='*50}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Test Top-2 Accuracy: {test_top2_acc:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Mean AP: {mean_ap:.4f}")
    print(f"F1-Score (Macro): {class_report['macro avg']['f1-score']:.4f}")
    print(f"Precision (Macro): {class_report['macro avg']['precision']:.4f}")
    print(f"Recall (Macro): {class_report['macro avg']['recall']:.4f}")
    print(f"Inference time per image: {avg_image_time*1000:.4f} ms")
    print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
    print(f"Parameters: {model.count_params():,}")
    
    # Clean up to save memory (optional)
    if model_name != 'Eye Disease Classifier':  # Keep your custom model
        del model

# Combined visualizations after all models are trained
print(f"\n{'='*80}")
print("COMBINED TRAINING HISTORIES VISUALIZATION")
print(f"{'='*80}")
plot_combined_training_histories(histories)

# Comprehensive results visualization
print(f"\n{'='*80}")
print("COMPREHENSIVE RESULTS VISUALIZATION")
print(f"{'='*80}")
plot_comprehensive_results(results)

# Print final detailed comparison with 4-digit precision
print("\n" + "="*130)
print("COMPREHENSIVE RESULTS COMPARISON (4-DIGIT PRECISION)")
print("="*130)

results_df = pd.DataFrame(results).T
results_df = results_df.sort_values('test_accuracy', ascending=False)

print(f"{'Model':<20} {'Test Acc':<10} {'Top-2 Acc':<10} {'mAP':<10} {'F1':<10} {'Precision':<10} {'Recall':<10} {'Params(M)':<12} {'Time(ms)':<12}")
print("-" * 130)

for model_name, row in results_df.iterrows():
    print(f"{model_name:<20} "
          f"{row['test_accuracy']:<10.4f} "
          f"{row['test_top2_accuracy']:<10.4f} "
          f"{row['mean_ap']:<10.4f} "
          f"{row['f1_macro']:<10.4f} "
          f"{row['precision_macro']:<10.4f} "
          f"{row['recall_macro']:<10.4f} "
          f"{row['parameters']/1e6:<12.2f} "
          f"{row['inference_time_per_image']*1000:<12.4f}")

# Final analysis and recommendations
print("\n" + "="*130)
print("FINAL ANALYSIS AND RECOMMENDATIONS")
print("="*130)

best_model = results_df.index[0]
efficiency_scores = results_df['test_accuracy'] / (results_df['parameters'] / 1e6)
most_efficient = efficiency_scores.idxmax()
fastest = results_df['inference_time_per_image'].idxmin()

print(f"🏆 BEST OVERALL PERFORMANCE: {best_model}")
print(f"   → Test Accuracy: {results_df.loc[best_model, 'test_accuracy']:.4f}")
print(f"   → F1-Score: {results_df.loc[best_model, 'f1_macro']:.4f}")
print(f"   → mAP: {results_df.loc[best_model, 'mean_ap']:.4f}")
print(f"   → Parameters: {results_df.loc[best_model, 'parameters']/1e6:.2f}M")

print(f"\n⚡ MOST EFFICIENT: {most_efficient}")
print(f"   → Efficiency Score: {efficiency_scores[most_efficient]:.4f}")
print(f"   → Test Accuracy: {results_df.loc[most_efficient, 'test_accuracy']:.4f}")
print(f"   → Parameters: {results_df.loc[most_efficient, 'parameters']/1e6:.2f}M")

print(f"\n🚀 FASTEST INFERENCE: {fastest}")
print(f"   → Inference Time: {results_df.loc[fastest, 'inference_time_per_image']*1000:.4f} ms")
print(f"   → Test Accuracy: {results_df.loc[fastest, 'test_accuracy']:.4f}")
print(f"   → FPS: {1/results_df.loc[fastest, 'inference_time_per_image']:.1f}")

# Eye Disease Classifier specific analysis
if 'Eye Disease Classifier' in results_df.index:
    eye_model_results = results_df.loc['Eye Disease Classifier']
    print(f"\n🔬 YOUR EYE DISEASE CLASSIFIER ANALYSIS:")
    print(f"   → Test Accuracy: {eye_model_results['test_accuracy']:.4f}")
    print(f"   → F1-Score: {eye_model_results['f1_macro']:.4f}")
    print(f"   → Mean AP: {eye_model_results['mean_ap']:.4f}")
    print(f"   → Efficiency: {efficiency_scores['Eye Disease Classifier']:.4f}")
    print(f"   → Inference Time: {eye_model_results['inference_time_per_image']*1000:.4f} ms")
    print(f"   → Rank by Accuracy: {list(results_df.index).index('Eye Disease Classifier') + 1}/{len(results_df)}")

# Save comprehensive results
results_df.to_csv('eye_disease_comprehensive_results.csv')
print(f"\n📊 Results saved to: eye_disease_comprehensive_results.csv")
print(f"\n{'='*130}")
print("ANALYSIS COMPLETE - ALL MODELS TRAINED SEQUENTIALLY")
print(f"{'='*130}")
