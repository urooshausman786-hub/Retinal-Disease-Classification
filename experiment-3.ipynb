# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import os
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0, ResNet50, DenseNet201, MobileNet, MobileNetV2, VGG16
from tensorflow.keras.optimizers import AdamW, Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import math
import itertools
import cv2

# Data loading
data_dir = r"/kaggle/input/eye-diseases-classification/dataset"
filepaths = []
labels = []
folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis=1)

print("Class distribution:")
print(df['labels'].value_counts())
print(f"Number of unique classes: {df['labels'].nunique()}")

# Split data
train_df, dummy_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=42)
valid_df, test_df = train_test_split(dummy_df, train_size=0.6, shuffle=True, random_state=42)

print(f"Train samples: {len(train_df)}")
print(f"Valid samples: {len(valid_df)}")
print(f"Test samples: {len(test_df)}")

# Create data generators
batch_size = 32
img_size = (224, 224)
channels = 3

tr_gen = ImageDataGenerator(rescale=1./255)
ts_gen = ImageDataGenerator(rescale=1./255)

train_gen = tr_gen.flow_from_dataframe(
    train_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
valid_gen = ts_gen.flow_from_dataframe(
    valid_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=True, batch_size=batch_size
)
test_gen = ts_gen.flow_from_dataframe(
    test_df, x_col='filepaths', y_col='labels', 
    target_size=img_size, class_mode='categorical',
    color_mode='rgb', shuffle=False, batch_size=batch_size
)

# Get number of classes
num_classes = 4
class_names = list(train_gen.class_indices.keys())
print(f"Classes: {class_names}")

# Multiscale Attention Layer for Eye Disease Classifier
class MultiscaleAttentionLayer(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(MultiscaleAttentionLayer, self).__init__(**kwargs)
        self.filters = filters
        
    def build(self, input_shape):
        # Channel attention
        self.channel_attention = keras.Sequential([
            layers.GlobalAveragePooling2D(),
            layers.Dense(self.filters // 8, activation='relu'),
            layers.Dense(self.filters, activation='sigmoid'),
            layers.Reshape((1, 1, self.filters))
        ])
        
        # Spatial attention
        self.spatial_attention = keras.Sequential([
            layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')
        ])
        
        super(MultiscaleAttentionLayer, self).build(input_shape)
    
    def call(self, inputs):
        # Channel attention
        channel_att = self.channel_attention(inputs)
        x = layers.Multiply()([inputs, channel_att])
        
        # Spatial attention
        avg_pool = tf.reduce_mean(x, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(x, axis=-1, keepdims=True)
        spatial_input = layers.Concatenate()([avg_pool, max_pool])
        spatial_att = self.spatial_attention(spatial_input)
        x = layers.Multiply()([x, spatial_att])
        
        return x
    
    def get_config(self):
        config = super(MultiscaleAttentionLayer, self).get_config()
        config.update({'filters': self.filters})
        return config

# Eye Disease Classifier
def create_eye_disease_classifier(num_classes):
    """
    Create Eye Disease Classifier with VGG16 base and multiscale attention
    """
    try:
        # Load pre-trained VGG16
        base_model = VGG16(
            weights='imagenet',
            include_top=False,
            input_shape=(224, 224, 3)
        )
        
        # Freeze early layers, unfreeze last few blocks for fine-tuning
        for layer in base_model.layers[:-4]:
            layer.trainable = False
        for layer in base_model.layers[-4:]:
            layer.trainable = True
            
        # Build the complete model
        inputs = keras.Input(shape=(224, 224, 3), name='input_image')
        
        # VGG16 feature extraction
        x = base_model(inputs, training=False)
        
        # Get the number of filters from VGG16 output
        vgg_output_filters = x.shape[-1]
        
        # Multiscale attention mechanism
        x = MultiscaleAttentionLayer(filters=vgg_output_filters, name='multiscale_attention')(x)
        
        # Global Average Pooling
        x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
        
        # Dropout for regularization
        x = layers.Dropout(0.5, name='dropout_1')(x)
        
        # Dense layer with batch normalization
        x = layers.Dense(256, activation='relu', name='dense_1')(x)
        x = layers.BatchNormalization(name='batch_norm')(x)
        x = layers.Dropout(0.25, name='dropout_2')(x)
        
        # Output layer with softmax activation
        predictions = layers.Dense(num_classes, activation='softmax', name='predictions')(x)
        
        # Create the model
        model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier')
        
        print(f"Eye Disease Classifier built successfully with {model.count_params()} parameters")
        return model
        
    except Exception as e:
        print(f"Error building model: {str(e)}")
        print("Building simplified model...")
        return create_eye_disease_classifier_simplified(num_classes)

def create_eye_disease_classifier_simplified(num_classes):
    """
    Build a simplified model without custom layers as fallback
    """
    # Load pre-trained VGG16
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    # Freeze early layers
    for layer in base_model.layers[:-4]:
        layer.trainable = False
    for layer in base_model.layers[-4:]:
        layer.trainable = True
        
    # Build simplified model
    inputs = keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    
    # Simple attention using Global Average Pooling and Dense layers
    gap = layers.GlobalAveragePooling2D()(x)
    attention_weights = layers.Dense(x.shape[-1], activation='sigmoid')(gap)
    attention_weights = layers.Reshape((1, 1, x.shape[-1]))(attention_weights)
    x = layers.Multiply()([x, attention_weights])
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.25)(x)
    predictions = layers.Dense(num_classes, activation='softmax')(x)
    
    model = keras.Model(inputs, predictions, name='EyeDiseaseClassifier_Simplified')
    
    print(f"Simplified Eye Disease Classifier built successfully with {model.count_params()} parameters")
    return model

# ViT Small Implementation
class PatchEmbedding(layers.Layer):
    def __init__(self, patch_size=16, embed_dim=384):
        super().__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.projection = layers.Conv2D(
            embed_dim, kernel_size=patch_size, strides=patch_size, padding='valid'
        )
        
    def call(self, x):
        batch_size = tf.shape(x)[0]
        patches = self.projection(x)
        patches = tf.reshape(patches, [batch_size, -1, self.embed_dim])
        return patches

class MultiHeadAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        
        self.qkv = layers.Dense(embed_dim * 3)
        self.projection = layers.Dense(embed_dim)
        
    def call(self, x):
        batch_size, seq_len, embed_dim = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        
        qkv = self.qkv(x)
        qkv = tf.reshape(qkv, [batch_size, seq_len, 3, self.num_heads, self.head_dim])
        qkv = tf.transpose(qkv, [2, 0, 3, 1, 4])
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = tf.cast(self.head_dim, tf.float32) ** -0.5
        attn = tf.matmul(q, k, transpose_b=True) * scale
        attn = tf.nn.softmax(attn, axis=-1)
        
        out = tf.matmul(attn, v)
        out = tf.transpose(out, [0, 2, 1, 3])
        out = tf.reshape(out, [batch_size, seq_len, embed_dim])
        
        return self.projection(out)

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, mlp_ratio=4.0, dropout=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.attn = MultiHeadAttention(embed_dim, num_heads)
        self.dropout1 = layers.Dropout(dropout)
        
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        mlp_hidden_dim = int(embed_dim * mlp_ratio)
        self.mlp = keras.Sequential([
            layers.Dense(mlp_hidden_dim, activation='gelu'),
            layers.Dropout(dropout),
            layers.Dense(embed_dim),
            layers.Dropout(dropout)
        ])
        
    def call(self, x, training=None):
        attn_out = self.attn(self.norm1(x))
        x = x + self.dropout1(attn_out, training=training)
        
        mlp_out = self.mlp(self.norm2(x), training=training)
        x = x + mlp_out
        
        return x

class VisionTransformerSmall(keras.Model):
    def __init__(self, 
                 img_size=224,
                 patch_size=16, 
                 num_classes=4,
                 embed_dim=384,
                 depth=12,
                 num_heads=6,
                 mlp_ratio=4.0,
                 dropout=0.1):
        super().__init__()
        
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        
        self.patch_embed = PatchEmbedding(patch_size, embed_dim)
        
        self.class_token = self.add_weight(
            shape=(1, 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='class_token'
        )
        
        self.pos_embed = self.add_weight(
            shape=(1, self.num_patches + 1, embed_dim),
            initializer='random_normal',
            trainable=True,
            name='pos_embed'
        )
        
        self.dropout = layers.Dropout(dropout)
        
        self.blocks = [
            TransformerBlock(embed_dim, num_heads, mlp_ratio, dropout)
            for _ in range(depth)
        ]
        
        self.norm = layers.LayerNormalization(epsilon=1e-6)
        self.head = layers.Dense(num_classes)
        
    def call(self, x, training=None):
        batch_size = tf.shape(x)[0]
        
        x = self.patch_embed(x)
        
        class_tokens = tf.broadcast_to(self.class_token, [batch_size, 1, tf.shape(self.class_token)[-1]])
        x = tf.concat([class_tokens, x], axis=1)
        
        x = x + self.pos_embed
        x = self.dropout(x, training=training)
        
        for block in self.blocks:
            x = block(x, training=training)
            
        x = self.norm(x)
        
        class_token_final = x[:, 0]
        return self.head(class_token_final)

def create_vit_small(num_classes):
    return VisionTransformerSmall(
        img_size=224,
        patch_size=16,
        num_classes=num_classes,
        embed_dim=384,
        depth=12,
        num_heads=6,
        mlp_ratio=4.0,
        dropout=0.1
    )

# Other model creation functions
def create_efficientnet(num_classes):
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_vgg16(num_classes):
    base_model = VGG16(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_denseNet201(num_classes):
    base_model = DenseNet201(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

def create_mobilenet_v2(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )
    
    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

# GradCAM implementation
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Generate GradCAM heatmap"""
    try:
        # Create a model that maps the input image to the activations of the last conv layer
        grad_model = tf.keras.models.Model(
            [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
        )
        
        # Compute the gradient of the top predicted class
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Gradient of the output neuron with regard to the output feature map
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Mean intensity of the gradient over a specific feature map channel
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Multiply each channel by "how important this channel is"
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize the heatmap between 0 & 1
        heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
        return heatmap.numpy()
    except Exception as e:
        print(f"GradCAM error: {e}")
        return None

# Fixed GradCAM implementation with proper layer detection

def get_last_conv_layer_name(model, model_name):
    """Enhanced function to get the last convolutional layer name"""
    conv_layers = []
    
    def collect_conv_layers(layer_or_model, prefix=""):
        """Recursively collect all conv layer names"""
        if hasattr(layer_or_model, 'layers'):
            for layer in layer_or_model.layers:
                layer_name = f"{prefix}{layer.name}" if prefix else layer.name
                
                # Check if it's a conv layer
                if any(conv_type in layer.__class__.__name__.lower() for conv_type in ['conv2d', 'separableconv2d', 'depthwiseconv2d']):
                    conv_layers.append(layer_name)
                
                # Recursively check sublayers
                collect_conv_layers(layer, prefix=f"{layer_name}/")
    
    # Start collection from the model
    collect_conv_layers(model)
    
    # If no conv layers found directly, try to access base model
    if not conv_layers:
        try:
            # For Sequential models
            if hasattr(model, 'layers') and len(model.layers) > 0:
                first_layer = model.layers[0]
                if hasattr(first_layer, 'layers'):
                    collect_conv_layers(first_layer)
        except:
            pass
    
    # Print available conv layers for debugging
    print(f"Available conv layers in {model_name}: {conv_layers[-5:]}")  # Show last 5
    
    # Return the last conv layer found
    return conv_layers[-1] if conv_layers else None

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    """Enhanced GradCAM with better error handling"""
    try:
        # Handle nested layer names (e.g., "base_model/block5_conv3")
        if '/' in last_conv_layer_name:
            layer_parts = last_conv_layer_name.split('/')
            current_layer = model
            
            # Navigate through nested layers
            for part in layer_parts:
                if hasattr(current_layer, 'get_layer'):
                    current_layer = current_layer.get_layer(part)
                elif hasattr(current_layer, 'layers'):
                    # Find layer by name in layers list
                    found = False
                    for layer in current_layer.layers:
                        if layer.name == part:
                            current_layer = layer
                            found = True
                            break
                    if not found:
                        raise ValueError(f"Layer {part} not found")
                else:
                    raise ValueError(f"Cannot navigate to layer {part}")
            
            target_layer = current_layer
        else:
            # Simple case - direct layer access
            target_layer = model.get_layer(last_conv_layer_name)
        
        # Create gradient model
        grad_model = tf.keras.models.Model(
            [model.inputs], 
            [target_layer.output, model.output]
        )
        
        # Compute gradients
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]
        
        # Get gradients
        grads = tape.gradient(class_channel, last_conv_layer_output)
        
        # Handle None gradients
        if grads is None:
            print(f"Warning: No gradients computed for layer {last_conv_layer_name}")
            return None
        
        # Compute importance weights
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
        
        # Generate heatmap
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)
        
        # Normalize heatmap
        heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-10)
        return heatmap.numpy()
        
    except Exception as e:
        print(f"GradCAM failed for {last_conv_layer_name}: {str(e)}")
        return None

def plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples=4):
    """Fixed GradCAM plotting with fallback strategies"""
    print(f"\nGenerating GradCAM for {model_name}...")
    
    # Get last conv layer with enhanced detection
    last_conv_layer = get_last_conv_layer_name(model, model_name)
    
    if not last_conv_layer:
        print(f"No convolutional layers found in {model_name} - skipping GradCAM")
        return
    
    print(f"Using layer: {last_conv_layer}")
    
    # Try alternative layers if the first one fails
    alternative_layers = []
    if 'vgg16' in last_conv_layer.lower():
        alternative_layers = ['block5_conv3', 'block5_conv2', 'block4_conv3']
    elif 'efficientnet' in model_name.lower():
        alternative_layers = ['top_activation', 'top_conv', 'block7a_expand_activation']
    elif 'mobilenet' in model_name.lower():
        alternative_layers = ['out_relu', 'Conv_1', 'block_16_depthwise']
    
    successful_layer = None
    test_heatmap = None
    
    # Test the primary layer
    test_gen.reset()
    test_images, test_labels = next(iter(test_gen))
    test_img = np.expand_dims(test_images[0], axis=0)
    
    test_heatmap = make_gradcam_heatmap(test_img, model, last_conv_layer, pred_index=0)
    if test_heatmap is not None:
        successful_layer = last_conv_layer
    else:
        # Try alternative layers
        for alt_layer in alternative_layers:
            try:
                test_heatmap = make_gradcam_heatmap(test_img, model, alt_layer, pred_index=0)
                if test_heatmap is not None:
                    successful_layer = alt_layer
                    print(f"Using alternative layer: {alt_layer}")
                    break
            except:
                continue
    
    if successful_layer is None:
        print(f"All GradCAM attempts failed for {model_name}")
        return
    
    # Plot GradCAM examples
    plt.figure(figsize=(20, 10))
    plt.suptitle(f'GradCAM Visualizations - {model_name} (Layer: {successful_layer})', 
                 fontsize=16, fontweight='bold')
    
    test_gen.reset()
    images, labels = next(iter(test_gen))
    
    for i in range(min(num_examples, len(images))):
        img_array = np.expand_dims(images[i], axis=0)
        
        # Make prediction
        preds = model.predict(img_array, verbose=0)
        pred_class = np.argmax(preds[0])
        true_class = np.argmax(labels[i])
        confidence = np.max(preds[0])
        
        # Generate heatmap
        heatmap = make_gradcam_heatmap(img_array, model, successful_layer, pred_class)
        
        # Plot original
        plt.subplot(2, num_examples, i + 1)
        plt.imshow(images[i])
        plt.title(f'Original\nTrue: {class_names[true_class]}', fontsize=10)
        plt.axis('off')
        
        # Plot GradCAM
        plt.subplot(2, num_examples, i + 1 + num_examples)
        plt.imshow(images[i])
        if heatmap is not None:
            # Resize heatmap to match image size
            heatmap_resized = cv2.resize(heatmap, (224, 224))
            plt.imshow(heatmap_resized, alpha=0.4, cmap='jet')
            status = "Success"
        else:
            status = "Failed"
        
        plt.title(f'GradCAM ({status})\nPred: {class_names[pred_class]}\nConf: {confidence:.3f}', 
                 fontsize=10)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

def debug_model_structure(model, model_name):
    """Debug function to understand model structure"""
    print(f"\n=== MODEL STRUCTURE DEBUG: {model_name} ===")
    
    def print_layers(layer_or_model, indent=0):
        prefix = "  " * indent
        if hasattr(layer_or_model, 'layers'):
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
            for i, layer in enumerate(layer_or_model.layers):
                print(f"{prefix}├─ [{i}] {layer.__class__.__name__}: {layer.name}")
                if hasattr(layer, 'layers') and len(layer.layers) > 0:
                    print_layers(layer, indent + 1)
        else:
            print(f"{prefix}{layer_or_model.__class__.__name__}: {getattr(layer_or_model, 'name', 'unnamed')}")
    
    print_layers(model)
    print("=" * 50)

# Modified plotting function call in main training loop
def plot_gradcam_examples(model, test_gen, class_names, model_name, num_examples=4):
    """Wrapper function that includes debugging"""
    # Debug model structure first
    debug_model_structure(model, model_name)
    
    # Use the fixed GradCAM implementation
    plot_gradcam_examples_fixed(model, test_gen, class_names, model_name, num_examples)

# Additional helper function to manually specify conv layer names
def get_manual_conv_layer_mapping():
    """Manual mapping for problematic models"""
    return {
        'EfficientNet-B0': ['efficientnetb0/block6a_expand_conv', 'efficientnetb0/top_conv'],
        'MobileNet-V2': ['mobilenetv2_1.00_224/block_16_depthwise', 'mobilenetv2_1.00_224/Conv_1'],
        'VGG16': ['vgg16/block5_conv3', 'vgg16/block5_conv2'],
        'DenseNet201': ['densenet201/conv5_block32_2_conv', 'densenet201/conv5_block32_concat'],
        'Eye Disease Classifier': ['vgg16/block5_conv3', 'multiscale_attention']
    }
# Enhanced visualization functions
def plot_clean_training_history(history, model_name):
    """Plot clean training history with 4-digit precision"""
    tr_acc = history.history['accuracy']
    tr_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    
    # Find best epochs
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    # Plot training history
    plt.figure(figsize=(15, 8))
    plt.style.use('fivethirtyeight')
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, label='Training loss', linewidth=2)
    plt.plot(Epochs, val_loss, label='Validation loss', linewidth=2)
    plt.scatter(index_loss + 1, val_lowest, s=150, c='blue', label=loss_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy', linewidth=2)
    plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy', linewidth=2)
    plt.scatter(index_acc + 1, acc_highest, s=150, c='blue', label=acc_label, zorder=5)
    plt.title(f'{model_name} - Training and Validation Accuracy', fontsize=14, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print best epoch information with 4-digit precision
    print(f"\n{model_name} Training Summary:")
    print(f"  Best Validation Loss: {val_lowest:.4f} at epoch {index_loss + 1}")
    print(f"  Best Validation Accuracy: {acc_highest:.4f} at epoch {index_acc + 1}")
    print(f"  Final Training Accuracy: {tr_acc[-1]:.4f}")
    print(f"  Final Validation Accuracy: {val_acc[-1]:.4f}")
    print(f"  Overfitting (Train-Val): {tr_acc[-1] - val_acc[-1]:.4f}")

def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    """Plot confusion matrix with 4-digit precision"""
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    plt.style.use('default')
    
    # Calculate percentages
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    # Create combined annotations (count and percentage)
    annotations = []
    for i in range(cm.shape[0]):
        row = []
        for j in range(cm.shape[1]):
            row.append(f'{cm[i,j]}\n({cm_percent[i,j]:.4f})')
        annotations.append(row)
    
    sns.heatmap(cm, annot=annotations, fmt='', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title(f'Confusion Matrix - {model_name}\n(Count and Proportion)', fontsize=14, fontweight='bold')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()
    
    return cm

def generate_classification_report_4digits(y_true, y_pred, class_names, model_name):
    """Generate detailed classification report with 4-digit precision"""
    report = classification_report(y_true, y_pred, target_names=class_names, 
                                 digits=4, output_dict=True)
    
    print(f"\n{'='*80}")
    print(f"CLASSIFICATION REPORT - {model_name}")
    print(f"{'='*80}")
    
    # Print header
    print(f"{'Class':<15} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}")
    print("-" * 80)
    
    # Print per-class metrics
    for class_name in class_names:
        metrics = report[class_name]
        print(f"{class_name:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print("-" * 80)
    
    # Print averages
    for avg_type in ['macro avg', 'weighted avg']:
        metrics = report[avg_type]
        print(f"{avg_type:<15} "
              f"{metrics['precision']:<12.4f} "
              f"{metrics['recall']:<12.4f} "
              f"{metrics['f1-score']:<12.4f} "
              f"{int(metrics['support']):<10}")
    
    print(f"\nAccuracy: {report['accuracy']:.4f}")
    print(f"{'='*80}")
    
    return report

def compile_and_train_model(model, model_name, train_gen, valid_gen, epochs=40):
    """Compile and train model with fixed callbacks (no ReduceLROnPlateau)"""
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    # Use fixed learning rate instead of schedule to avoid callback conflicts
    if 'Eye Disease' in model_name or 'ViT' in model_name:
        optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-4)
    else:
        optimizer = keras.optimizers.Adam(learning_rate=1e-4)
    
    # Compile the model
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top_2_accuracy')]
    )
    
    # Simple callbacks without ReduceLROnPlateau to avoid conflicts
    callbacks = [
        EarlyStopping(
            monitor='val_accuracy',
            patience=10,  # Increased patience since we removed ReduceLROnPlateau
            restore_best_weights=True,
            verbose=1
        )
    ]
    
    # Train model
    history = model.fit(
        train_gen,
        validation_data=valid_gen,
        epochs=40,
        verbose=1
    )
    
    # Plot individual training history
    plot_clean_training_history(history, model_name)
    
    return model, history

def measure_inference_time(model, test_gen, num_batches=10):
    """Measure inference time"""
    times = []
    
    for i, (x_batch, y_batch) in enumerate(test_gen):
        if i >= num_batches:
            break
        
        start_time = time.time()
        _ = model.predict(x_batch, verbose=0)
        end_time = time.time()
        
        times.append(end_time - start_time)
    
    avg_time_per_batch = np.mean(times)
    avg_time_per_image = avg_time_per_batch / batch_size
    
    return avg_time_per_batch, avg_time_per_image

def plot_combined_training_histories(histories):
    """Combined training histories visualization"""
    plt.figure(figsize=(20, 12))
    plt.style.use('fivethirtyeight')
    
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FECA57', '#FF9FF3']
    
    # Training Loss
    plt.subplot(2, 2, 1)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['loss']))]
        plt.plot(epochs, history.history['loss'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Loss
    plt.subplot(2, 2, 2)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_loss']))]
        val_loss = history.history['val_loss']
        plt.plot(epochs, val_loss, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmin(val_loss) + 1
        best_loss = min(val_loss)
        plt.scatter(best_epoch, best_loss, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Loss Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Training Accuracy
    plt.subplot(2, 2, 3)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['accuracy']))]
        plt.plot(epochs, history.history['accuracy'], 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
    plt.title('Training Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Accuracy
    plt.subplot(2, 2, 4)
    for idx, (model_name, history) in enumerate(histories.items()):
        epochs = [i+1 for i in range(len(history.history['val_accuracy']))]
        val_acc = history.history['val_accuracy']
        plt.plot(epochs, val_acc, 
                color=colors[idx % len(colors)], linewidth=2, label=model_name)
        
        # Mark best epoch
        best_epoch = np.argmax(val_acc) + 1
        best_acc = max(val_acc)
        plt.scatter(best_epoch, best_acc, 
                   color=colors[idx % len(colors)], s=100, zorder=5)
        
    plt.title('Validation Accuracy Comparison', fontsize=16, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_comprehensive_results(results):
    """Comprehensive results visualization with 4-digit precision"""
    fig, axes = plt.subplots(3, 3, figsize=(20, 18))
    plt.style.use('default')
    
    models = list(results.keys())
    colors = plt.cm.Set3(np.linspace(0, 1, len(models)))
    
    # Test Accuracy Comparison
    test_accs = [results[model]['test_accuracy'] for model in models]
    bars1 = axes[0, 0].bar(models, test_accs, color=colors)
    axes[0, 0].set_title('Test Accuracy Comparison', fontsize=14, fontweight='bold')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].set_ylim(0, 1)
    axes[0, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(test_accs):
        axes[0, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Parameters vs Accuracy
    params = [results[model]['parameters'] / 1e6 for model in models]
    scatter = axes[0, 1].scatter(params, test_accs, s=150, c=colors, alpha=0.7)
    axes[0, 1].set_title('Parameters vs Test Accuracy', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Parameters (Millions)')
    axes[0, 1].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[0, 1].annotate(model, (params[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Inference Time Comparison
    inf_times = [results[model]['inference_time_per_image'] * 1000 for model in models]
    bars2 = axes[0, 2].bar(models, inf_times, color=colors)
    axes[0, 2].set_title('Inference Time per Image', fontsize=14, fontweight='bold')
    axes[0, 2].set_ylabel('Time (ms)')
    axes[0, 2].tick_params(axis='x', rotation=45)
    for i, v in enumerate(inf_times):
        axes[0, 2].text(i, v + max(inf_times)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # F1-Score Comparison
    f1_scores = [results[model]['f1_macro'] for model in models]
    bars3 = axes[1, 0].bar(models, f1_scores, color=colors)
    axes[1, 0].set_title('F1-Score (Macro Average)', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('F1-Score')
    axes[1, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(f1_scores):
        axes[1, 0].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Mean Average Precision
    mean_aps = [results[model]['mean_ap'] for model in models]
    bars4 = axes[1, 1].bar(models, mean_aps, color=colors)
    axes[1, 1].set_title('Mean Average Precision', fontsize=14, fontweight='bold')
    axes[1, 1].set_ylabel('mAP')
    axes[1, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(mean_aps):
        axes[1, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Precision vs Recall
    precisions = [results[model]['precision_macro'] for model in models]
    recalls = [results[model]['recall_macro'] for model in models]
    scatter = axes[1, 2].scatter(recalls, precisions, s=150, c=colors, alpha=0.7)
    axes[1, 2].set_title('Precision vs Recall', fontsize=14, fontweight='bold')
    axes[1, 2].set_xlabel('Recall (Macro)')
    axes[1, 2].set_ylabel('Precision (Macro)')
    for i, model in enumerate(models):
        axes[1, 2].annotate(model, (recalls[i], precisions[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # Efficiency Score (Accuracy / Parameters)
    efficiency = [results[model]['test_accuracy'] / (results[model]['parameters'] / 1e6) for model in models]
    bars5 = axes[2, 0].bar(models, efficiency, color=colors)
    axes[2, 0].set_title('Efficiency Score (Acc/Params)', fontsize=14, fontweight='bold')
    axes[2, 0].set_ylabel('Efficiency Score')
    axes[2, 0].tick_params(axis='x', rotation=45)
    for i, v in enumerate(efficiency):
        axes[2, 0].text(i, v + max(efficiency)*0.02, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Top-2 Accuracy
    top2_accs = [results[model]['test_top2_accuracy'] for model in models]
    bars6 = axes[2, 1].bar(models, top2_accs, color=colors)
    axes[2, 1].set_title('Top-2 Accuracy', fontsize=14, fontweight='bold')
    axes[2, 1].set_ylabel('Top-2 Accuracy')
    axes[2, 1].tick_params(axis='x', rotation=45)
    for i, v in enumerate(top2_accs):
        axes[2, 1].text(i, v + 0.01, f'{v:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Speed vs Accuracy Trade-off
    axes[2, 2].scatter(inf_times, test_accs, s=150, c=colors, alpha=0.7)
    axes[2, 2].set_title('Speed vs Accuracy Trade-off', fontsize=14, fontweight='bold')
    axes[2, 2].set_xlabel('Inference Time (ms)')
    axes[2, 2].set_ylabel('Test Accuracy')
    for i, model in enumerate(models):
        axes[2, 2].annotate(model, (inf_times[i], test_accs[i]), 
                           xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    plt.tight_layout()
    plt.show()

# Main execution: Train models one by one, with Eye Disease Classifier at the end
print("\n" + "="*80)
print("SEQUENTIAL MODEL TRAINING - EYE DISEASE CLASSIFICATION")
print("="*80)

# Define models in order (Eye Disease Classifier will be trained last)
models_to_train = [
    ('EfficientNet-B0', create_efficientnet),
    ('MobileNet-V2', create_mobilenet_v2), 
    ('VGG16', create_vgg16),
    ('DenseNet201', create_denseNet201),
    ('ViT Small', create_vit_small),
    ('Eye Disease Classifier', create_eye_disease_classifier)  # Your custom model last
]

# Store results
results = {}
histories = {}
trained_models = {}

# Train each model sequentially
for model_name, model_creator in models_to_train:
    print(f"\n{'='*60}")
    print(f"CREATING AND TRAINING: {model_name}")
    print(f"{'='*60}")
    
    # Create the model
    model = model_creator(num_classes)
    
    # Build the model using a real batch from train_gen if not built
    if not model.built:
        x_batch, y_batch = next(iter(train_gen))
        _ = model(x_batch)
    
    print(f"Parameters: {model.count_params():,}")
    
    # Reset generators before training
    train_gen.reset()
    valid_gen.reset()
    
    # Train model
    trained_model, history = compile_and_train_model(
        model, model_name, train_gen, valid_gen, epochs=30
    )
    
    # Store trained model and history
    trained_models[model_name] = trained_model
    histories[model_name] = history
    
    # Evaluate on test set
    test_gen.reset()
    test_loss, test_acc, test_top2_acc = trained_model.evaluate(test_gen, verbose=0)
    
    # Get predictions for confusion matrix and classification report
    test_gen.reset()
    y_pred_probs = trained_model.predict(test_gen, verbose=0)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)
    
    # Get true labels
    y_true = test_gen.classes
    
    # Measure inference time
    test_gen.reset()
    avg_batch_time, avg_image_time = measure_inference_time(trained_model, test_gen)
    
    # Plot confusion matrix with 4-digit precision
    cm = plot_confusion_matrix(y_true, y_pred_classes, class_names, model_name)
    
    # Generate classification report with 4-digit precision
    class_report = generate_classification_report_4digits(
        y_true, y_pred_classes, class_names, model_name
    )
    
    # Plot GradCAM examples (for CNN-based models)
    if any(keyword in model_name for keyword in ['Eye Disease', 'EfficientNet', 'MobileNet', 'VGG', 'DenseNet201', 'MobileNet_v2']):
        #plot_gradcam_examples(trained_model, test_gen, class_names, model_name)
        pass
    
    # Calculate precision-recall curves
    y_true_onehot = tf.keras.utils.to_categorical(y_true, num_classes)
    
    # Calculate mean AP with 4-digit precision
    mean_ap = np.mean([average_precision_score(y_true_onehot[:, i], y_pred_probs[:, i]) 
                      for i in range(len(class_names))])
    
    # Store results with 4-digit precision
    results[model_name] = {
        'test_accuracy': round(test_acc, 4),
        'test_top2_accuracy': round(test_top2_acc, 4),
        'test_loss': round(test_loss, 4),
        'parameters': model.count_params(),
        'best_val_accuracy': round(max(history.history['val_accuracy']), 4),
        'mean_ap': round(mean_ap, 4),
        'precision_macro': round(class_report['macro avg']['precision'], 4),
        'recall_macro': round(class_report['macro avg']['recall'], 4),
        'f1_macro': round(class_report['macro avg']['f1-score'], 4),
        'inference_time_per_image': round(avg_image_time, 6),
        'inference_time_per_batch': round(avg_batch_time, 4)
    }
    
    print(f"\n{'='*50}")
    print(f"TEST RESULTS FOR {model_name}:")
    print(f"{'='*50}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Test Top-2 Accuracy: {test_top2_acc:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Mean AP: {mean_ap:.4f}")
    print(f"F1-Score (Macro): {class_report['macro avg']['f1-score']:.4f}")
    print(f"Precision (Macro): {class_report['macro avg']['precision']:.4f}")
    print(f"Recall (Macro): {class_report['macro avg']['recall']:.4f}")
    print(f"Inference time per image: {avg_image_time*1000:.4f} ms")
    print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
    print(f"Parameters: {model.count_params():,}")
    
    # Clean up to save memory (optional)
    if model_name != 'Eye Disease Classifier':  # Keep your custom model
        del model

# Combined visualizations after all models are trained
print(f"\n{'='*80}")
print("COMBINED TRAINING HISTORIES VISUALIZATION")
print(f"{'='*80}")
plot_combined_training_histories(histories)

# Comprehensive results visualization
print(f"\n{'='*80}")
print("COMPREHENSIVE RESULTS VISUALIZATION")
print(f"{'='*80}")
plot_comprehensive_results(results)

# Print final detailed comparison with 4-digit precision
print("\n" + "="*130)
print("COMPREHENSIVE RESULTS COMPARISON (4-DIGIT PRECISION)")
print("="*130)

results_df = pd.DataFrame(results).T
results_df = results_df.sort_values('test_accuracy', ascending=False)

print(f"{'Model':<20} {'Test Acc':<10} {'Top-2 Acc':<10} {'mAP':<10} {'F1':<10} {'Precision':<10} {'Recall':<10} {'Params(M)':<12} {'Time(ms)':<12}")
print("-" * 130)

for model_name, row in results_df.iterrows():
    print(f"{model_name:<20} "
          f"{row['test_accuracy']:<10.4f} "
          f"{row['test_top2_accuracy']:<10.4f} "
          f"{row['mean_ap']:<10.4f} "
          f"{row['f1_macro']:<10.4f} "
          f"{row['precision_macro']:<10.4f} "
          f"{row['recall_macro']:<10.4f} "
          f"{row['parameters']/1e6:<12.2f} "
          f"{row['inference_time_per_image']*1000:<12.4f}")

# Final analysis and recommendations
print("\n" + "="*130)
print("FINAL ANALYSIS AND RECOMMENDATIONS")
print("="*130)

best_model = results_df.index[0]
efficiency_scores = results_df['test_accuracy'] / (results_df['parameters'] / 1e6)
most_efficient = efficiency_scores.idxmax()
fastest = results_df['inference_time_per_image'].idxmin()

print(f"🏆 BEST OVERALL PERFORMANCE: {best_model}")
print(f"   → Test Accuracy: {results_df.loc[best_model, 'test_accuracy']:.4f}")
print(f"   → F1-Score: {results_df.loc[best_model, 'f1_macro']:.4f}")
print(f"   → mAP: {results_df.loc[best_model, 'mean_ap']:.4f}")
print(f"   → Parameters: {results_df.loc[best_model, 'parameters']/1e6:.2f}M")

print(f"\n⚡ MOST EFFICIENT: {most_efficient}")
print(f"   → Efficiency Score: {efficiency_scores[most_efficient]:.4f}")
print(f"   → Test Accuracy: {results_df.loc[most_efficient, 'test_accuracy']:.4f}")
print(f"   → Parameters: {results_df.loc[most_efficient, 'parameters']/1e6:.2f}M")

print(f"\n🚀 FASTEST INFERENCE: {fastest}")
print(f"   → Inference Time: {results_df.loc[fastest, 'inference_time_per_image']*1000:.4f} ms")
print(f"   → Test Accuracy: {results_df.loc[fastest, 'test_accuracy']:.4f}")
print(f"   → FPS: {1/results_df.loc[fastest, 'inference_time_per_image']:.1f}")

# Eye Disease Classifier specific analysis
if 'Eye Disease Classifier' in results_df.index:
    eye_model_results = results_df.loc['Eye Disease Classifier']
    print(f"\n🔬 YOUR EYE DISEASE CLASSIFIER ANALYSIS:")
    print(f"   → Test Accuracy: {eye_model_results['test_accuracy']:.4f}")
    print(f"   → F1-Score: {eye_model_results['f1_macro']:.4f}")
    print(f"   → Mean AP: {eye_model_results['mean_ap']:.4f}")
    print(f"   → Efficiency: {efficiency_scores['Eye Disease Classifier']:.4f}")
    print(f"   → Inference Time: {eye_model_results['inference_time_per_image']*1000:.4f} ms")
    print(f"   → Rank by Accuracy: {list(results_df.index).index('Eye Disease Classifier') + 1}/{len(results_df)}")

# Save comprehensive results
results_df.to_csv('eye_disease_comprehensive_results.csv')
print(f"\n📊 Results saved to: eye_disease_comprehensive_results.csv")
print(f"\n{'='*130}")
print("ANALYSIS COMPLETE - ALL MODELS TRAINED SEQUENTIALLY")
print(f"{'='*130}")
# Out:
# Class distribution:
# labels
# diabetic_retinopathy    1098
# normal                  1074
# cataract                1038
# glaucoma                1007
# Name: count, dtype: int64
# Number of unique classes: 4
# Train samples: 3373
# Valid samples: 506
# Test samples: 338
# Found 3373 validated image filenames belonging to 4 classes.
# Found 506 validated image filenames belonging to 4 classes.
# Found 338 validated image filenames belonging to 4 classes.
# Classes: ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
#
# ================================================================================
# SEQUENTIAL MODEL TRAINING - EYE DISEASE CLASSIFICATION
# ================================================================================
#
# ============================================================
# CREATING AND TRAINING: EfficientNet-B0
# ============================================================
# I0000 00:00:1761993342.531408      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Parameters: 4,054,695
#
# ==================================================
# Training EfficientNet-B0
# ==================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761993404.857889     100 service.cc:148] XLA service 0x7c86540028d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761993404.858601     100 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761993410.267454     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1761993419.402879     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993419.592519     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993420.071410     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993420.278247     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993420.662439     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993420.870470     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1761993442.521245     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  83/106 ━━━━━━━━━━━━━━━━━━━━ 9s 410ms/step - accuracy: 0.6077 - loss: 0.9467 - top_2_accuracy: 0.7991
# E0000 00:00:1761993487.501642      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993487.689011      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993488.139887      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993488.347386      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993488.703133      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761993488.910386      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 190s 893ms/step - accuracy: 0.6395 - loss: 0.8829 - top_2_accuracy: 0.8228 - val_accuracy: 0.2688 - val_loss: 1.4161 - val_top_2_accuracy: 0.4802
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - accuracy: 0.9003 - loss: 0.2991 - top_2_accuracy: 0.9823 - val_accuracy: 0.3617 - val_loss: 1.5291 - val_top_2_accuracy: 0.4802
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9301 - loss: 0.1961 - top_2_accuracy: 0.9923 - val_accuracy: 0.3933 - val_loss: 1.7665 - val_top_2_accuracy: 0.5672
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 259ms/step - accuracy: 0.9485 - loss: 0.1463 - top_2_accuracy: 0.9921 - val_accuracy: 0.3439 - val_loss: 1.3681 - val_top_2_accuracy: 0.5277
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.9724 - loss: 0.1027 - top_2_accuracy: 0.9980 - val_accuracy: 0.3775 - val_loss: 1.8361 - val_top_2_accuracy: 0.6462
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9702 - loss: 0.0887 - top_2_accuracy: 0.9989 - val_accuracy: 0.5751 - val_loss: 1.1240 - val_top_2_accuracy: 0.7292
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9780 - loss: 0.0688 - top_2_accuracy: 0.9995 - val_accuracy: 0.4051 - val_loss: 1.3199 - val_top_2_accuracy: 0.7154
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9829 - loss: 0.0516 - top_2_accuracy: 0.9986 - val_accuracy: 0.5079 - val_loss: 1.1768 - val_top_2_accuracy: 0.7154
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9905 - loss: 0.0375 - top_2_accuracy: 0.9997 - val_accuracy: 0.2569 - val_loss: 2.3201 - val_top_2_accuracy: 0.4921
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 258ms/step - accuracy: 0.9914 - loss: 0.0295 - top_2_accuracy: 0.9989 - val_accuracy: 0.2510 - val_loss: 117.5835 - val_top_2_accuracy: 0.6225
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9903 - loss: 0.0257 - top_2_accuracy: 0.9994 - val_accuracy: 0.4032 - val_loss: 1.7985 - val_top_2_accuracy: 0.6996
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9952 - loss: 0.0213 - top_2_accuracy: 0.9994 - val_accuracy: 0.5573 - val_loss: 1.2768 - val_top_2_accuracy: 0.7826
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 249ms/step - accuracy: 0.9906 - loss: 0.0233 - top_2_accuracy: 0.9992 - val_accuracy: 0.2984 - val_loss: 76.1207 - val_top_2_accuracy: 0.6561
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 250ms/step - accuracy: 0.9936 - loss: 0.0214 - top_2_accuracy: 0.9998 - val_accuracy: 0.2451 - val_loss: 1.5148 - val_top_2_accuracy: 0.5850
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9924 - loss: 0.0260 - top_2_accuracy: 1.0000 - val_accuracy: 0.5375 - val_loss: 1.6122 - val_top_2_accuracy: 0.7490
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9936 - loss: 0.0197 - top_2_accuracy: 1.0000 - val_accuracy: 0.4407 - val_loss: 1.4730 - val_top_2_accuracy: 0.5296
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9938 - loss: 0.0210 - top_2_accuracy: 0.9994 - val_accuracy: 0.2747 - val_loss: 956.7263 - val_top_2_accuracy: 0.9012
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9906 - loss: 0.0262 - top_2_accuracy: 0.9990 - val_accuracy: 0.2688 - val_loss: 70.6362 - val_top_2_accuracy: 0.5198
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9956 - loss: 0.0144 - top_2_accuracy: 0.9999 - val_accuracy: 0.5455 - val_loss: 1.3432 - val_top_2_accuracy: 0.7668
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9973 - loss: 0.0083 - top_2_accuracy: 1.0000 - val_accuracy: 0.1897 - val_loss: 2.2545 - val_top_2_accuracy: 0.4427
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9951 - loss: 0.0148 - top_2_accuracy: 1.0000 - val_accuracy: 0.6166 - val_loss: 1.1561 - val_top_2_accuracy: 0.7925
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9969 - loss: 0.0081 - top_2_accuracy: 1.0000 - val_accuracy: 0.2451 - val_loss: 2.4316 - val_top_2_accuracy: 0.5099
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9966 - loss: 0.0095 - top_2_accuracy: 0.9991 - val_accuracy: 0.3399 - val_loss: 2.5410 - val_top_2_accuracy: 0.5988
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 250ms/step - accuracy: 0.9945 - loss: 0.0194 - top_2_accuracy: 1.0000 - val_accuracy: 0.2510 - val_loss: 2.8113 - val_top_2_accuracy: 0.5613
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9953 - loss: 0.0154 - top_2_accuracy: 1.0000 - val_accuracy: 0.2174 - val_loss: 11.2257 - val_top_2_accuracy: 0.4802
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9929 - loss: 0.0203 - top_2_accuracy: 0.9996 - val_accuracy: 0.2767 - val_loss: 2.9392 - val_top_2_accuracy: 0.5573
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 259ms/step - accuracy: 0.9958 - loss: 0.0102 - top_2_accuracy: 0.9998 - val_accuracy: 0.2372 - val_loss: 24.9663 - val_top_2_accuracy: 0.5079
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.9982 - loss: 0.0124 - top_2_accuracy: 1.0000 - val_accuracy: 0.5929 - val_loss: 1.1557 - val_top_2_accuracy: 0.7846
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9976 - loss: 0.0102 - top_2_accuracy: 1.0000 - val_accuracy: 0.5534 - val_loss: 1.1740 - val_top_2_accuracy: 0.7787
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9980 - loss: 0.0079 - top_2_accuracy: 1.0000 - val_accuracy: 0.2233 - val_loss: 2.8075 - val_top_2_accuracy: 0.5040
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9972 - loss: 0.0066 - top_2_accuracy: 1.0000 - val_accuracy: 0.3953 - val_loss: 2.2399 - val_top_2_accuracy: 0.6304
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - accuracy: 0.9970 - loss: 0.0093 - top_2_accuracy: 1.0000 - val_accuracy: 0.6818 - val_loss: 0.8984 - val_top_2_accuracy: 0.8419
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9967 - loss: 0.0091 - top_2_accuracy: 0.9999 - val_accuracy: 0.2115 - val_loss: 37228.7617 - val_top_2_accuracy: 1.0000
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9965 - loss: 0.0115 - top_2_accuracy: 1.0000 - val_accuracy: 0.7470 - val_loss: 1.1923 - val_top_2_accuracy: 0.9170
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.9975 - loss: 0.0088 - top_2_accuracy: 1.0000 - val_accuracy: 0.5158 - val_loss: 2.3638 - val_top_2_accuracy: 0.8340
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9956 - loss: 0.0114 - top_2_accuracy: 1.0000 - val_accuracy: 0.2668 - val_loss: 2.3683 - val_top_2_accuracy: 0.6522
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9972 - loss: 0.0071 - top_2_accuracy: 1.0000 - val_accuracy: 0.4783 - val_loss: 1.4035 - val_top_2_accuracy: 0.7885
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9963 - loss: 0.0097 - top_2_accuracy: 1.0000 - val_accuracy: 0.3933 - val_loss: 2.2079 - val_top_2_accuracy: 0.5395
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9956 - loss: 0.0122 - top_2_accuracy: 1.0000 - val_accuracy: 0.2095 - val_loss: 2.6464 - val_top_2_accuracy: 0.5000
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9969 - loss: 0.0102 - top_2_accuracy: 0.9996 - val_accuracy: 0.4012 - val_loss: 1.8027 - val_top_2_accuracy: 0.5830
# EfficientNet-B0 Training Summary:
#   Best Validation Loss: 0.8984 at epoch 32
#   Best Validation Accuracy: 0.7470 at epoch 34
#   Final Training Accuracy: 0.9961
#   Final Validation Accuracy: 0.4012
#   Overfitting (Train-Val): 0.5950
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ================================================================================
# CLASSIFICATION REPORT - EfficientNet-B0
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.2824       0.9867       0.4392       75
# diabetic_retinopathy 0.7324       0.6265       0.6753       83
# glaucoma        0.5000       0.0225       0.0430       89
# normal          1.0000       0.0110       0.0217       91
# --------------------------------------------------------------------------------
# macro avg       0.6287       0.4117       0.2948       338
# weighted avg    0.6434       0.3817       0.2805       338
#
# Accuracy: 0.3817
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR EfficientNet-B0:
# ==================================================
# Test Accuracy: 0.3817
# Test Top-2 Accuracy: 0.5592
# Test Loss: 1.8648
# Mean AP: 0.5298
# F1-Score (Macro): 0.2948
# Precision (Macro): 0.6287
# Recall (Macro): 0.4117
# Inference time per image: 26.4622 ms
# Best Validation Accuracy: 0.7470
# Parameters: 4,054,695
#
# ============================================================
# CREATING AND TRAINING: MobileNet-V2
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Parameters: 2,263,108
#
# ==================================================
# Training MobileNet-V2
# ==================================================
# Epoch 1/40
# E0000 00:00:1761994672.611362     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761994672.808548     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  93/106 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.6654 - loss: 0.8193 - top_2_accuracy: 0.8727
# E0000 00:00:1761994709.972512     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761994710.168963     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 109s 473ms/step - accuracy: 0.6818 - loss: 0.7820 - top_2_accuracy: 0.8817 - val_accuracy: 0.3024 - val_loss: 2.3570 - val_top_2_accuracy: 0.6957
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9443 - loss: 0.1644 - top_2_accuracy: 0.9964 - val_accuracy: 0.3241 - val_loss: 1.7985 - val_top_2_accuracy: 0.7036
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9755 - loss: 0.0860 - top_2_accuracy: 1.0000 - val_accuracy: 0.3735 - val_loss: 1.4960 - val_top_2_accuracy: 0.8043
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9883 - loss: 0.0465 - top_2_accuracy: 1.0000 - val_accuracy: 0.4289 - val_loss: 1.6254 - val_top_2_accuracy: 0.7846
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9929 - loss: 0.0263 - top_2_accuracy: 0.9998 - val_accuracy: 0.4209 - val_loss: 2.0133 - val_top_2_accuracy: 0.7391
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9905 - loss: 0.0329 - top_2_accuracy: 0.9994 - val_accuracy: 0.5020 - val_loss: 2.1665 - val_top_2_accuracy: 0.7727
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - accuracy: 0.9917 - loss: 0.0308 - top_2_accuracy: 0.9993 - val_accuracy: 0.5613 - val_loss: 1.9103 - val_top_2_accuracy: 0.8063
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9971 - loss: 0.0111 - top_2_accuracy: 1.0000 - val_accuracy: 0.6008 - val_loss: 1.8933 - val_top_2_accuracy: 0.8261
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9940 - loss: 0.0219 - top_2_accuracy: 1.0000 - val_accuracy: 0.5909 - val_loss: 1.8811 - val_top_2_accuracy: 0.8518
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9973 - loss: 0.0108 - top_2_accuracy: 1.0000 - val_accuracy: 0.7352 - val_loss: 1.0417 - val_top_2_accuracy: 0.9130
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9987 - loss: 0.0070 - top_2_accuracy: 1.0000 - val_accuracy: 0.7055 - val_loss: 1.3113 - val_top_2_accuracy: 0.9071
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9976 - loss: 0.0084 - top_2_accuracy: 1.0000 - val_accuracy: 0.7194 - val_loss: 1.2694 - val_top_2_accuracy: 0.9032
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9981 - loss: 0.0072 - top_2_accuracy: 1.0000 - val_accuracy: 0.7727 - val_loss: 0.9870 - val_top_2_accuracy: 0.9506
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 257ms/step - accuracy: 0.9921 - loss: 0.0319 - top_2_accuracy: 0.9997 - val_accuracy: 0.7925 - val_loss: 0.9531 - val_top_2_accuracy: 0.9447
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9929 - loss: 0.0178 - top_2_accuracy: 1.0000 - val_accuracy: 0.7648 - val_loss: 1.0375 - val_top_2_accuracy: 0.9071
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.9885 - loss: 0.0324 - top_2_accuracy: 0.9997 - val_accuracy: 0.7292 - val_loss: 1.4643 - val_top_2_accuracy: 0.8814
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9923 - loss: 0.0246 - top_2_accuracy: 1.0000 - val_accuracy: 0.7767 - val_loss: 1.1957 - val_top_2_accuracy: 0.9308
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9967 - loss: 0.0119 - top_2_accuracy: 1.0000 - val_accuracy: 0.8182 - val_loss: 0.8444 - val_top_2_accuracy: 0.9447
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9966 - loss: 0.0129 - top_2_accuracy: 1.0000 - val_accuracy: 0.8419 - val_loss: 0.6299 - val_top_2_accuracy: 0.9723
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 249ms/step - accuracy: 0.9972 - loss: 0.0069 - top_2_accuracy: 0.9997 - val_accuracy: 0.8755 - val_loss: 0.5642 - val_top_2_accuracy: 0.9723
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9997 - loss: 0.0020 - top_2_accuracy: 1.0000 - val_accuracy: 0.8893 - val_loss: 0.5179 - val_top_2_accuracy: 0.9723
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9944 - loss: 0.0118 - top_2_accuracy: 0.9996 - val_accuracy: 0.8913 - val_loss: 0.4857 - val_top_2_accuracy: 0.9842
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9965 - loss: 0.0077 - top_2_accuracy: 1.0000 - val_accuracy: 0.8814 - val_loss: 0.7156 - val_top_2_accuracy: 0.9664
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9938 - loss: 0.0190 - top_2_accuracy: 0.9999 - val_accuracy: 0.8814 - val_loss: 0.5655 - val_top_2_accuracy: 0.9704
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9969 - loss: 0.0077 - top_2_accuracy: 1.0000 - val_accuracy: 0.8755 - val_loss: 0.8063 - val_top_2_accuracy: 0.9704
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9934 - loss: 0.0224 - top_2_accuracy: 0.9999 - val_accuracy: 0.8794 - val_loss: 0.6973 - val_top_2_accuracy: 0.9605
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - accuracy: 0.9970 - loss: 0.0096 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.6416 - val_top_2_accuracy: 0.9644
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9937 - loss: 0.0149 - top_2_accuracy: 1.0000 - val_accuracy: 0.9032 - val_loss: 0.5254 - val_top_2_accuracy: 0.9763
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 249ms/step - accuracy: 0.9972 - loss: 0.0083 - top_2_accuracy: 1.0000 - val_accuracy: 0.9032 - val_loss: 0.5607 - val_top_2_accuracy: 0.9625
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9983 - loss: 0.0057 - top_2_accuracy: 1.0000 - val_accuracy: 0.8814 - val_loss: 0.5955 - val_top_2_accuracy: 0.9664
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9966 - loss: 0.0103 - top_2_accuracy: 1.0000 - val_accuracy: 0.8814 - val_loss: 0.6288 - val_top_2_accuracy: 0.9783
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9975 - loss: 0.0056 - top_2_accuracy: 1.0000 - val_accuracy: 0.8893 - val_loss: 0.6882 - val_top_2_accuracy: 0.9723
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 239ms/step - accuracy: 0.9997 - loss: 0.0025 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.6396 - val_top_2_accuracy: 0.9763
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9990 - loss: 0.0022 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.6942 - val_top_2_accuracy: 0.9822
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9995 - loss: 0.0039 - top_2_accuracy: 1.0000 - val_accuracy: 0.8933 - val_loss: 0.6891 - val_top_2_accuracy: 0.9822
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9936 - loss: 0.0176 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.5645 - val_top_2_accuracy: 0.9783
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9922 - loss: 0.0177 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.6277 - val_top_2_accuracy: 0.9842
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9959 - loss: 0.0148 - top_2_accuracy: 0.9999 - val_accuracy: 0.8775 - val_loss: 0.5825 - val_top_2_accuracy: 0.9901
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 240ms/step - accuracy: 0.9953 - loss: 0.0126 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.7405 - val_top_2_accuracy: 0.9783
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 237ms/step - accuracy: 0.9936 - loss: 0.0172 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.7279 - val_top_2_accuracy: 0.9822
# MobileNet-V2 Training Summary:
#   Best Validation Loss: 0.4857 at epoch 22
#   Best Validation Accuracy: 0.9032 at epoch 28
#   Final Training Accuracy: 0.9941
#   Final Validation Accuracy: 0.8913
#   Overfitting (Train-Val): 0.1028
# ================================================================================
# CLASSIFICATION REPORT - MobileNet-V2
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.8506       0.9867       0.9136       75
# diabetic_retinopathy 0.9880       0.9880       0.9880       83
# glaucoma        0.9146       0.8427       0.8772       89
# normal          0.9070       0.8571       0.8814       91
# --------------------------------------------------------------------------------
# macro avg       0.9150       0.9186       0.9150       338
# weighted avg    0.9164       0.9142       0.9136       338
#
# Accuracy: 0.9142
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR MobileNet-V2:
# ==================================================
# Test Accuracy: 0.9142
# Test Top-2 Accuracy: 0.9822
# Test Loss: 0.5208
# Mean AP: 0.9711
# F1-Score (Macro): 0.9150
# Precision (Macro): 0.9150
# Recall (Macro): 0.9186
# Inference time per image: 16.6206 ms
# Best Validation Accuracy: 0.9032
# Parameters: 2,263,108
#
# ============================================================
# CREATING AND TRAINING: VGG16
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Parameters: 14,716,740
#
# ==================================================
# Training VGG16
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 78s 497ms/step - accuracy: 0.5506 - loss: 1.0123 - top_2_accuracy: 0.7682 - val_accuracy: 0.8142 - val_loss: 0.4424 - val_top_2_accuracy: 0.9625
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.8387 - loss: 0.4123 - top_2_accuracy: 0.9670 - val_accuracy: 0.8439 - val_loss: 0.3617 - val_top_2_accuracy: 0.9704
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.8934 - loss: 0.3123 - top_2_accuracy: 0.9753 - val_accuracy: 0.8597 - val_loss: 0.3426 - val_top_2_accuracy: 0.9802
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9062 - loss: 0.2607 - top_2_accuracy: 0.9819 - val_accuracy: 0.8834 - val_loss: 0.3640 - val_top_2_accuracy: 0.9763
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 274ms/step - accuracy: 0.9195 - loss: 0.2273 - top_2_accuracy: 0.9873 - val_accuracy: 0.8755 - val_loss: 0.3247 - val_top_2_accuracy: 0.9802
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9394 - loss: 0.1783 - top_2_accuracy: 0.9950 - val_accuracy: 0.8735 - val_loss: 0.3687 - val_top_2_accuracy: 0.9743
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9341 - loss: 0.1829 - top_2_accuracy: 0.9914 - val_accuracy: 0.8814 - val_loss: 0.3048 - val_top_2_accuracy: 0.9822
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.9406 - loss: 0.1514 - top_2_accuracy: 0.9960 - val_accuracy: 0.8992 - val_loss: 0.2565 - val_top_2_accuracy: 0.9921
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.9534 - loss: 0.1247 - top_2_accuracy: 0.9964 - val_accuracy: 0.9071 - val_loss: 0.2944 - val_top_2_accuracy: 0.9862
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.9481 - loss: 0.1438 - top_2_accuracy: 0.9965 - val_accuracy: 0.8933 - val_loss: 0.3680 - val_top_2_accuracy: 0.9881
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9662 - loss: 0.1020 - top_2_accuracy: 0.9961 - val_accuracy: 0.8992 - val_loss: 0.3026 - val_top_2_accuracy: 0.9941
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.9753 - loss: 0.0719 - top_2_accuracy: 0.9982 - val_accuracy: 0.8676 - val_loss: 0.4118 - val_top_2_accuracy: 0.9783
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 264ms/step - accuracy: 0.9653 - loss: 0.0971 - top_2_accuracy: 0.9971 - val_accuracy: 0.8933 - val_loss: 0.2846 - val_top_2_accuracy: 0.9901
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.9760 - loss: 0.0666 - top_2_accuracy: 0.9993 - val_accuracy: 0.8834 - val_loss: 0.3292 - val_top_2_accuracy: 0.9862
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9734 - loss: 0.0832 - top_2_accuracy: 0.9981 - val_accuracy: 0.8874 - val_loss: 0.3924 - val_top_2_accuracy: 0.9842
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 272ms/step - accuracy: 0.9725 - loss: 0.0766 - top_2_accuracy: 0.9963 - val_accuracy: 0.8953 - val_loss: 0.3317 - val_top_2_accuracy: 0.9921
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 277ms/step - accuracy: 0.9820 - loss: 0.0550 - top_2_accuracy: 0.9991 - val_accuracy: 0.8972 - val_loss: 0.3290 - val_top_2_accuracy: 0.9921
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9898 - loss: 0.0404 - top_2_accuracy: 0.9989 - val_accuracy: 0.9150 - val_loss: 0.3023 - val_top_2_accuracy: 0.9941
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 272ms/step - accuracy: 0.9875 - loss: 0.0417 - top_2_accuracy: 0.9997 - val_accuracy: 0.8854 - val_loss: 0.5107 - val_top_2_accuracy: 0.9901
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9891 - loss: 0.0383 - top_2_accuracy: 0.9990 - val_accuracy: 0.8972 - val_loss: 0.3942 - val_top_2_accuracy: 0.9881
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9953 - loss: 0.0191 - top_2_accuracy: 0.9996 - val_accuracy: 0.8893 - val_loss: 0.4241 - val_top_2_accuracy: 0.9921
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.9941 - loss: 0.0177 - top_2_accuracy: 0.9998 - val_accuracy: 0.8794 - val_loss: 0.7677 - val_top_2_accuracy: 0.9822
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.9826 - loss: 0.0464 - top_2_accuracy: 0.9974 - val_accuracy: 0.8854 - val_loss: 0.3892 - val_top_2_accuracy: 0.9901
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.9959 - loss: 0.0183 - top_2_accuracy: 1.0000 - val_accuracy: 0.8874 - val_loss: 0.5219 - val_top_2_accuracy: 0.9763
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.9922 - loss: 0.0283 - top_2_accuracy: 0.9996 - val_accuracy: 0.8972 - val_loss: 0.4766 - val_top_2_accuracy: 0.9822
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.9797 - loss: 0.0689 - top_2_accuracy: 0.9975 - val_accuracy: 0.9051 - val_loss: 0.4840 - val_top_2_accuracy: 0.9941
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.9956 - loss: 0.0121 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.5848 - val_top_2_accuracy: 0.9862
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.9976 - loss: 0.0058 - top_2_accuracy: 0.9999 - val_accuracy: 0.8063 - val_loss: 1.6716 - val_top_2_accuracy: 0.9526
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 268ms/step - accuracy: 0.9748 - loss: 0.0831 - top_2_accuracy: 0.9985 - val_accuracy: 0.8953 - val_loss: 0.5701 - val_top_2_accuracy: 0.9901
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9786 - loss: 0.0644 - top_2_accuracy: 0.9978 - val_accuracy: 0.9051 - val_loss: 0.4313 - val_top_2_accuracy: 0.9901
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9887 - loss: 0.0369 - top_2_accuracy: 0.9990 - val_accuracy: 0.8874 - val_loss: 0.5495 - val_top_2_accuracy: 0.9901
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.9901 - loss: 0.0285 - top_2_accuracy: 0.9998 - val_accuracy: 0.8953 - val_loss: 0.4321 - val_top_2_accuracy: 0.9881
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.9955 - loss: 0.0134 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.6064 - val_top_2_accuracy: 0.9802
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.9918 - loss: 0.0211 - top_2_accuracy: 0.9985 - val_accuracy: 0.8874 - val_loss: 0.8476 - val_top_2_accuracy: 0.9763
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.9797 - loss: 0.0688 - top_2_accuracy: 0.9979 - val_accuracy: 0.8953 - val_loss: 0.4743 - val_top_2_accuracy: 0.9901
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 274ms/step - accuracy: 0.9980 - loss: 0.0045 - top_2_accuracy: 1.0000 - val_accuracy: 0.8913 - val_loss: 0.7658 - val_top_2_accuracy: 0.9822
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - accuracy: 0.9942 - loss: 0.0146 - top_2_accuracy: 1.0000 - val_accuracy: 0.9051 - val_loss: 0.6480 - val_top_2_accuracy: 0.9881
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 275ms/step - accuracy: 0.9951 - loss: 0.0167 - top_2_accuracy: 0.9999 - val_accuracy: 0.9032 - val_loss: 0.5898 - val_top_2_accuracy: 0.9862
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.9870 - loss: 0.0370 - top_2_accuracy: 0.9998 - val_accuracy: 0.9012 - val_loss: 0.5583 - val_top_2_accuracy: 0.9921
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 1.0000 - loss: 6.3259e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9071 - val_loss: 0.6554 - val_top_2_accuracy: 0.9921
# VGG16 Training Summary:
#   Best Validation Loss: 0.2565 at epoch 8
#   Best Validation Accuracy: 0.9150 at epoch 18
#   Final Training Accuracy: 0.9997
#   Final Validation Accuracy: 0.9071
#   Overfitting (Train-Val): 0.0926
# ================================================================================
# CLASSIFICATION REPORT - VGG16
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.9367       0.9867       0.9610       75
# diabetic_retinopathy 1.0000       1.0000       1.0000       83
# glaucoma        0.9518       0.8876       0.9186       89
# normal          0.9140       0.9341       0.9239       91
# --------------------------------------------------------------------------------
# macro avg       0.9506       0.9521       0.9509       338
# weighted avg    0.9501       0.9497       0.9494       338
#
# Accuracy: 0.9497
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR VGG16:
# ==================================================
# Test Accuracy: 0.9497
# Test Top-2 Accuracy: 0.9941
# Test Loss: 0.3340
# Mean AP: 0.9703
# F1-Score (Macro): 0.9509
# Precision (Macro): 0.9506
# Recall (Macro): 0.9521
# Inference time per image: 6.3897 ms
# Best Validation Accuracy: 0.9150
# Parameters: 14,716,740
#
# ============================================================
# CREATING AND TRAINING: DenseNet201
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Parameters: 18,329,668
#
# ==================================================
# Training DenseNet201
# ==================================================
# Epoch 1/40
# 2025-11-01 11:43:26.533485: E external/local_xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module a_inference_one_step_on_data_553437__.89571] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2025-11-01 11:43:27.228387: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2m0.695043108s
#
# ********************************
# [Compiling module a_inference_one_step_on_data_553437__.89571] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 741s 3s/step - accuracy: 0.7827 - loss: 0.5448 - top_2_accuracy: 0.9267 - val_accuracy: 0.6126 - val_loss: 1.2739 - val_top_2_accuracy: 0.8636
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 304ms/step - accuracy: 0.9583 - loss: 0.1271 - top_2_accuracy: 0.9973 - val_accuracy: 0.8300 - val_loss: 0.5032 - val_top_2_accuracy: 0.9644
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 310ms/step - accuracy: 0.9821 - loss: 0.0574 - top_2_accuracy: 0.9985 - val_accuracy: 0.7391 - val_loss: 0.8771 - val_top_2_accuracy: 0.9407
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 311ms/step - accuracy: 0.9860 - loss: 0.0421 - top_2_accuracy: 0.9993 - val_accuracy: 0.8972 - val_loss: 0.3291 - val_top_2_accuracy: 0.9881
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 306ms/step - accuracy: 0.9914 - loss: 0.0260 - top_2_accuracy: 1.0000 - val_accuracy: 0.9130 - val_loss: 0.3189 - val_top_2_accuracy: 0.9901
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 310ms/step - accuracy: 0.9926 - loss: 0.0219 - top_2_accuracy: 0.9998 - val_accuracy: 0.8676 - val_loss: 0.5004 - val_top_2_accuracy: 0.9605
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 311ms/step - accuracy: 0.9869 - loss: 0.0355 - top_2_accuracy: 1.0000 - val_accuracy: 0.8953 - val_loss: 0.5163 - val_top_2_accuracy: 0.9822
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 310ms/step - accuracy: 0.9935 - loss: 0.0192 - top_2_accuracy: 1.0000 - val_accuracy: 0.8992 - val_loss: 0.4985 - val_top_2_accuracy: 0.9802
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 310ms/step - accuracy: 0.9940 - loss: 0.0213 - top_2_accuracy: 0.9998 - val_accuracy: 0.8854 - val_loss: 0.4421 - val_top_2_accuracy: 0.9901
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 305ms/step - accuracy: 0.9964 - loss: 0.0135 - top_2_accuracy: 1.0000 - val_accuracy: 0.9111 - val_loss: 0.3614 - val_top_2_accuracy: 0.9862
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 307ms/step - accuracy: 0.9946 - loss: 0.0155 - top_2_accuracy: 1.0000 - val_accuracy: 0.9012 - val_loss: 0.4106 - val_top_2_accuracy: 0.9783
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 303ms/step - accuracy: 0.9960 - loss: 0.0147 - top_2_accuracy: 1.0000 - val_accuracy: 0.9051 - val_loss: 0.3308 - val_top_2_accuracy: 0.9881
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 305ms/step - accuracy: 0.9930 - loss: 0.0199 - top_2_accuracy: 0.9995 - val_accuracy: 0.8735 - val_loss: 0.5221 - val_top_2_accuracy: 0.9763
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9939 - loss: 0.0202 - top_2_accuracy: 1.0000 - val_accuracy: 0.9071 - val_loss: 0.3652 - val_top_2_accuracy: 0.9881
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9982 - loss: 0.0066 - top_2_accuracy: 1.0000 - val_accuracy: 0.9012 - val_loss: 0.4281 - val_top_2_accuracy: 0.9960
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 33s 305ms/step - accuracy: 0.9957 - loss: 0.0123 - top_2_accuracy: 1.0000 - val_accuracy: 0.8972 - val_loss: 0.4480 - val_top_2_accuracy: 0.9901
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9976 - loss: 0.0072 - top_2_accuracy: 1.0000 - val_accuracy: 0.8656 - val_loss: 0.8206 - val_top_2_accuracy: 0.9664
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9954 - loss: 0.0142 - top_2_accuracy: 0.9999 - val_accuracy: 0.9051 - val_loss: 0.5262 - val_top_2_accuracy: 0.9802
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9935 - loss: 0.0271 - top_2_accuracy: 1.0000 - val_accuracy: 0.8281 - val_loss: 0.6355 - val_top_2_accuracy: 0.9605
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9859 - loss: 0.0410 - top_2_accuracy: 0.9998 - val_accuracy: 0.9229 - val_loss: 0.3194 - val_top_2_accuracy: 0.9881
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9999 - loss: 0.0030 - top_2_accuracy: 1.0000 - val_accuracy: 0.8498 - val_loss: 0.9499 - val_top_2_accuracy: 0.9842
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9877 - loss: 0.0386 - top_2_accuracy: 1.0000 - val_accuracy: 0.9150 - val_loss: 0.3794 - val_top_2_accuracy: 0.9822
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9964 - loss: 0.0101 - top_2_accuracy: 1.0000 - val_accuracy: 0.9170 - val_loss: 0.3700 - val_top_2_accuracy: 0.9862
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9996 - loss: 0.0025 - top_2_accuracy: 1.0000 - val_accuracy: 0.9269 - val_loss: 0.3456 - val_top_2_accuracy: 0.9901
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9992 - loss: 0.0041 - top_2_accuracy: 1.0000 - val_accuracy: 0.9190 - val_loss: 0.3701 - val_top_2_accuracy: 0.9941
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9989 - loss: 0.0081 - top_2_accuracy: 1.0000 - val_accuracy: 0.9150 - val_loss: 0.4778 - val_top_2_accuracy: 0.9881
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9992 - loss: 0.0028 - top_2_accuracy: 1.0000 - val_accuracy: 0.9249 - val_loss: 0.3405 - val_top_2_accuracy: 0.9901
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 301ms/step - accuracy: 0.9994 - loss: 0.0011 - top_2_accuracy: 1.0000 - val_accuracy: 0.9407 - val_loss: 0.3338 - val_top_2_accuracy: 0.9921
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 1.0000 - loss: 7.2016e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9229 - val_loss: 0.3856 - val_top_2_accuracy: 0.9901
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 1.0000 - loss: 2.6562e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9229 - val_loss: 0.3689 - val_top_2_accuracy: 0.9921
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 1.0000 - loss: 2.7838e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9289 - val_loss: 0.3658 - val_top_2_accuracy: 0.9921
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9999 - loss: 4.9256e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9289 - val_loss: 0.3694 - val_top_2_accuracy: 0.9901
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9998 - loss: 4.5965e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9328 - val_loss: 0.3694 - val_top_2_accuracy: 0.9901
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 1.0000 - loss: 6.0366e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9328 - val_loss: 0.3855 - val_top_2_accuracy: 0.9901
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 304ms/step - accuracy: 0.9998 - loss: 0.0013 - top_2_accuracy: 1.0000 - val_accuracy: 0.9308 - val_loss: 0.3992 - val_top_2_accuracy: 0.9901
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9989 - loss: 0.0011 - top_2_accuracy: 1.0000 - val_accuracy: 0.9368 - val_loss: 0.3896 - val_top_2_accuracy: 0.9881
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9994 - loss: 6.8996e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9328 - val_loss: 0.3888 - val_top_2_accuracy: 0.9901
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 299ms/step - accuracy: 0.9997 - loss: 7.1898e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9368 - val_loss: 0.3895 - val_top_2_accuracy: 0.9901
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 300ms/step - accuracy: 0.9998 - loss: 3.2883e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9348 - val_loss: 0.3942 - val_top_2_accuracy: 0.9921
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 32s 302ms/step - accuracy: 0.9993 - loss: 8.4264e-04 - top_2_accuracy: 1.0000 - val_accuracy: 0.9387 - val_loss: 0.3913 - val_top_2_accuracy: 0.9921
# DenseNet201 Training Summary:
#   Best Validation Loss: 0.3189 at epoch 5
#   Best Validation Accuracy: 0.9407 at epoch 28
#   Final Training Accuracy: 0.9994
#   Final Validation Accuracy: 0.9387
#   Overfitting (Train-Val): 0.0607
# ================================================================================
# CLASSIFICATION REPORT - DenseNet201
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.9481       0.9733       0.9605       75
# diabetic_retinopathy 1.0000       1.0000       1.0000       83
# glaucoma        0.9419       0.9101       0.9257       89
# normal          0.9457       0.9560       0.9508       91
# --------------------------------------------------------------------------------
# macro avg       0.9589       0.9599       0.9593       338
# weighted avg    0.9585       0.9586       0.9584       338
#
# Accuracy: 0.9586
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR DenseNet201:
# ==================================================
# Test Accuracy: 0.9586
# Test Top-2 Accuracy: 0.9970
# Test Loss: 0.2102
# Mean AP: 0.9868
# F1-Score (Macro): 0.9593
# Precision (Macro): 0.9589
# Recall (Macro): 0.9599
# Inference time per image: 73.9758 ms
# Best Validation Accuracy: 0.9407
# Parameters: 18,329,668
#
# ============================================================
# CREATING AND TRAINING: ViT Small
# ============================================================
# Parameters: 21,667,204
#
# ==================================================
# Training ViT Small
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 138s 593ms/step - accuracy: 0.2413 - loss: 8.2107 - top_2_accuracy: 0.4877 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2373 - loss: 8.3315 - top_2_accuracy: 0.4831 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 258ms/step - accuracy: 0.2395 - loss: 8.3412 - top_2_accuracy: 0.4825 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2368 - loss: 8.1524 - top_2_accuracy: 0.4942 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 261ms/step - accuracy: 0.2337 - loss: 8.3479 - top_2_accuracy: 0.4821 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 266ms/step - accuracy: 0.2383 - loss: 8.1439 - top_2_accuracy: 0.4947 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 267ms/step - accuracy: 0.2453 - loss: 8.2338 - top_2_accuracy: 0.4892 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 259ms/step - accuracy: 0.2307 - loss: 8.1533 - top_2_accuracy: 0.4942 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2233 - loss: 8.4436 - top_2_accuracy: 0.4761 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 269ms/step - accuracy: 0.2300 - loss: 8.4063 - top_2_accuracy: 0.4785 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.2333 - loss: 8.3659 - top_2_accuracy: 0.4810 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.2276 - loss: 8.3599 - top_2_accuracy: 0.4813 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2221 - loss: 8.3211 - top_2_accuracy: 0.4837 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.2284 - loss: 8.3110 - top_2_accuracy: 0.4844 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.2320 - loss: 8.3421 - top_2_accuracy: 0.4824 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 265ms/step - accuracy: 0.2533 - loss: 8.0229 - top_2_accuracy: 0.5022 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 266ms/step - accuracy: 0.2263 - loss: 8.2706 - top_2_accuracy: 0.4869 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 267ms/step - accuracy: 0.2389 - loss: 8.2561 - top_2_accuracy: 0.4878 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 19/40
# ...
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.2328 - loss: 8.3929 - top_2_accuracy: 0.4793 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 271ms/step - accuracy: 0.2390 - loss: 8.0465 - top_2_accuracy: 0.5008 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2334 - loss: 8.2990 - top_2_accuracy: 0.4851 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 262ms/step - accuracy: 0.2373 - loss: 8.0136 - top_2_accuracy: 0.5028 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 266ms/step - accuracy: 0.2256 - loss: 8.2532 - top_2_accuracy: 0.4880 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 274ms/step - accuracy: 0.2276 - loss: 8.3538 - top_2_accuracy: 0.4817 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 29s 270ms/step - accuracy: 0.2430 - loss: 8.1765 - top_2_accuracy: 0.4927 - val_accuracy: 0.2708 - val_loss: 7.7405 - val_top_2_accuracy: 0.5198
# ViT Small Training Summary:
#   Best Validation Loss: 7.7405 at epoch 23
#   Best Validation Accuracy: 0.2708 at epoch 1
#   Final Training Accuracy: 0.2315
#   Final Validation Accuracy: 0.2708
#   Overfitting (Train-Val): -0.0392
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
# CLASSIFICATION REPORT - ViT Small
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.0000       0.0000       0.0000       75
# diabetic_retinopathy 0.0000       0.0000       0.0000       83
# glaucoma        0.2633       1.0000       0.4169       89
# normal          0.0000       0.0000       0.0000       91
# --------------------------------------------------------------------------------
# macro avg       0.0658       0.2500       0.1042       338
# weighted avg    0.0693       0.2633       0.1098       338
#
# Accuracy: 0.2633
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR ViT Small:
# ==================================================
# Test Accuracy: 0.2633
# Test Top-2 Accuracy: 0.5325
# Test Loss: 7.5345
# Mean AP: 0.3795
# F1-Score (Macro): 0.1042
# Precision (Macro): 0.0658
# Recall (Macro): 0.2500
# Inference time per image: 27.1834 ms
# Best Validation Accuracy: 0.2708
# Parameters: 21,667,204
#
# ============================================================
# CREATING AND TRAINING: Eye Disease Classifier
# ============================================================
# Eye Disease Classifier built successfully with 14914279 parameters
# Parameters: 14,914,279
#
# ==================================================
# Training Eye Disease Classifier
# ==================================================
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 44s 338ms/step - accuracy: 0.4783 - loss: 1.3860 - top_2_accuracy: 0.6993 - val_accuracy: 0.8241 - val_loss: 0.8673 - val_top_2_accuracy: 0.9585
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.8088 - loss: 0.5449 - top_2_accuracy: 0.9407 - val_accuracy: 0.8320 - val_loss: 0.6128 - val_top_2_accuracy: 0.9723
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.8490 - loss: 0.4191 - top_2_accuracy: 0.9591 - val_accuracy: 0.8439 - val_loss: 0.5020 - val_top_2_accuracy: 0.9723
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.8826 - loss: 0.3308 - top_2_accuracy: 0.9771 - val_accuracy: 0.7846 - val_loss: 0.5827 - val_top_2_accuracy: 0.9111
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 249ms/step - accuracy: 0.8945 - loss: 0.3044 - top_2_accuracy: 0.9784 - val_accuracy: 0.8399 - val_loss: 0.3870 - val_top_2_accuracy: 0.9763
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9153 - loss: 0.2443 - top_2_accuracy: 0.9825 - val_accuracy: 0.8182 - val_loss: 0.4462 - val_top_2_accuracy: 0.9763
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 268ms/step - accuracy: 0.9134 - loss: 0.2324 - top_2_accuracy: 0.9888 - val_accuracy: 0.8617 - val_loss: 0.3759 - val_top_2_accuracy: 0.9763
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9264 - loss: 0.2041 - top_2_accuracy: 0.9870 - val_accuracy: 0.8043 - val_loss: 0.5465 - val_top_2_accuracy: 0.9704
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9193 - loss: 0.2199 - top_2_accuracy: 0.9878 - val_accuracy: 0.8261 - val_loss: 0.6983 - val_top_2_accuracy: 0.9486
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9480 - loss: 0.1602 - top_2_accuracy: 0.9867 - val_accuracy: 0.8419 - val_loss: 0.4418 - val_top_2_accuracy: 0.9842
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9532 - loss: 0.1476 - top_2_accuracy: 0.9896 - val_accuracy: 0.8696 - val_loss: 0.4247 - val_top_2_accuracy: 0.9783
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9573 - loss: 0.1214 - top_2_accuracy: 0.9945 - val_accuracy: 0.8518 - val_loss: 0.3816 - val_top_2_accuracy: 0.9842
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.9535 - loss: 0.1214 - top_2_accuracy: 0.9944 - val_accuracy: 0.8814 - val_loss: 0.4313 - val_top_2_accuracy: 0.9842
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9597 - loss: 0.1205 - top_2_accuracy: 0.9945 - val_accuracy: 0.8696 - val_loss: 0.4604 - val_top_2_accuracy: 0.9862
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.9660 - loss: 0.1019 - top_2_accuracy: 0.9974 - val_accuracy: 0.8933 - val_loss: 0.4332 - val_top_2_accuracy: 0.9901
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 254ms/step - accuracy: 0.9814 - loss: 0.0591 - top_2_accuracy: 0.9988 - val_accuracy: 0.8024 - val_loss: 0.7698 - val_top_2_accuracy: 0.9506
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9645 - loss: 0.1060 - top_2_accuracy: 0.9963 - val_accuracy: 0.8775 - val_loss: 0.5427 - val_top_2_accuracy: 0.9802
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 250ms/step - accuracy: 0.9805 - loss: 0.0556 - top_2_accuracy: 0.9976 - val_accuracy: 0.8636 - val_loss: 0.5444 - val_top_2_accuracy: 0.9822
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9832 - loss: 0.0528 - top_2_accuracy: 0.9964 - val_accuracy: 0.8814 - val_loss: 0.5309 - val_top_2_accuracy: 0.9862
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9801 - loss: 0.0614 - top_2_accuracy: 0.9967 - val_accuracy: 0.8755 - val_loss: 0.5413 - val_top_2_accuracy: 0.9783
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 246ms/step - accuracy: 0.9814 - loss: 0.0603 - top_2_accuracy: 0.9992 - val_accuracy: 0.8498 - val_loss: 0.7142 - val_top_2_accuracy: 0.9605
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9898 - loss: 0.0412 - top_2_accuracy: 0.9983 - val_accuracy: 0.8083 - val_loss: 1.0795 - val_top_2_accuracy: 0.9229
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 260ms/step - accuracy: 0.9812 - loss: 0.0590 - top_2_accuracy: 0.9987 - val_accuracy: 0.7905 - val_loss: 1.6109 - val_top_2_accuracy: 0.9605
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 253ms/step - accuracy: 0.9698 - loss: 0.0840 - top_2_accuracy: 0.9970 - val_accuracy: 0.8597 - val_loss: 0.4971 - val_top_2_accuracy: 0.9704
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 249ms/step - accuracy: 0.9834 - loss: 0.0433 - top_2_accuracy: 0.9976 - val_accuracy: 0.8715 - val_loss: 0.6203 - val_top_2_accuracy: 0.9822
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9909 - loss: 0.0326 - top_2_accuracy: 0.9992 - val_accuracy: 0.8794 - val_loss: 0.4640 - val_top_2_accuracy: 0.9822
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9901 - loss: 0.0308 - top_2_accuracy: 0.9997 - val_accuracy: 0.8794 - val_loss: 0.6489 - val_top_2_accuracy: 0.9842
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 247ms/step - accuracy: 0.9932 - loss: 0.0269 - top_2_accuracy: 0.9994 - val_accuracy: 0.8933 - val_loss: 0.5311 - val_top_2_accuracy: 0.9881
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9899 - loss: 0.0337 - top_2_accuracy: 0.9981 - val_accuracy: 0.8498 - val_loss: 0.8051 - val_top_2_accuracy: 0.9802
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 248ms/step - accuracy: 0.9804 - loss: 0.0510 - top_2_accuracy: 0.9970 - val_accuracy: 0.8577 - val_loss: 0.7025 - val_top_2_accuracy: 0.9664
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9909 - loss: 0.0305 - top_2_accuracy: 0.9990 - val_accuracy: 0.8794 - val_loss: 0.5142 - val_top_2_accuracy: 0.9862
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9923 - loss: 0.0198 - top_2_accuracy: 0.9981 - val_accuracy: 0.8636 - val_loss: 0.8009 - val_top_2_accuracy: 0.9763
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 251ms/step - accuracy: 0.9889 - loss: 0.0369 - top_2_accuracy: 0.9985 - val_accuracy: 0.8617 - val_loss: 0.6758 - val_top_2_accuracy: 0.9565
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 248ms/step - accuracy: 0.9830 - loss: 0.0690 - top_2_accuracy: 0.9973 - val_accuracy: 0.8715 - val_loss: 0.6229 - val_top_2_accuracy: 0.9664
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9943 - loss: 0.0197 - top_2_accuracy: 1.0000 - val_accuracy: 0.8874 - val_loss: 0.5443 - val_top_2_accuracy: 0.9802
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 242ms/step - accuracy: 0.9934 - loss: 0.0223 - top_2_accuracy: 0.9997 - val_accuracy: 0.8478 - val_loss: 0.9053 - val_top_2_accuracy: 0.9743
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9932 - loss: 0.0200 - top_2_accuracy: 0.9997 - val_accuracy: 0.8557 - val_loss: 0.7030 - val_top_2_accuracy: 0.9822
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9941 - loss: 0.0196 - top_2_accuracy: 0.9991 - val_accuracy: 0.8103 - val_loss: 0.8963 - val_top_2_accuracy: 0.9704
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.9891 - loss: 0.0307 - top_2_accuracy: 0.9990 - val_accuracy: 0.8775 - val_loss: 0.8305 - val_top_2_accuracy: 0.9644
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 27s 256ms/step - accuracy: 0.9943 - loss: 0.0179 - top_2_accuracy: 1.0000 - val_accuracy: 0.8933 - val_loss: 0.5315 - val_top_2_accuracy: 0.9822
# Eye Disease Classifier Training Summary:
#   Best Validation Loss: 0.3759 at epoch 7
#   Best Validation Accuracy: 0.8933 at epoch 15
#   Final Training Accuracy: 0.9929
#   Final Validation Accuracy: 0.8933
#   Overfitting (Train-Val): 0.0996
# ================================================================================
# CLASSIFICATION REPORT - Eye Disease Classifier
# ================================================================================
# Class           Precision    Recall       F1-Score     Support
# --------------------------------------------------------------------------------
# cataract        0.8987       0.9467       0.9221       75
# diabetic_retinopathy 1.0000       1.0000       1.0000       83
# glaucoma        0.8041       0.8764       0.8387       89
# normal          0.9114       0.7912       0.8471       91
# --------------------------------------------------------------------------------
# macro avg       0.9036       0.9036       0.9020       338
# weighted avg    0.9021       0.8994       0.8991       338
#
# Accuracy: 0.8994
# ================================================================================
#
# ==================================================
# TEST RESULTS FOR Eye Disease Classifier:
# ==================================================
# Test Accuracy: 0.8994
# Test Top-2 Accuracy: 0.9970
# Test Loss: 0.4359
# Mean AP: 0.9617
# F1-Score (Macro): 0.9020
# Precision (Macro): 0.9036
# Recall (Macro): 0.9036
# Inference time per image: 7.6096 ms
# Best Validation Accuracy: 0.8933
# Parameters: 14,914,279
#
# ================================================================================
# COMBINED TRAINING HISTORIES VISUALIZATION
# ================================================================================
# ================================================================================
# COMPREHENSIVE RESULTS VISUALIZATION
# ================================================================================
# ==================================================================================================================================
# COMPREHENSIVE RESULTS COMPARISON (4-DIGIT PRECISION)
# ==================================================================================================================================
# Model                Test Acc   Top-2 Acc  mAP        F1         Precision  Recall     Params(M)    Time(ms)
# ----------------------------------------------------------------------------------------------------------------------------------
# DenseNet201          0.9586     0.9970     0.9868     0.9593     0.9589     0.9599     18.33        73.9760
# VGG16                0.9497     0.9941     0.9703     0.9509     0.9506     0.9521     14.72        6.3900
# MobileNet-V2         0.9142     0.9822     0.9711     0.9150     0.9150     0.9186     2.26         16.6210
# Eye Disease Classifier 0.8994     0.9970     0.9617     0.9020     0.9036     0.9036     14.91        7.6100
# EfficientNet-B0      0.3817     0.5592     0.5298     0.2948     0.6287     0.4117     4.05         26.4620
# ViT Small            0.2633     0.5325     0.3795     0.1042     0.0658     0.2500     21.67        27.1830
#
# ==================================================================================================================================
# FINAL ANALYSIS AND RECOMMENDATIONS
# ==================================================================================================================================
# 🏆 BEST OVERALL PERFORMANCE: DenseNet201
#    → Test Accuracy: 0.9586
#    → F1-Score: 0.9593
#    → mAP: 0.9868
#    → Parameters: 18.33M
#
# ⚡ MOST EFFICIENT: MobileNet-V2
#    → Efficiency Score: 0.4040
#    → Test Accuracy: 0.9142
#    → Parameters: 2.26M
#
# 🚀 FASTEST INFERENCE: VGG16
#    → Inference Time: 6.3900 ms
#    → Test Accuracy: 0.9497
#    → FPS: 156.5
#
# 🔬 YOUR EYE DISEASE CLASSIFIER ANALYSIS:
#    → Test Accuracy: 0.8994
#    → F1-Score: 0.9020
#    → Mean AP: 0.9617
#    → Efficiency: 0.0603
#    → Inference Time: 7.6100 ms
#    → Rank by Accuracy: 4/6
#
# 📊 Results saved to: eye_disease_comprehensive_results.csv
#
# ==================================================================================================================================
# ANALYSIS COMPLETE - ALL MODELS TRAINED SEQUENTIALLY
# ==================================================================================================================================

# %%
import pandas as pd
from IPython.display import display

# Load the CSV
df = pd.read_csv("eye_disease_comprehensive_results.csv")

# Show shape and column names
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

# Display the first few rows as a nice table
display(df.head(10))

# If you want summary stats for numeric columns
display(df.describe())

# If you want to sort models by accuracy (or another metric)
if "accuracy" in df.columns:
    display(df.sort_values(by="accuracy", ascending=False).head(10))
# Out:
# Shape: (6, 12)
# Columns: ['Unnamed: 0', 'test_accuracy', 'test_top2_accuracy', 'test_loss', 'parameters', 'best_val_accuracy', 'mean_ap', 'precision_macro', 'recall_macro', 'f1_macro', 'inference_time_per_image', 'inference_time_per_batch']
#                Unnamed: 0  test_accuracy  test_top2_accuracy  test_loss  \
# 0             DenseNet201         0.9586              0.9970     0.2102
# 1                   VGG16         0.9497              0.9941     0.3340
# 2            MobileNet-V2         0.9142              0.9822     0.5208
# 3  Eye Disease Classifier         0.8994              0.9970     0.4359
# 4         EfficientNet-B0         0.3817              0.5592     1.8648
# 5               ViT Small         0.2633              0.5325     7.5345
#
#    parameters  best_val_accuracy  mean_ap  precision_macro  recall_macro  \
# 0  18329668.0             0.9407   0.9868           0.9589        0.9599
# 1  14716740.0             0.9150   0.9703           0.9506        0.9521
# 2   2263108.0             0.9032   0.9711           0.9150        0.9186
# 3  14914279.0             0.8933   0.9617           0.9036        0.9036
# 4   4054695.0             0.7470   0.5298           0.6287        0.4117
# 5  21667204.0             0.2708   0.3795           0.0658        0.2500
#
#    f1_macro  inference_time_per_image  inference_time_per_batch
# 0    0.9593                  0.073976                    2.3672
# 1    0.9509                  0.006390                    0.2045
# 2    0.9150                  0.016621                    0.5319
# 3    0.9020                  0.007610                    0.2435
# 4    0.2948                  0.026462                    0.8468
# 5    0.1042                  0.027183                    0.8699
#        test_accuracy  test_top2_accuracy  test_loss    parameters  \
# count       6.000000            6.000000   6.000000  6.000000e+00
# mean        0.727817            0.843667   1.816700  1.265762e+07
# std         0.316937            0.230907   2.865685  7.806836e+06
# min         0.263300            0.532500   0.210200  2.263108e+06
# 25%         0.511125            0.664950   0.359475  6.720206e+06
# 50%         0.906800            0.988150   0.478350  1.481551e+07
# 75%         0.940825            0.996275   1.528800  1.747582e+07
# max         0.958600            0.997000   7.534500  2.166720e+07
#
#        best_val_accuracy   mean_ap  precision_macro  recall_macro  f1_macro  \
# count           6.000000  6.000000         6.000000      6.000000  6.000000
# mean            0.778333  0.799867         0.737100      0.732650  0.687700
# std             0.257846  0.271716         0.351153      0.316089  0.383529
# min             0.270800  0.379500         0.065800      0.250000  0.104200
# 25%             0.783575  0.637775         0.697425      0.534675  0.446600
# 50%             0.898250  0.966000         0.909300      0.911100  0.908500
# 75%             0.912050  0.970900         0.941700      0.943725  0.941925
# max             0.940700  0.986800         0.958900      0.959900  0.959300
#
#        inference_time_per_image  inference_time_per_batch
# count                  6.000000                  6.000000
# mean                   0.026374                  0.843967
# std                    0.024953                  0.798472
# min                    0.006390                  0.204500
# 25%                    0.009863                  0.315600
# 50%                    0.021541                  0.689350
# 75%                    0.027003                  0.864125
# max                    0.073976                  2.367200

# %%
import tensorflow as tf

save_path = "/kaggle/working/MobileNetV2_model.h5"

# Save the current trained model (if it's MobileNetV2)
model.save(save_path, include_optimizer=False)
print(f"✅ MobileNetV2 model saved successfully at: {save_path}")
# Out:
# ✅ MobileNetV2 model saved successfully at: /kaggle/working/MobileNetV2_model.h5

# %%
import shutil

shutil.make_archive('/kaggle/working/MobileNetV2_model', 'zip', '/kaggle/working', 'MobileNetV2_model.h5')
# Out:
# '/kaggle/working/MobileNetV2_model.zip'

# %%
from IPython.display import FileLink
FileLink('/kaggle/working/MobileNetV2_model.zip')
# Out:
# /kaggle/working/MobileNetV2_model.zip

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Enable optimizations to reduce size and fix common op issues
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Allow select TensorFlow ops (for unsupported layers)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
    tf.lite.OpsSet.SELECT_TF_OPS
]

try:
    tflite_model = converter.convert()
    with open("/kaggle/working/MobileNetV2_model.tflite", "wb") as f:
        f.write(tflite_model)
    print("✅ Conversion successful! Saved as MobileNetV2_model.tflite")
except Exception as e:
    print("❌ Conversion failed:", e)
# Out:
# Saved artifact at '/tmp/tmpd2q7i6ke'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_image')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136905803269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803269712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803268944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803268752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136907147324368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803270480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136905803270096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429242128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429241360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429238288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429240592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429237520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429244240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429241168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429240016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896429243856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392928464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392927504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392929424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392933072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392932880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392933456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392932304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392929808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392930000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392930384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392930192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392928848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392931920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392932496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136896392936336: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Conversion successful! Saved as MobileNetV2_model.tflite
# W0000 00:00:1762002222.540858      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1762002222.540902      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1762002222.562201      36 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
# !ls -lh /kaggle/working/MobileNetV2_model.tflite
# Out:
# -rw-r--r-- 1 root root 15M Nov  1 13:03 /kaggle/working/MobileNetV2_model.tflite

# %%
from IPython.display import FileLink
FileLink("/kaggle/working/MobileNetV2_model.tflite")
# Out:
# /kaggle/working/MobileNetV2_model.tflite
